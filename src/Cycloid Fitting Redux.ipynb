# %% [markdown]
# # Cycloid Fitting
#
# ### Simplified to reduce notebook size

# %% [markdown]
# ## Load Cyloid Data Points and Bezier Curves

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import curves.bezier as bezier
import curves.fitCurves as fit
import StressTools as tools
import utils
import fitting
import cycloidData
from scipy import stats
from os import path
from datetime import datetime

interior = utils.import_interior('interior1')

TOLERANCE = 1

cycloids = cycloidData.load_all_cycloids()
highResCycloids = cycloidData.load_all_cycloids(points_per_curve=1000)

min_vals = np.array([0, 0.1, 0])
max_vals = np.array([360, 1, 360])
constraints = [
    dict(wrapValue=True, minValue=1e-8, maxValue=1),
    dict(minValue=1e-8, maxValue=1, unstick=True),
    dict(wrapValue=True, minValue=0, maxValue=1)
]

tight_obliquity_contstraints = [
        dict(wrapValue=True, minValue=1e-8, maxValue=1),
        dict(minValue=0.62, maxValue=0.82, unstick=True),
        dict(wrapValue=True, minValue=0, maxValue=1)
    ]

def getConstraints(obliquity, longitude_max=1):
    return [
        dict(wrapValue=True, minValue=1e-8, maxValue=1),
        dict(minValue=obliquity, maxValue=obliquity, unstick=False),
        dict(wrapValue=True, minValue=0, maxValue=longitude_max)
    ]

def get_longitude_only_constraints(obliquity, phase):
    return [
        dict(minValue=phase, maxValue=phase, unstick=False),
        dict(minValue=obliquity, maxValue=obliquity, unstick=False),
        dict(wrapValue=True, minValue=0, maxValue=1)
    ]

# %% [markdown]
# ### Helper Functions

# %%
def logmessage(msg):
    now = datetime.now()
    timestamp = now.strftime("%H:%M:%S")
    
    print(f'[{timestamp}] {msg}')
    

def translate_params(params, minVals, maxVals):
    if len(params) == 3:
        variables = params * (max_vals - min_vals) + min_vals # denormalize
    else:
        variables = params * (max_vals[0:2:] - min_vals[0:2:]) + min_vals[0:2:]

    return variables

def setChartXLimit(points, plt):
    BUFFER_PERCENT = 0.025

    first = points['lon'].max()
    last = points['lon'].min()

    buffer = (first - last) * BUFFER_PERCENT

    plt.xlim(first + buffer, last - buffer)


def check_fit(params, minVals, maxVals, curve, interior, tolerance=0.25, title='',
              verbose=True, path='./output/stressfield.csv.gz'):

    if len(params) == 3:
        variables = params * (max_vals - min_vals) + min_vals # denormalize
    else:
        variables = params * (max_vals[0:2:] - min_vals[0:2:]) + min_vals[0:2:]

    data, loss = fitting.match_stresses(curve,
                                        variables,
                                        interior,
                                        save_stress_field=True,
                                        path=path)
    if verbose:
        plt.figure()
        plt.title(f'{title} - Orientation Match')
        fit_points = data.loc[data['deltaHeading'] < tolerance].copy()

        if len(variables) >= 3:
            fit_points['lon'] = fit_points['lon'] - variables[2]

        plt.plot(curve['lon'], curve['lat'])
        setChartXLimit(curve, plt)

        plt.scatter(fit_points['lon'], fit_points['lat'], alpha=0.3, color='green')

        plt.figure()
        plt.title(f'{title} - Stress Magnitude')
        plt.scatter(fit_points['pointNumber'], fit_points['stress'])

        print(np.array(variables))

    return data

def plot_time(data):
    timeData = data.copy()
    time = np.array(timeData['time'])
    time[time < 180] = time[time < 180] + 360
    timeData['time'] = time

    plt.figure()
    plt.scatter(timeData['pointNumber'], timeData['time'],s=1)
    plt.title("Time")

def analyze_fit(opt, curve, tolerance, name=''):
    plt.figure()
    plt.title('Optimizer Loss Values')
    plt.plot(opt[0])

    display(opt[1])
    display(opt[2])

    params = opt[1]['parameters']
    bestCase = check_fit(params, min_vals, max_vals, curve, interior, tolerance=tolerance,
                         title=f'{name} Best Fit')

    params = opt[2]['parameters']
    finalCase = check_fit(params, min_vals, max_vals, curve, interior, tolerance=tolerance,
                         title=f'{name} Final Fit')


    # Plot time progression
    plot_time(bestCase)

    return bestCase, finalCase

def analyze_params(params, curve, tolerance, name='', verbose=True, folder='./output/', suffix=''):
    fieldPath = path.join(folder, f'{name}{suffix}StressField.csv.gz')
    results = check_fit(params, min_vals, max_vals, curve, interior, tolerance=tolerance,
                       title=f'{name} Highest Probability Fit', verbose=verbose, path=fieldPath)

    if verbose:
        plot_time(results)

    return results

def direct_fit(curve, tolerance, show_plots=True, params=[0, 0, 0]):
    data, loss = fitting.match_stresses(curve, params, interior)
    fit_points = data.loc[data['deltaHeading'] < tolerance].copy()

    if show_plots:
        plt.figure()
        plt.plot(curve['lon'], curve['lat'])
        setChartXLimit(curve, plt)

        plt.scatter(fit_points['lon'], fit_points['lat'], alpha=0.3, color='green')
        plt.figure()
        plt.scatter(fit_points['pointNumber'], fit_points['stress'])

        plot_time(data)

    return data, loss

def process_cycloid(curve,
                    name,
                    paramCount = 2,
                    analysisCurve=None,
                    folder='./output/',
                    iterations=500,
                    constraints=tight_obliquity_contstraints,
                    verbose=True):

    logmessage(f'Processing Cycloid: {name}')
    plt.close('all')
    numParams = paramCount
    start_params = [np.random.rand() for iter in range(numParams)]
    start_params[1] = 0.67

    optimizer = fitting.Adam(alpha=0.05)

    opt = optimizer.minimize(
        fitting.test_stress_parameters,
        curve,
        start_params,
        interior,
        constraints=constraints,
        max_iterations=iterations,
        verbose=verbose,
        batch_size=16
    )

    params = fitting.find_best_parameters(opt)
    fullCurve = analysisCurve if analysisCurve is not None else curve
    
    logmessage(f'Analyzing optimization parameters for {name}')
    bestFit = analyze_params(np.array(params), fullCurve, 0.25, name, verbose, folder)

    # TODO: Handle dynamic parameter list
    cols = ['loss', 'phase', 'obliquity']
    if len(params) == 3:
        cols.append('longitude')
        
    df = pd.DataFrame(opt[3], columns=cols).copy()

    df['phase'] = df['phase'] * (max_vals[0] - min_vals[0]) + min_vals[0]
    df['obliquity'] = df['obliquity'] * (max_vals[1] - min_vals[1]) + min_vals[1]

    df.to_csv(f'{folder}{name}Fits.csv.gz', index=False, encoding='utf-8', compression='gzip')
    bestFit.to_csv(f'{folder}{name}BestFit.csv.gz', index=False, encoding='utf-8', compression='gzip')
    

def process_cycloid_top_fits(curve,
                    name,
                    paramCount = 2,
                    analysisCurve=None,
                    folder='./output/',
                    iterations=500,
                    constraints=constraints,
                    verbose=True,
                    number_of_fits=5):

    numParams = paramCount
    start_params = [np.random.rand() for iter in range(numParams)]
    start_params[1] = 0.67

    optimizer = fitting.Adam(alpha=0.05)

    opt = optimizer.minimize(
        fitting.test_stress_parameters,
        curve,
        start_params,
        interior,
        constraints=constraints,
        max_iterations=iterations,
        verbose=verbose,
        batch_size=16
    )

    cols = ['loss', 'phase', 'obliquity']
    if paramCount == 3:
        cols.append('longitude')
    fitFrame = pd.DataFrame(opt[3],
                            columns=cols).sort_values('loss')[0:number_of_fits]
    fitFrame['FitNumber'] = range(1, number_of_fits + 1)

    fullCurve = analysisCurve if analysisCurve is not None else curve

    for fit in fitFrame.itertuples():
        params = [fit.phase, fit.obliquity]
        if paramCount == 3:
            params.append(fit.longitude)
        bestFit = analyze_params(np.array(params),
                                 fullCurve,
                                 0.25,
                                 name,
                                 verbose,
                                 folder,
                                 suffix=fit.FitNumber)
        bestFit.to_csv(f'{folder}{name}BestFit{fit.FitNumber}.csv.gz',
                       index=False, encoding='utf-8', compression='gzip')

    df = pd.DataFrame(opt[3], columns=cols).copy()

    df['phase'] = df['phase'] * (max_vals[0] - min_vals[0]) + min_vals[0]
    df['obliquity'] = df['obliquity'] * (max_vals[1] - min_vals[1]) + min_vals[1]
    if paramCount == 3:
        df['longitude'] = df['longitude'] * (max_vals[2] - min_vals[2]) + min_vals[2]

    df.to_csv(f'{folder}{name}Fits.csv.gz', index=False, encoding='utf-8', compression='gzip')

    
def process_cycloid_by_name(name, folder='./output/', iterations=3000, constraints=constraints, verbose=False, paramCount=2):
    process_cycloid(cycloids[name].curve,
                    name,
                    analysisCurve=highResCycloids[name].curve,
                    folder=folder,
                    iterations=iterations,
                    constraints=constraints,
                    verbose=verbose,
                    paramCount=paramCount)

# %% [markdown]
# ## Generate Cyloid Data in Full Obliquity Range

# %%
for key in cycloids:
    process_cycloid_by_name(key, 
                            iterations=2000,
                            folder='./output/fullObliquityRange/',
                            verbose=False)
# Out:
# [15:05:10] Processing Cycloid: alex
# Iteration 150/2000 -- Loss Output: 1.4412968280813365 -- Moving Avg Loss: 3.187500242991867
# 	Parameters used: [0.64034691 0.48889579]
# Iteration 300/2000 -- Loss Output: 0.06872068050246764 -- Moving Avg Loss: 0.07524279631654662
# 	Parameters used: [0.71643325 0.56122124]
# Iteration 450/2000 -- Loss Output: 0.06574918896083055 -- Moving Avg Loss: 0.062303407176191684
# 	Parameters used: [0.75027096 0.59339873]
# Iteration 600/2000 -- Loss Output: 11.010938307460401 -- Moving Avg Loss: 1.9546183074555403
# 	Parameters used: [0.01947357 0.8509783 ]
# Iteration 750/2000 -- Loss Output: 0.06192930258936101 -- Moving Avg Loss: 0.059950053225756424
# 	Parameters used: [0.78400875 0.88523679]
# Iteration 900/2000 -- Loss Output: 15.01961276388642 -- Moving Avg Loss: 7.748228653643021
# 	Parameters used: [0.37353927 0.50402265]
# Iteration 1050/2000 -- Loss Output: 0.06493183854299693 -- Moving Avg Loss: 0.06120119246017501
# 	Parameters used: [0.79175633 0.90334334]
# Iteration 1200/2000 -- Loss Output: 0.04844707950813006 -- Moving Avg Loss: 0.07039924546356648
# 	Parameters used: [0.83792483 0.94741148]
# Iteration 1350/2000 -- Loss Output: 0.09912574352653356 -- Moving Avg Loss: 0.09790338641381258
# 	Parameters used: [0.88538272 0.9927104 ]
# Iteration 1500/2000 -- Loss Output: 0.05920743417594072 -- Moving Avg Loss: 0.2126826679056956
# 	Parameters used: [0.82411465 0.51413054]
# Iteration 1650/2000 -- Loss Output: 0.06914820881569456 -- Moving Avg Loss: 0.06252969707472089
# 	Parameters used: [0.80697702 0.7121744 ]
# Iteration 1800/2000 -- Loss Output: 0.08583895865638597 -- Moving Avg Loss: 0.08224864942229188
# 	Parameters used: [0.86733751 0.7704398 ]
# Iteration 1950/2000 -- Loss Output: 1.4281999385712496 -- Moving Avg Loss: 9.459544122463688
# 	Parameters used: [0.58807066 0.74049439]
# [15:07:50] Analyzing optimization parameters for alex
# [15:08:04] Processing Cycloid: carly
# Iteration 150/2000 -- Loss Output: 11.23061582744274 -- Moving Avg Loss: 3.716629787322361
# 	Parameters used: [0.74915552 0.63321877]
# Iteration 300/2000 -- Loss Output: 2.436453113603435 -- Moving Avg Loss: 1.3107588889058719
# 	Parameters used: [0.41992758 0.1449758 ]
# Iteration 450/2000 -- Loss Output: 0.17969000657971423 -- Moving Avg Loss: 0.33562011911006123
# 	Parameters used: [0.11982881 0.49342832]
# Iteration 600/2000 -- Loss Output: 4.156349967921515 -- Moving Avg Loss: 5.5681449422445874
# 	Parameters used: [0.5594632  0.32677572]
# Iteration 750/2000 -- Loss Output: 4.327277583887864 -- Moving Avg Loss: 1.241700830736676
# 	Parameters used: [0.32705812 0.09535192]
# Iteration 900/2000 -- Loss Output: 1.9598003661900834 -- Moving Avg Loss: 1.5065101941446957
# 	Parameters used: [0.34916321 0.10939909]
# Iteration 1050/2000 -- Loss Output: 0.10338450440447013 -- Moving Avg Loss: 0.5657245034541479
# 	Parameters used: [0.18384013 0.24945844]
# Iteration 1200/2000 -- Loss Output: 0.8383538208347526 -- Moving Avg Loss: 1.545180422635386
# 	Parameters used: [0.94740534 0.01382662]
# Iteration 1350/2000 -- Loss Output: 2.4270962470996733 -- Moving Avg Loss: 3.136158582064433
# 	Parameters used: [0.50389074 0.17108578]
# Iteration 1500/2000 -- Loss Output: 0.6543680502019735 -- Moving Avg Loss: 1.895312844324986
# 	Parameters used: [0.38684544 0.21960295]
# Iteration 1650/2000 -- Loss Output: 0.12822297435151211 -- Moving Avg Loss: 0.8390960454778857
# 	Parameters used: [0.25576818 0.08882593]
# Iteration 1800/2000 -- Loss Output: 0.39828527904183814 -- Moving Avg Loss: 0.4000664175059145
# 	Parameters used: [0.09424502 0.67791016]
# Iteration 1950/2000 -- Loss Output: 3.106931465505343 -- Moving Avg Loss: 1.947821941333553
# 	Parameters used: [0.38001859 0.01529303]
# [15:10:52] Analyzing optimization parameters for carly
# [15:11:16] Processing Cycloid: cilicia
# Iteration 150/2000 -- Loss Output: 0.10654696580229564 -- Moving Avg Loss: 0.09509554765977869
# 	Parameters used: [0.53778564 0.39181333]
# Iteration 300/2000 -- Loss Output: 0.1015577976190228 -- Moving Avg Loss: 0.09315211920095282
# 	Parameters used: [0.55935256 0.41313262]
# Iteration 450/2000 -- Loss Output: 0.08769176714315212 -- Moving Avg Loss: 0.0905202162982438
# 	Parameters used: [0.58806271 0.44151313]
# Iteration 600/2000 -- Loss Output: 0.0886668169695148 -- Moving Avg Loss: 0.08158021502053822
# 	Parameters used: [0.61382613 0.46698075]
# Iteration 750/2000 -- Loss Output: 0.07781478748675327 -- Moving Avg Loss: 0.08186998269754911
# 	Parameters used: [0.70110152 0.5532571 ]
# Iteration 900/2000 -- Loss Output: 0.06595195924126532 -- Moving Avg Loss: 0.07331918727685058
# 	Parameters used: [0.74036662 0.59207222]
# Iteration 1050/2000 -- Loss Output: 0.06994450020581088 -- Moving Avg Loss: 0.07918299825645912
# 	Parameters used: [0.91344044 0.76317049]
# Iteration 1200/2000 -- Loss Output: 0.08241894022029314 -- Moving Avg Loss: 0.08153467341742568
# 	Parameters used: [0.94521593 0.79458312]
# Iteration 1350/2000 -- Loss Output: 0.08522680525078223 -- Moving Avg Loss: 0.08590389491244395
# 	Parameters used: [0.98962065 0.83848079]
# Iteration 1500/2000 -- Loss Output: 0.10067823083243535 -- Moving Avg Loss: 0.09731979118852417
# 	Parameters used: [0.04821929 0.89644488]
# Iteration 1650/2000 -- Loss Output: 0.07983870092929887 -- Moving Avg Loss: 0.09529090512160049
# 	Parameters used: [0.37453715 0.54630328]
# Iteration 1800/2000 -- Loss Output: 0.05696269094124632 -- Moving Avg Loss: 0.09845556121787849
# 	Parameters used: [0.4416833 0.6126909]
# Iteration 1950/2000 -- Loss Output: 0.07632263451945319 -- Moving Avg Loss: 0.10384777310244253
# 	Parameters used: [0.50261275 0.67293206]
# [15:14:18] Analyzing optimization parameters for cilicia
# [15:14:47] Processing Cycloid: delphi
# Iteration 150/2000 -- Loss Output: 0.10220011793121025 -- Moving Avg Loss: 0.07264086171727449
# 	Parameters used: [0.48365353 0.07871404]
# Iteration 300/2000 -- Loss Output: 0.07606665881917965 -- Moving Avg Loss: 0.07958421766560907
# 	Parameters used: [0.09270045 0.2214861 ]
# Iteration 450/2000 -- Loss Output: 0.07481201737558811 -- Moving Avg Loss: 0.07516478136265153
# 	Parameters used: [0.30770077 0.52677174]
# Iteration 600/2000 -- Loss Output: 0.08754300732477205 -- Moving Avg Loss: 0.0750362330987692
# 	Parameters used: [0.80642218 0.43412421]
# Iteration 750/2000 -- Loss Output: 0.07971489445959429 -- Moving Avg Loss: 0.07551428440000485
# 	Parameters used: [0.83652003 0.24236319]
# Iteration 900/2000 -- Loss Output: 0.06460589123591313 -- Moving Avg Loss: 0.07301476947249218
# 	Parameters used: [0.49125395 0.1571133 ]
# Iteration 1050/2000 -- Loss Output: 0.09241465400011065 -- Moving Avg Loss: 0.07874020872051037
# 	Parameters used: [0.1130361  0.73931771]
# Iteration 1200/2000 -- Loss Output: 0.09312701047930548 -- Moving Avg Loss: 0.07452828925454656
# 	Parameters used: [0.87036947 0.67180477]
# Iteration 1350/2000 -- Loss Output: 0.06212079488781638 -- Moving Avg Loss: 0.06956886561669369
# 	Parameters used: [0.49707521 0.1618464 ]
# Iteration 1500/2000 -- Loss Output: 0.0872128825590954 -- Moving Avg Loss: 0.08021262055825698
# 	Parameters used: [0.93438246 0.88741504]
# Iteration 1650/2000 -- Loss Output: 0.061261949575163975 -- Moving Avg Loss: 0.06978596530843294
# 	Parameters used: [0.6680045  0.95862705]
# Iteration 1800/2000 -- Loss Output: 0.05129994574111503 -- Moving Avg Loss: 0.07413494338721713
# 	Parameters used: [0.77355125 0.38241095]
# Iteration 1950/2000 -- Loss Output: 0.06820218940268989 -- Moving Avg Loss: 0.07483152292012338
# 	Parameters used: [0.06306654 0.09429312]
# [15:17:48] Analyzing optimization parameters for delphi
# [15:18:12] Processing Cycloid: dirk
# Iteration 150/2000 -- Loss Output: 0.11072301365809016 -- Moving Avg Loss: 0.21006257015566931
# 	Parameters used: [0.41035324 0.65645479]
# Iteration 300/2000 -- Loss Output: 0.05273185935961599 -- Moving Avg Loss: 0.2755162246721979
# 	Parameters used: [0.43531415 0.74265608]
# Iteration 450/2000 -- Loss Output: 0.11332932071465336 -- Moving Avg Loss: 7.6646408423401375
# 	Parameters used: [0.20389157 0.57544137]
# Iteration 600/2000 -- Loss Output: 0.2010080377215447 -- Moving Avg Loss: 7.701359326148516
# 	Parameters used: [0.33762476 0.03016573]
# Iteration 750/2000 -- Loss Output: 0.06074555518852341 -- Moving Avg Loss: 0.06261360993651868
# 	Parameters used: [0.3141369  0.68104185]
# Iteration 900/2000 -- Loss Output: 0.06967562745783475 -- Moving Avg Loss: 0.10344535726023942
# 	Parameters used: [0.38147044 0.7477883 ]
# Iteration 1050/2000 -- Loss Output: 4.026411836501461 -- Moving Avg Loss: 15.431213881048192
# 	Parameters used: [0.06615253 0.59195613]
# Iteration 1200/2000 -- Loss Output: 0.06965604508195589 -- Moving Avg Loss: 0.050923911026500575
# 	Parameters used: [0.3164234  0.84497708]
# Iteration 1350/2000 -- Loss Output: 0.0474471582527316 -- Moving Avg Loss: 0.05529347253051044
# 	Parameters used: [0.37014702 0.89824173]
# Iteration 1500/2000 -- Loss Output: 0.43323243015753743 -- Moving Avg Loss: 0.2919571469889116
# 	Parameters used: [0.46694809 0.994216  ]
# Iteration 1650/2000 -- Loss Output: 0.09560350807497903 -- Moving Avg Loss: 0.5643541038873843
# 	Parameters used: [0.43254025 0.47538147]
# Iteration 1800/2000 -- Loss Output: 15.166993992955327 -- Moving Avg Loss: 3.1415052099570118
# 	Parameters used: [0.58995736 0.58166375]
# Iteration 1950/2000 -- Loss Output: 20.48743242256944 -- Moving Avg Loss: 12.568007180128362
# 	Parameters used: [0.02108204 0.72204772]
# [15:21:27] Analyzing optimization parameters for dirk
# [15:21:57] Processing Cycloid: mira
# Iteration 150/2000 -- Loss Output: 5.496586135348115 -- Moving Avg Loss: 7.949383001825307
# 	Parameters used: [0.96726144 0.0973134 ]
# Iteration 300/2000 -- Loss Output: 8.904071507795683 -- Moving Avg Loss: 8.667380439972888
# 	Parameters used: [0.15461112 0.09471087]
# Iteration 450/2000 -- Loss Output: 17.182135394486856 -- Moving Avg Loss: 15.15611999470584
# 	Parameters used: [0.81340477 0.0039711 ]
# Iteration 600/2000 -- Loss Output: 15.732616991072296 -- Moving Avg Loss: 15.020052022768459
# 	Parameters used: [0.78864028 0.21284093]
# Iteration 750/2000 -- Loss Output: 20.97492218260658 -- Moving Avg Loss: 14.198108813905067
# 	Parameters used: [0.86294767 0.07334035]
# Iteration 900/2000 -- Loss Output: 7.422703264059685 -- Moving Avg Loss: 11.858067193669854
# 	Parameters used: [0.31580104 0.00460437]
# Iteration 1050/2000 -- Loss Output: 9.990201501703362 -- Moving Avg Loss: 13.838669314326685
# 	Parameters used: [0.95378574 0.16886352]
# Iteration 1200/2000 -- Loss Output: 10.127454252394537 -- Moving Avg Loss: 14.600536335288528
# 	Parameters used: [0.83047132 0.14595336]
# Iteration 1350/2000 -- Loss Output: 14.52397326599747 -- Moving Avg Loss: 13.389588178623058
# 	Parameters used: [0.51230312 0.033898  ]
# Iteration 1500/2000 -- Loss Output: 21.37216360097427 -- Moving Avg Loss: 15.430380182370046
# 	Parameters used: [0.7209659  0.03740496]
# Iteration 1650/2000 -- Loss Output: 13.055715743020036 -- Moving Avg Loss: 7.963016286752251
# 	Parameters used: [0.19999299 0.19623457]
# Iteration 1800/2000 -- Loss Output: 14.08631898136702 -- Moving Avg Loss: 14.83774096979808
# 	Parameters used: [0.69413195 0.09526686]
# Iteration 1950/2000 -- Loss Output: 14.84105810995823 -- Moving Avg Loss: 10.725625262163142
# 	Parameters used: [0.69948496 0.29049035]
# [15:24:57] Analyzing optimization parameters for mira
# [15:25:22] Processing Cycloid: odessa
# Iteration 150/2000 -- Loss Output: 0.17723583500157425 -- Moving Avg Loss: 5.052684399013872
# 	Parameters used: [0.46426252 0.59718086]
# Iteration 300/2000 -- Loss Output: 8.790298426840247 -- Moving Avg Loss: 2.93128613037262
# 	Parameters used: [0.00638705 0.67612617]
# Iteration 450/2000 -- Loss Output: 0.057821036927310755 -- Moving Avg Loss: 5.873658983310163
# 	Parameters used: [0.45615195 0.64904558]
# Iteration 600/2000 -- Loss Output: 4.660135942235842 -- Moving Avg Loss: 4.3991110234832975
# 	Parameters used: [0.72841902 0.54906908]
# Iteration 750/2000 -- Loss Output: 0.05239345156439622 -- Moving Avg Loss: 3.649281707384041
# 	Parameters used: [0.35986633 0.77391311]
# Iteration 900/2000 -- Loss Output: 6.680703662150431 -- Moving Avg Loss: 6.0733108401628035
# 	Parameters used: [0.63881798 0.71057883]
# Iteration 1050/2000 -- Loss Output: 0.07083754052108121 -- Moving Avg Loss: 1.1940777675387535
# 	Parameters used: [0.21294461 0.82858488]
# Iteration 1200/2000 -- Loss Output: 1.4639258803704085 -- Moving Avg Loss: 3.790947923418342
# 	Parameters used: [0.26592124 0.17536674]
# Iteration 1350/2000 -- Loss Output: 0.04322679752249995 -- Moving Avg Loss: 0.09140865019884556
# 	Parameters used: [0.28866119 0.47284662]
# Iteration 1500/2000 -- Loss Output: 0.9045660761653397 -- Moving Avg Loss: 1.7510013898946568
# 	Parameters used: [0.31440485 0.21981479]
# Iteration 1650/2000 -- Loss Output: 0.4556804560184428 -- Moving Avg Loss: 2.4992545619645545
# 	Parameters used: [0.21129851 0.52672194]
# Iteration 1800/2000 -- Loss Output: 2.3533182855122923 -- Moving Avg Loss: 4.438216911560625
# 	Parameters used: [0.61426888 0.31882336]
# Iteration 1950/2000 -- Loss Output: 0.05382093324812868 -- Moving Avg Loss: 0.04656314095727296
# 	Parameters used: [0.2463821  0.80558326]
# [15:28:03] Analyzing optimization parameters for odessa
# [15:28:23] Processing Cycloid: sidon
# Iteration 150/2000 -- Loss Output: 0.07577395596204989 -- Moving Avg Loss: 0.07889085676402882
# 	Parameters used: [0.93324795 0.85077932]
# Iteration 300/2000 -- Loss Output: 0.058643496023813226 -- Moving Avg Loss: 0.1174903940495353
# 	Parameters used: [0.71418336 0.81625459]
# Iteration 450/2000 -- Loss Output: 0.07889395340962171 -- Moving Avg Loss: 0.08182829256511842
# 	Parameters used: [0.86970216 0.99879091]
# Iteration 600/2000 -- Loss Output: 0.06776980511720672 -- Moving Avg Loss: 0.07950543182054241
# 	Parameters used: [0.23623138 0.45440443]
# Iteration 750/2000 -- Loss Output: 0.08536246190964959 -- Moving Avg Loss: 0.3289767503433009
# 	Parameters used: [0.87739511 0.58903573]
# Iteration 900/2000 -- Loss Output: 0.09721570009013629 -- Moving Avg Loss: 0.08547891999956957
# 	Parameters used: [0.4450479  0.46037777]
# Iteration 1050/2000 -- Loss Output: 0.08529876711978354 -- Moving Avg Loss: 0.08705945091039353
# 	Parameters used: [0.1511908  0.72623233]
# Iteration 1200/2000 -- Loss Output: 0.06940976217164468 -- Moving Avg Loss: 0.07041710499679704
# 	Parameters used: [0.05205183 0.14806133]
# Iteration 1350/2000 -- Loss Output: 0.07806172544197877 -- Moving Avg Loss: 0.07924484526293814
# 	Parameters used: [0.68708688 0.78076017]
# Iteration 1500/2000 -- Loss Output: 0.13084170634624687 -- Moving Avg Loss: 0.09372205761751622
# 	Parameters used: [0.36320381 0.90509757]
# Iteration 1650/2000 -- Loss Output: 0.0844936501368946 -- Moving Avg Loss: 0.09503882010834715
# 	Parameters used: [0.1909042 0.725795 ]
# Iteration 1800/2000 -- Loss Output: 0.08179468103639566 -- Moving Avg Loss: 0.07325633718099533
# 	Parameters used: [0.92270073 0.50966708]
# Iteration 1950/2000 -- Loss Output: 0.07044073298176012 -- Moving Avg Loss: 0.07455967805811835
# 	Parameters used: [0.65130856 0.4566928 ]
# [15:31:40] Analyzing optimization parameters for sidon
# [15:32:24] Processing Cycloid: tyrrel
# Iteration 150/2000 -- Loss Output: 1.3949414333277033 -- Moving Avg Loss: 9.658615871535659
# 	Parameters used: [0.06171995 0.93439683]
# Iteration 300/2000 -- Loss Output: 7.828144841277824 -- Moving Avg Loss: 10.340336631481835
# 	Parameters used: [0.0508228  0.84095573]
# Iteration 450/2000 -- Loss Output: 11.403883562108636 -- Moving Avg Loss: 11.165949752065979
# 	Parameters used: [0.89257049 0.68151919]
# Iteration 600/2000 -- Loss Output: 8.276592482974372 -- Moving Avg Loss: 10.379702659032105
# 	Parameters used: [0.79367236 0.9150188 ]
# Iteration 750/2000 -- Loss Output: 1.9185132969950889 -- Moving Avg Loss: 2.7405659461754612
# 	Parameters used: [0.20293372 0.74361747]
# Iteration 900/2000 -- Loss Output: 3.930552344809177 -- Moving Avg Loss: 2.806753681644876
# 	Parameters used: [0.21657602 0.73810888]
# Iteration 1050/2000 -- Loss Output: 1.9740587367608489 -- Moving Avg Loss: 6.268949958791373
# 	Parameters used: [0.06652069 0.6743693 ]
# Iteration 1200/2000 -- Loss Output: 14.534758593118138 -- Moving Avg Loss: 11.061470397223209
# 	Parameters used: [0.56032934 0.64816025]
# Iteration 1350/2000 -- Loss Output: 4.239966347358536 -- Moving Avg Loss: 8.297395244979771
# 	Parameters used: [0.06836214 0.69879346]
# Iteration 1500/2000 -- Loss Output: 0.12265097278867809 -- Moving Avg Loss: 2.483542314511175
# 	Parameters used: [0.21126942 0.86699577]
# Iteration 1650/2000 -- Loss Output: 8.397972182865356 -- Moving Avg Loss: 10.658865279493043
# 	Parameters used: [0.95706158 0.78186466]
# Iteration 1800/2000 -- Loss Output: 5.50755094938804 -- Moving Avg Loss: 10.12453154977086
# 	Parameters used: [0.09681886 0.14251414]
# Iteration 1950/2000 -- Loss Output: 7.10032685088236 -- Moving Avg Loss: 5.31027726840543
# 	Parameters used: [0.17802265 0.39984934]
# [15:35:53] Analyzing optimization parameters for tyrrel
# [15:36:37] Processing Cycloid: yaphet
# Iteration 150/2000 -- Loss Output: 6.0012031895988205 -- Moving Avg Loss: 3.4337894460094374
# 	Parameters used: [0.6917503  0.07844312]
# Iteration 300/2000 -- Loss Output: 1.914511203175434 -- Moving Avg Loss: 2.6276537795899033
# 	Parameters used: [0.45524203 0.88933671]
# Iteration 450/2000 -- Loss Output: 9.59306096705395 -- Moving Avg Loss: 3.4405390173463997
# 	Parameters used: [0.59119527 0.39701839]
# Iteration 600/2000 -- Loss Output: 0.06216118739451971 -- Moving Avg Loss: 0.09720005645041904
# 	Parameters used: [0.07837492 0.88774687]
# Iteration 750/2000 -- Loss Output: 0.06843032600270194 -- Moving Avg Loss: 0.06152275145507053
# 	Parameters used: [0.14620828 0.95607455]
# Iteration 900/2000 -- Loss Output: 1.281017996147527 -- Moving Avg Loss: 0.922601937862801
# 	Parameters used: [0.26187925 0.26722295]
# Iteration 1050/2000 -- Loss Output: 0.08608523856347539 -- Moving Avg Loss: 0.08967340053686586
# 	Parameters used: [0.06960436 0.49274685]
# Iteration 1200/2000 -- Loss Output: 0.05963490572587706 -- Moving Avg Loss: 0.10374597596947735
# 	Parameters used: [0.13821317 0.56183549]
# Iteration 1350/2000 -- Loss Output: 0.058884810209252854 -- Moving Avg Loss: 0.20251098235293946
# 	Parameters used: [0.19224846 0.61624869]
# Iteration 1500/2000 -- Loss Output: 5.001534854401065 -- Moving Avg Loss: 12.585325511505062
# 	Parameters used: [0.94132097 0.45650542]
# Iteration 1650/2000 -- Loss Output: 0.05786984654288696 -- Moving Avg Loss: 0.06626420525328645
# 	Parameters used: [0.19572975 0.9070312 ]
# Iteration 1800/2000 -- Loss Output: 15.49305352459181 -- Moving Avg Loss: 7.118722801045163
# 	Parameters used: [0.79904659 0.81599272]
# Iteration 1950/2000 -- Loss Output: 0.050988580409843796 -- Moving Avg Loss: 0.07064589239233925
# 	Parameters used: [0.11214521 0.54085597]
# [15:39:36] Analyzing optimization parameters for yaphet

# %% [markdown]
# ## Non-Optimized Fits
#
# * 0.25 Deg Obliquity
# * Phases 0, 60, 120, 180, 240 and 300 degrees

# %%
losses = []
folder = './output/lockedFits/'

OBLIQUITY = 0.25
phases = [0, 60, 120, 180, 240, 300]

for current in cycloids:
    for phase in phases:
        print(f'Processing phase {phase}')
        data, loss = direct_fit(cycloids[current].curve, 
                                0.25, 
                                show_plots=False, 
                                params=[phase, OBLIQUITY, 0])

        losses.append(dict(cycloid=current, loss=loss, phase=phase))
        print(current,'\t-', loss)

        filename = f'{folder}{current}-phase{phase}.csv.gz'
        data.to_csv(filename, index=False, compression='gzip')

lossFrame = pd.DataFrame(losses)
filename = f'{folder}Losses.csv'
lossFrame.to_csv(filename, index=False)
# Out:
# Processing phase 0
# alex 	- 1.101083245680132
# Processing phase 60
# alex 	- 1.4971956846431838
# Processing phase 120
# alex 	- 0.6598343140300722
# Processing phase 180
# alex 	- 0.7702316207406991
# Processing phase 240
# alex 	- 0.43309652602466875
# Processing phase 300
# alex 	- 0.5071788920359364
# Processing phase 0
# carly 	- 0.35328613497182065
# Processing phase 60
# carly 	- 0.21267623114570441
# Processing phase 120
# carly 	- 0.24922552695109376
# Processing phase 180
# carly 	- 0.538335195440918
# Processing phase 240
# carly 	- 0.8777948253803868
# Processing phase 300
# carly 	- 1.8209416009303054
# Processing phase 0
# cilicia 	- 0.012293092595647051
# Processing phase 60
# cilicia 	- 0.01239612808496264
# Processing phase 120
# cilicia 	- 0.012877744702335128
# Processing phase 180
# cilicia 	- 0.013864483392336313
# Processing phase 240
# cilicia 	- 0.011287991762470551
# Processing phase 300
# cilicia 	- 0.011243036088465809
# Processing phase 0
# delphi 	- 0.013205383710725268
# Processing phase 60
# delphi 	- 0.013160345707482517
# Processing phase 120
# delphi 	- 0.013290890297907173
# Processing phase 180
# delphi 	- 0.013202676538413973
# Processing phase 240
# delphi 	- 0.013055121880552807
# Processing phase 300
# delphi 	- 0.012797128595729282
# Processing phase 0
# dirk 	- 3.367056706039251
# Processing phase 60
# dirk 	- 0.13759690896666923
# Processing phase 120
# dirk 	- 0.13875360288581387
# Processing phase 180
# dirk 	- 0.29411201474848647
# Processing phase 240
# dirk 	- 3.7767413826847687
# Processing phase 300
# dirk 	- 3.555025822716339
# Processing phase 0
# mira 	- 2.6679100870698123
# Processing phase 60
# mira 	- 1.9692835740267005
# Processing phase 120
# mira 	- 1.67811873404682
# Processing phase 180
# mira 	- 1.9586866427318785
# Processing phase 240
# mira 	- 2.4311884007706746
# Processing phase 300
# mira 	- 2.783880687854297
# Processing phase 0
# odessa 	- 1.0922006276311136
# Processing phase 60
# odessa 	- 0.6148629598184023
# Processing phase 120
# odessa 	- 0.2752575560511966
# Processing phase 180
# odessa 	- 0.3628690153326097
# Processing phase 240
# odessa 	- 0.7069418095555955
# Processing phase 300
# odessa 	- 1.0604877439998193
# Processing phase 0
# sidon 	- 0.009706054836317824
# Processing phase 60
# sidon 	- 0.009639118896826893
# Processing phase 120
# sidon 	- 0.01103232963957045
# Processing phase 180
# sidon 	- 0.010145938961389824
# Processing phase 240
# sidon 	- 0.009964654452619149
# Processing phase 300
# sidon 	- 0.010255636306789126
# Processing phase 0
# tyrrel 	- 0.5455693964540093
# Processing phase 60
# tyrrel 	- 0.793646033010145
# Processing phase 120
# tyrrel 	- 1.105389083382538
# Processing phase 180
# tyrrel 	- 1.0614500016325699
# Processing phase 240
# tyrrel 	- 1.6913946028194555
# Processing phase 300
# tyrrel 	- 1.6105589566565115
# Processing phase 0
# yaphet 	- 0.0986318751726185
# Processing phase 60
# yaphet 	- 0.14652338122268518
# Processing phase 120
# yaphet 	- 0.3116822921627202
# Processing phase 180
# yaphet 	- 0.365706642595349
# Processing phase 240
# yaphet 	- 1.8113313971266873
# Processing phase 300
# yaphet 	- 1.3333428185154181

# %% [markdown]
# ## Direct Fits (no phase or obliquity) for all cycloids

# %%
losses = []
folder = './output/directFits/'

for current in cycloids:
    data, loss = direct_fit(cycloids[current].curve, 0.25, show_plots=False)

    losses.append(dict(cycloid=current, loss=loss))
    print(current,'\t-', loss)

    filename = f'{folder}{current}.csv.gz'
    data.to_csv(filename, index=False, compression='gzip')

lossFrame = pd.DataFrame(losses)
filename = f'{folder}directLosses.csv'
lossFrame.to_csv(filename, index=False)
# Out:
# alex 	- 0.90675499538864
# carly 	- 0.4679169956204177
# cilicia 	- 0.011850136742198897
# delphi 	- 0.01290892547457404
# dirk 	- 2.1386070161654858
# mira 	- 2.261342358536797
# odessa 	- 0.6678619449895173
# sidon 	- 0.010174794559418736
# tyrrel 	- 0.8524575485454637
# yaphet 	- 0.21000699087411415

# %% [markdown]
# ## Fits with Tight Obliquity

# %%
for cycloid in cycloids:
    process_cycloid_top_fits(cycloids[cycloid].curve,
                             cycloid,
                             folder='./output/tightObliquity/',
                             iterations=2000,
                             constraints=tight_obliquity_contstraints,
                             number_of_fits=5,
                             paramCount=2,
                             verbose=False
                            )
# Out:
# Iteration 150/2000 -- Loss Output: 8.028798871030212 -- Moving Avg Loss: 7.161403804839364
# 	Parameters used: [0.03865885 0.64632175]
# Iteration 300/2000 -- Loss Output: 0.0849318188792649 -- Moving Avg Loss: 0.2742772959311655
# 	Parameters used: [0.64213435 0.6557327 ]
# Iteration 450/2000 -- Loss Output: 0.07604066554203465 -- Moving Avg Loss: 0.2056619535944901
# 	Parameters used: [0.63431565 0.75516557]
# Iteration 600/2000 -- Loss Output: 0.06912360607798695 -- Moving Avg Loss: 0.2669931409451784
# 	Parameters used: [0.64196153 0.67627278]
# Iteration 750/2000 -- Loss Output: 0.0702255251940562 -- Moving Avg Loss: 0.1583508998035677
# 	Parameters used: [0.63486726 0.73519788]
# Iteration 900/2000 -- Loss Output: 0.09585557062183099 -- Moving Avg Loss: 6.030047399311965
# 	Parameters used: [0.80287311 0.67053078]
# Iteration 1050/2000 -- Loss Output: 0.11422449818758477 -- Moving Avg Loss: 0.24389000835591115
# 	Parameters used: [0.63916597 0.64868204]
# Iteration 1200/2000 -- Loss Output: 0.0502840233915232 -- Moving Avg Loss: 0.11577216313404477
# 	Parameters used: [0.68508321 0.77203006]
# Iteration 1350/2000 -- Loss Output: 0.1458025123499469 -- Moving Avg Loss: 0.7063280314109928
# 	Parameters used: [0.57327054 0.81245998]
# Iteration 1500/2000 -- Loss Output: 0.05924781799465755 -- Moving Avg Loss: 6.442455815946704
# 	Parameters used: [0.81084692 0.75360419]
# Iteration 1650/2000 -- Loss Output: 15.872614462538083 -- Moving Avg Loss: 1.1080538398540702
# 	Parameters used: [0.459207   0.67795413]
# Iteration 1800/2000 -- Loss Output: 0.06800108338904931 -- Moving Avg Loss: 0.07568591460883796
# 	Parameters used: [0.8476071  0.68203726]
# Iteration 1950/2000 -- Loss Output: 0.08131466110392915 -- Moving Avg Loss: 0.06926504143727971
# 	Parameters used: [0.82634517 0.70310745]
# Iteration 150/2000 -- Loss Output: 0.06416516262864846 -- Moving Avg Loss: 5.612962873707554
# 	Parameters used: [0.30876022 0.7275134 ]
# Iteration 300/2000 -- Loss Output: 0.04164729038151677 -- Moving Avg Loss: 0.06939320098922469
# 	Parameters used: [0.37991986 0.80676652]
# Iteration 450/2000 -- Loss Output: 7.810575540868005 -- Moving Avg Loss: 3.148433092407436
# 	Parameters used: [0.73108189 0.79569634]
# Iteration 600/2000 -- Loss Output: 0.7557137680598418 -- Moving Avg Loss: 0.20970057647871576
# 	Parameters used: [0.41318542 0.78401158]
# Iteration 750/2000 -- Loss Output: 0.04249481580503071 -- Moving Avg Loss: 0.12424412668270036
# 	Parameters used: [0.37388537 0.71832449]
# Iteration 900/2000 -- Loss Output: 0.031401043305623474 -- Moving Avg Loss: 0.05419118164661536
# 	Parameters used: [0.35769118 0.78668958]
# Iteration 1050/2000 -- Loss Output: 0.08704779411138895 -- Moving Avg Loss: 8.866195487719956
# 	Parameters used: [0.15369347 0.81003225]
# Iteration 1200/2000 -- Loss Output: 0.07713288334891022 -- Moving Avg Loss: 0.07048748175142494
# 	Parameters used: [0.22112607 0.80504917]
# Iteration 1350/2000 -- Loss Output: 0.0573386458422669 -- Moving Avg Loss: 0.06183926234174284
# 	Parameters used: [0.24049414 0.81626376]
# Iteration 1500/2000 -- Loss Output: 0.04177891311461129 -- Moving Avg Loss: 0.05898692021512314
# 	Parameters used: [0.26916012 0.77642528]
# Iteration 1650/2000 -- Loss Output: 0.060566420849585564 -- Moving Avg Loss: 0.052624718942025445
# 	Parameters used: [0.29595826 0.79194225]
# Iteration 1800/2000 -- Loss Output: 0.035686524336284435 -- Moving Avg Loss: 0.05113829539242528
# 	Parameters used: [0.31193792 0.80119498]
# Iteration 1950/2000 -- Loss Output: 0.04751669857023694 -- Moving Avg Loss: 0.04925323892567451
# 	Parameters used: [0.33206889 0.81285147]
# Iteration 150/2000 -- Loss Output: 0.07867666269394265 -- Moving Avg Loss: 0.3976671899897134
# 	Parameters used: [0.674597   0.65322978]
# Iteration 300/2000 -- Loss Output: 0.08215218126022128 -- Moving Avg Loss: 0.08967899023631799
# 	Parameters used: [0.72978272 0.80420259]
# Iteration 450/2000 -- Loss Output: 0.09379083903822201 -- Moving Avg Loss: 0.6811303138444117
# 	Parameters used: [0.06096907 0.76785105]
# Iteration 600/2000 -- Loss Output: 0.08940040255042798 -- Moving Avg Loss: 0.09975215658888803
# 	Parameters used: [0.11843963 0.67332612]
# Iteration 750/2000 -- Loss Output: 0.10449017593938911 -- Moving Avg Loss: 0.07668335591442094
# 	Parameters used: [0.84781282 0.76807484]
# Iteration 900/2000 -- Loss Output: 0.3584232913596568 -- Moving Avg Loss: 0.7287421589386721
# 	Parameters used: [0.18263999 0.80896873]
# Iteration 1050/2000 -- Loss Output: 0.10160157766868957 -- Moving Avg Loss: 0.09518483066202967
# 	Parameters used: [0.56536716 0.77450846]
# Iteration 1200/2000 -- Loss Output: 0.06371596900722981 -- Moving Avg Loss: 0.08327382378775662
# 	Parameters used: [0.6750817  0.76217612]
# Iteration 1350/2000 -- Loss Output: 0.07468600444847998 -- Moving Avg Loss: 0.06877338284792585
# 	Parameters used: [0.7648824 0.6539308]
# Iteration 1500/2000 -- Loss Output: 0.071014633338171 -- Moving Avg Loss: 0.07691861996403636
# 	Parameters used: [0.86933485 0.73832367]
# Iteration 1650/2000 -- Loss Output: 0.07966996147440145 -- Moving Avg Loss: 0.08824176207113801
# 	Parameters used: [0.02971667 0.80248766]
# Iteration 1800/2000 -- Loss Output: 0.09380894040345727 -- Moving Avg Loss: 0.1006796557173822
# 	Parameters used: [0.58698291 0.73696384]
# Iteration 1950/2000 -- Loss Output: 0.09491496641626315 -- Moving Avg Loss: 0.08027949617330622
# 	Parameters used: [0.7132532  0.65841329]
# Iteration 150/2000 -- Loss Output: 0.06968224817404725 -- Moving Avg Loss: 0.08067142728905205
# 	Parameters used: [0.69868008 0.74113038]
# Iteration 300/2000 -- Loss Output: 0.07147059636181062 -- Moving Avg Loss: 0.08162300676476651
# 	Parameters used: [0.68981951 0.75647492]
# Iteration 450/2000 -- Loss Output: 0.07031288425028856 -- Moving Avg Loss: 0.08398357062044111
# 	Parameters used: [0.7438069  0.70223832]
# Iteration 600/2000 -- Loss Output: 0.08002452779440805 -- Moving Avg Loss: 0.07509360026014958
# 	Parameters used: [0.85990424 0.7892234 ]
# Iteration 750/2000 -- Loss Output: 0.10511992309327944 -- Moving Avg Loss: 0.08315788385431143
# 	Parameters used: [0.18144104 0.64768116]
# Iteration 900/2000 -- Loss Output: 0.05976834897727613 -- Moving Avg Loss: 0.08986777617051418
# 	Parameters used: [0.89175895 0.78402943]
# Iteration 1050/2000 -- Loss Output: 0.056586277832985525 -- Moving Avg Loss: 0.09759827883070325
# 	Parameters used: [0.42894508 0.81923937]
# Iteration 1200/2000 -- Loss Output: 0.07190790941014973 -- Moving Avg Loss: 0.09530535488452899
# 	Parameters used: [0.28176922 0.78356251]
# Iteration 1350/2000 -- Loss Output: 0.06342445062255715 -- Moving Avg Loss: 0.07236565808837668
# 	Parameters used: [0.7386322 0.7641767]
# Iteration 1500/2000 -- Loss Output: 0.07587546373891026 -- Moving Avg Loss: 0.07311522104483385
# 	Parameters used: [0.8231515  0.66544311]
# Iteration 1650/2000 -- Loss Output: 0.07947341966520402 -- Moving Avg Loss: 0.07530127722958216
# 	Parameters used: [0.97456384 0.81690364]
# Iteration 1800/2000 -- Loss Output: 0.08727412413250656 -- Moving Avg Loss: 0.074869680719704
# 	Parameters used: [0.00390936 0.80955589]
# Iteration 1950/2000 -- Loss Output: 0.08440754239591869 -- Moving Avg Loss: 0.09260025984841899
# 	Parameters used: [0.38780332 0.81614304]
# Iteration 150/2000 -- Loss Output: 0.05720013600552868 -- Moving Avg Loss: 0.08758166280666581
# 	Parameters used: [0.22176394 0.68721325]
# Iteration 300/2000 -- Loss Output: 0.060697826320490186 -- Moving Avg Loss: 0.06268580376470928
# 	Parameters used: [0.29807348 0.66742909]
# Iteration 450/2000 -- Loss Output: 0.056497085870093736 -- Moving Avg Loss: 0.06780467240159806
# 	Parameters used: [0.27747655 0.64677195]
# Iteration 600/2000 -- Loss Output: 0.06413187741948433 -- Moving Avg Loss: 0.06919139259998697
# 	Parameters used: [0.26419872 0.63345182]
# Iteration 750/2000 -- Loss Output: 0.06392810024993535 -- Moving Avg Loss: 0.09859017848001896
# 	Parameters used: [0.23509168 0.75864107]
# Iteration 900/2000 -- Loss Output: 0.15489369602339736 -- Moving Avg Loss: 0.18786144185683512
# 	Parameters used: [0.18934851 0.71275223]
# Iteration 1050/2000 -- Loss Output: 0.137653506366657 -- Moving Avg Loss: 0.3401794088408846
# 	Parameters used: [0.14437349 0.66763399]
# Iteration 1200/2000 -- Loss Output: 12.465365995780628 -- Moving Avg Loss: 15.613191875462789
# 	Parameters used: [0.65156745 0.65793226]
# Iteration 1350/2000 -- Loss Output: 0.07455530514057196 -- Moving Avg Loss: 0.21195048649935383
# 	Parameters used: [0.38744599 0.63958493]
# Iteration 1500/2000 -- Loss Output: 0.05206069828613434 -- Moving Avg Loss: 0.0767707662665701
# 	Parameters used: [0.35932807 0.74250081]
# Iteration 1650/2000 -- Loss Output: 0.13900937190711277 -- Moving Avg Loss: 0.07900606838737236
# 	Parameters used: [0.24555076 0.67065662]
# Iteration 1800/2000 -- Loss Output: 0.09710421374800188 -- Moving Avg Loss: 0.11736850100010889
# 	Parameters used: [0.22213303 0.6471745 ]
# Iteration 1950/2000 -- Loss Output: 0.1435662699419337 -- Moving Avg Loss: 0.3956540986139583
# 	Parameters used: [0.15986167 0.75771098]
# Iteration 150/2000 -- Loss Output: 5.443320958224298 -- Moving Avg Loss: 10.955258284596605
# 	Parameters used: [0.55670126 0.70511255]
# Iteration 300/2000 -- Loss Output: 8.887840854502263 -- Moving Avg Loss: 12.54229027526376
# 	Parameters used: [0.68412211 0.68103478]
# Iteration 450/2000 -- Loss Output: 13.988424815372651 -- Moving Avg Loss: 4.897739929648377
# 	Parameters used: [0.11853844 0.73093865]
# Iteration 600/2000 -- Loss Output: 9.68500648914418 -- Moving Avg Loss: 13.306604083395834
# 	Parameters used: [0.76164274 0.67656509]
# Iteration 750/2000 -- Loss Output: 16.479347607634484 -- Moving Avg Loss: 7.927054376476246
# 	Parameters used: [0.98035495 0.6587302 ]
# Iteration 900/2000 -- Loss Output: 6.845124287528667 -- Moving Avg Loss: 4.184558409029846
# 	Parameters used: [0.17455697 0.80111178]
# Iteration 1050/2000 -- Loss Output: 3.8460052860070055 -- Moving Avg Loss: 2.663276873788241
# 	Parameters used: [0.22143228 0.785965  ]
# Iteration 1200/2000 -- Loss Output: 8.019320115799218 -- Moving Avg Loss: 8.246742359251535
# 	Parameters used: [0.38745587 0.81939142]
# Iteration 1350/2000 -- Loss Output: 5.797664856588523 -- Moving Avg Loss: 5.835102965550784
# 	Parameters used: [0.26884779 0.7062474 ]
# Iteration 1500/2000 -- Loss Output: 22.80452441214945 -- Moving Avg Loss: 11.272662665536181
# 	Parameters used: [0.97897126 0.75142801]
# Iteration 1650/2000 -- Loss Output: 3.612008996320379 -- Moving Avg Loss: 7.050404818819102
# 	Parameters used: [0.39786877 0.79250175]
# Iteration 1800/2000 -- Loss Output: 7.364992041307473 -- Moving Avg Loss: 8.134609054636623
# 	Parameters used: [0.41847109 0.70409779]
# Iteration 1950/2000 -- Loss Output: 12.861430423132152 -- Moving Avg Loss: 6.608403436846306
# 	Parameters used: [0.05784752 0.78961836]
# Iteration 150/2000 -- Loss Output: 0.05256563277983436 -- Moving Avg Loss: 0.04677237663976875
# 	Parameters used: [0.23801836 0.80260928]
# Iteration 300/2000 -- Loss Output: 0.04033929656751042 -- Moving Avg Loss: 5.5409346465822304
# 	Parameters used: [0.38611717 0.76838267]
# Iteration 450/2000 -- Loss Output: 0.04220142073903949 -- Moving Avg Loss: 3.2135346179976203
# 	Parameters used: [0.28819224 0.72936398]
# Iteration 600/2000 -- Loss Output: 11.508024214860988 -- Moving Avg Loss: 7.1276687736231885
# 	Parameters used: [0.9189596  0.70113966]
# Iteration 750/2000 -- Loss Output: 6.8457321900838135 -- Moving Avg Loss: 7.685371181559783
# 	Parameters used: [0.87419564 0.77629084]
# Iteration 900/2000 -- Loss Output: 0.053267721698570934 -- Moving Avg Loss: 0.05972380635554697
# 	Parameters used: [0.43204046 0.67142813]
# Iteration 1050/2000 -- Loss Output: 0.06142406070819826 -- Moving Avg Loss: 0.05655050627814886
# 	Parameters used: [0.4230225  0.68022767]
# Iteration 1200/2000 -- Loss Output: 0.037035709476713176 -- Moving Avg Loss: 0.0524589804650838
# 	Parameters used: [0.41112101 0.69184092]
# Iteration 1350/2000 -- Loss Output: 0.048121524437765954 -- Moving Avg Loss: 0.04961660844986749
# 	Parameters used: [0.39928765 0.70338768]
# Iteration 1500/2000 -- Loss Output: 0.051860491539533475 -- Moving Avg Loss: 0.04793426062082234
# 	Parameters used: [0.38638238 0.7159804 ]
# Iteration 1650/2000 -- Loss Output: 0.03147525119404564 -- Moving Avg Loss: 0.04738808347728875
# 	Parameters used: [0.37752936 0.724619  ]
# Iteration 1800/2000 -- Loss Output: 0.03716281878363677 -- Moving Avg Loss: 0.04474927880365175
# 	Parameters used: [0.36639399 0.73548468]
# Iteration 1950/2000 -- Loss Output: 0.0355493186083281 -- Moving Avg Loss: 0.04190354806965407
# 	Parameters used: [0.35486323 0.74673619]
# Iteration 150/2000 -- Loss Output: 0.07285185008243376 -- Moving Avg Loss: 0.0831460183316577
# 	Parameters used: [0.61612603 0.67124228]
# Iteration 300/2000 -- Loss Output: 0.08070398346942896 -- Moving Avg Loss: 0.08476114723261728
# 	Parameters used: [0.81494904 0.65222362]
# Iteration 450/2000 -- Loss Output: 0.08615667590642051 -- Moving Avg Loss: 0.08632952543407026
# 	Parameters used: [0.94959306 0.69692741]
# Iteration 600/2000 -- Loss Output: 0.11933300812412456 -- Moving Avg Loss: 0.0859449946958378
# 	Parameters used: [0.16402421 0.68151438]
# Iteration 750/2000 -- Loss Output: 0.09042988694799 -- Moving Avg Loss: 0.09000188900383281
# 	Parameters used: [0.96626517 0.68364549]
# Iteration 900/2000 -- Loss Output: 0.058323883074996107 -- Moving Avg Loss: 0.07710688144658052
# 	Parameters used: [0.81867384 0.67579851]
# Iteration 1050/2000 -- Loss Output: 0.10028286675939292 -- Moving Avg Loss: 0.08728554890765064
# 	Parameters used: [0.03871487 0.75601604]
# Iteration 1200/2000 -- Loss Output: 0.07466748792165938 -- Moving Avg Loss: 0.08685796677873654
# 	Parameters used: [0.79707715 0.69268367]
# Iteration 1350/2000 -- Loss Output: 0.11590473634060612 -- Moving Avg Loss: 0.0824258741977571
# 	Parameters used: [0.40005552 0.62334837]
# Iteration 1500/2000 -- Loss Output: 0.06746942784884288 -- Moving Avg Loss: 0.0802738583425802
# 	Parameters used: [0.50753753 0.66955691]
# Iteration 1650/2000 -- Loss Output: 0.06855658201732942 -- Moving Avg Loss: 0.07478494315165493
# 	Parameters used: [0.6918643  0.72139611]
# Iteration 1800/2000 -- Loss Output: 0.09228372215687658 -- Moving Avg Loss: 0.08700845160712387
# 	Parameters used: [0.85288272 0.62811403]
# Iteration 1950/2000 -- Loss Output: 0.0781000823755221 -- Moving Avg Loss: 0.0883739212160735
# 	Parameters used: [0.27001686 0.81429253]
# Iteration 150/2000 -- Loss Output: 10.66391295796312 -- Moving Avg Loss: 11.789143057023143
# 	Parameters used: [0.29663407 0.71048943]
# Iteration 300/2000 -- Loss Output: 0.17013391015814716 -- Moving Avg Loss: 2.6162645286925033
# 	Parameters used: [0.10031364 0.64243317]
# Iteration 450/2000 -- Loss Output: 14.519275046751437 -- Moving Avg Loss: 6.470850807282907
# 	Parameters used: [0.83714528 0.66683447]
# Iteration 600/2000 -- Loss Output: 8.583474916881162 -- Moving Avg Loss: 7.88460060767903
# 	Parameters used: [0.72611788 0.64747173]
# Iteration 750/2000 -- Loss Output: 8.021459240501697 -- Moving Avg Loss: 7.652375503270734
# 	Parameters used: [0.94312743 0.64818961]
# Iteration 900/2000 -- Loss Output: 5.265341084619579 -- Moving Avg Loss: 6.797136249875307
# 	Parameters used: [0.08491564 0.63236298]
# Iteration 1050/2000 -- Loss Output: 15.626430653360243 -- Moving Avg Loss: 6.140448281343955
# 	Parameters used: [0.27699021 0.62592743]
# Iteration 1200/2000 -- Loss Output: 0.5206504694765614 -- Moving Avg Loss: 5.571515064383045
# 	Parameters used: [0.2142549 0.7761743]
# Iteration 1350/2000 -- Loss Output: 12.029395703975393 -- Moving Avg Loss: 11.43821810810475
# 	Parameters used: [0.65145008 0.79572533]
# Iteration 1500/2000 -- Loss Output: 11.99441514149498 -- Moving Avg Loss: 8.202033692283807
# 	Parameters used: [0.36740513 0.80300462]
# Iteration 1650/2000 -- Loss Output: 3.3466257361969913 -- Moving Avg Loss: 3.863936794357455
# 	Parameters used: [0.22052521 0.76486261]
# Iteration 1800/2000 -- Loss Output: 6.33579793566037 -- Moving Avg Loss: 3.7470757107058876
# 	Parameters used: [0.03998499 0.70324102]
# Iteration 1950/2000 -- Loss Output: 15.670371698014291 -- Moving Avg Loss: 12.236082045434111
# 	Parameters used: [0.66762766 0.74829496]
# Iteration 150/2000 -- Loss Output: 0.20890971079428108 -- Moving Avg Loss: 0.12977850261733873
# 	Parameters used: [0.01892964 0.80899245]
# Iteration 300/2000 -- Loss Output: 0.15411418522618506 -- Moving Avg Loss: 0.14195562279458257
# 	Parameters used: [0.02088938 0.76648963]
# Iteration 450/2000 -- Loss Output: 1.1076486255406106 -- Moving Avg Loss: 3.6712877985904733
# 	Parameters used: [0.25768273 0.6573273 ]
# Iteration 600/2000 -- Loss Output: 0.05662766127803908 -- Moving Avg Loss: 0.05674960226573072
# 	Parameters used: [0.15704849 0.75113386]
# Iteration 750/2000 -- Loss Output: 0.0672270636434909 -- Moving Avg Loss: 0.06486893387807817
# 	Parameters used: [0.11941305 0.7863    ]
# Iteration 900/2000 -- Loss Output: 0.12480976781384683 -- Moving Avg Loss: 0.12313710454244176
# 	Parameters used: [0.04445971 0.78760772]
# Iteration 1050/2000 -- Loss Output: 0.04618220628941588 -- Moving Avg Loss: 0.3493753079406288
# 	Parameters used: [0.2076011  0.77747152]
# Iteration 1200/2000 -- Loss Output: 0.08081601181113628 -- Moving Avg Loss: 0.06349279651101711
# 	Parameters used: [0.13016802 0.7194188 ]
# Iteration 1350/2000 -- Loss Output: 0.13224093492150077 -- Moving Avg Loss: 0.1108364565781579
# 	Parameters used: [0.05482076 0.78998213]
# Iteration 1500/2000 -- Loss Output: 2.0413799476688497 -- Moving Avg Loss: 5.656550628336225
# 	Parameters used: [0.27652865 0.74307476]
# Iteration 1650/2000 -- Loss Output: 0.08725195221640515 -- Moving Avg Loss: 0.08267807068402946
# 	Parameters used: [0.0834716 0.7172226]
# Iteration 1800/2000 -- Loss Output: 0.1107901913912045 -- Moving Avg Loss: 0.1555402793130744
# 	Parameters used: [0.01079398 0.70234732]
# Iteration 1950/2000 -- Loss Output: 0.05790631083805535 -- Moving Avg Loss: 0.8374601271278895
# 	Parameters used: [0.19387463 0.75687286]

# %% [markdown]
# ## Fits with Specific Obliquity

# %%
OBLIQUITY = 0.25
constraints = getConstraints(OBLIQUITY, longitude_max=0)

for cycloid in cycloids:
    process_cycloid_top_fits(cycloids[cycloid].curve,
                             cycloid,
                             folder='./output/lockedObliquity025/',
                             iterations=2000,
                             constraints=constraints,
                             number_of_fits=5,
                             paramCount=2,
                             verbose=False
                            )
    
# process_cycloid_top_fits(cycloids['alex'].curve,
#                          cycloid,
#                          folder='./output/lockedObliquity025/',
#                          iterations=2000,
#                          constraints=constraints,
#                          number_of_fits=5,
#                          paramCount=2,
#                          verbose=False
#                         )
# Out:
# Iteration 150/2000 -- Loss Output: 1.4248075384285983 -- Moving Avg Loss: 1.1883207512159861
# 	Parameters used: [0.74257724 0.25      ]
# Iteration 300/2000 -- Loss Output: 2.2319747593251553 -- Moving Avg Loss: 0.8793087615137398
# 	Parameters used: [0.67137518 0.25      ]
# Iteration 450/2000 -- Loss Output: 1.8551155894105715 -- Moving Avg Loss: 1.1156791536528265
# 	Parameters used: [0.7431446 0.25     ]
# Iteration 600/2000 -- Loss Output: 2.2753502336085654 -- Moving Avg Loss: 1.6835541664231528
# 	Parameters used: [0.54834402 0.25      ]
# Iteration 750/2000 -- Loss Output: 2.1466281134023473 -- Moving Avg Loss: 2.8258506444263882
# 	Parameters used: [0.58251043 0.25      ]
# Iteration 900/2000 -- Loss Output: 1.8328936090408587 -- Moving Avg Loss: 1.0576207875360288
# 	Parameters used: [0.71936988 0.25      ]
# Iteration 1050/2000 -- Loss Output: 5.922528065039167 -- Moving Avg Loss: 9.893401589187995
# 	Parameters used: [0.18281204 0.25      ]
# Iteration 1200/2000 -- Loss Output: 4.039426328330896 -- Moving Avg Loss: 2.516041674835317
# 	Parameters used: [0.49742503 0.25      ]
# Iteration 1350/2000 -- Loss Output: 2.03752950330483 -- Moving Avg Loss: 1.5089784951333096
# 	Parameters used: [0.59595924 0.25      ]
# Iteration 1500/2000 -- Loss Output: 1.7966932308443662 -- Moving Avg Loss: 1.2930881625748325
# 	Parameters used: [0.71055438 0.25      ]
# Iteration 1650/2000 -- Loss Output: 1.760277791436157 -- Moving Avg Loss: 2.5303391882150343
# 	Parameters used: [0.80986234 0.25      ]
# Iteration 1800/2000 -- Loss Output: 10.871164245996878 -- Moving Avg Loss: 4.786311665259877
# 	Parameters used: [0.33311116 0.25      ]
# Iteration 1950/2000 -- Loss Output: 2.2263564071431334 -- Moving Avg Loss: 1.5966176793836562
# 	Parameters used: [0.63059759 0.25      ]
# Iteration 150/2000 -- Loss Output: 0.08189361778049312 -- Moving Avg Loss: 0.7534108545749615
# 	Parameters used: [0.37816955 0.25      ]
# Iteration 300/2000 -- Loss Output: 1.1570987850258745 -- Moving Avg Loss: 4.017018767405636
# 	Parameters used: [0.57233844 0.25      ]
# Iteration 450/2000 -- Loss Output: 1.7750116438949868 -- Moving Avg Loss: 0.7660365783906863
# 	Parameters used: [0.09462456 0.25      ]
# Iteration 600/2000 -- Loss Output: 0.1090673908438702 -- Moving Avg Loss: 0.8164603915476926
# 	Parameters used: [0.17563292 0.25      ]
# Iteration 750/2000 -- Loss Output: 0.07097319407829418 -- Moving Avg Loss: 0.4754766670644923
# 	Parameters used: [0.23280965 0.25      ]
# Iteration 900/2000 -- Loss Output: 1.1556671957726596 -- Moving Avg Loss: 0.597581992303326
# 	Parameters used: [0.28260055 0.25      ]
# Iteration 1050/2000 -- Loss Output: 1.1084808906897552 -- Moving Avg Loss: 1.4207728312750825
# 	Parameters used: [0.37508527 0.25      ]
# Iteration 1200/2000 -- Loss Output: 11.957132827705255 -- Moving Avg Loss: 10.521502016340182
# 	Parameters used: [0.930944 0.25    ]
# Iteration 1350/2000 -- Loss Output: 0.09349069010192859 -- Moving Avg Loss: 0.6098104804226065
# 	Parameters used: [0.24020444 0.25      ]
# Iteration 1500/2000 -- Loss Output: 0.6991022858518263 -- Moving Avg Loss: 0.47204397154649613
# 	Parameters used: [0.30070304 0.25      ]
# Iteration 1650/2000 -- Loss Output: 0.07462758482161842 -- Moving Avg Loss: 0.7392099949705014
# 	Parameters used: [0.38109782 0.25      ]
# Iteration 1800/2000 -- Loss Output: 2.42440350756641 -- Moving Avg Loss: 4.09805151766798
# 	Parameters used: [0.13754519 0.25      ]
# Iteration 1950/2000 -- Loss Output: 0.41836301029776723 -- Moving Avg Loss: 0.6018499344004209
# 	Parameters used: [0.2010066 0.25     ]
# Iteration 150/2000 -- Loss Output: 0.06213396456658723 -- Moving Avg Loss: 0.08086677166694498
# 	Parameters used: [0.47501643 0.25      ]
# Iteration 300/2000 -- Loss Output: 0.11752873365766296 -- Moving Avg Loss: 0.09043451759134488
# 	Parameters used: [0.73276664 0.25      ]
# Iteration 450/2000 -- Loss Output: 0.08571927102049993 -- Moving Avg Loss: 0.07717934731546996
# 	Parameters used: [0.64248682 0.25      ]
# Iteration 600/2000 -- Loss Output: 0.07339288580390911 -- Moving Avg Loss: 0.07626556099715814
# 	Parameters used: [0.23635908 0.25      ]
# Iteration 750/2000 -- Loss Output: 0.08517635439126314 -- Moving Avg Loss: 0.07930490681588634
# 	Parameters used: [0.24483256 0.25      ]
# Iteration 900/2000 -- Loss Output: 0.09261359055369041 -- Moving Avg Loss: 0.07542850838376566
# 	Parameters used: [0.24834954 0.25      ]
# Iteration 1050/2000 -- Loss Output: 0.05555938423998512 -- Moving Avg Loss: 0.06676099736210082
# 	Parameters used: [0.80937072 0.25      ]
# Iteration 1200/2000 -- Loss Output: 0.06083353095733569 -- Moving Avg Loss: 0.0779239795394273
# 	Parameters used: [0.76798488 0.25      ]
# Iteration 1350/2000 -- Loss Output: 0.11411193786900901 -- Moving Avg Loss: 0.08556398940925103
# 	Parameters used: [0.23914697 0.25      ]
# Iteration 1500/2000 -- Loss Output: 0.06242744210495077 -- Moving Avg Loss: 0.07384506814657098
# 	Parameters used: [0.71063535 0.25      ]
# Iteration 1650/2000 -- Loss Output: 0.09692709732701484 -- Moving Avg Loss: 0.08676523464736073
# 	Parameters used: [0.42483821 0.25      ]
# Iteration 1800/2000 -- Loss Output: 0.06953050053228846 -- Moving Avg Loss: 0.06612891097749976
# 	Parameters used: [0.88479672 0.25      ]
# Iteration 1950/2000 -- Loss Output: 0.06896711508548495 -- Moving Avg Loss: 0.08176558872770866
# 	Parameters used: [0.70245997 0.25      ]
# Iteration 150/2000 -- Loss Output: 0.08132100419337308 -- Moving Avg Loss: 0.07282447117794442
# 	Parameters used: [0.65874063 0.25      ]
# Iteration 300/2000 -- Loss Output: 0.06790179468347433 -- Moving Avg Loss: 0.07068249695954296
# 	Parameters used: [0.70745268 0.25      ]
# Iteration 450/2000 -- Loss Output: 0.07225110445358009 -- Moving Avg Loss: 0.07240558713634017
# 	Parameters used: [0.79219893 0.25      ]
# Iteration 600/2000 -- Loss Output: 0.058288744788044626 -- Moving Avg Loss: 0.0712859462869814
# 	Parameters used: [0.99844227 0.25      ]
# Iteration 750/2000 -- Loss Output: 0.07235905144605102 -- Moving Avg Loss: 0.0718073866715348
# 	Parameters used: [0.07683888 0.25      ]
# Iteration 900/2000 -- Loss Output: 0.07325124823688839 -- Moving Avg Loss: 0.07463291313254426
# 	Parameters used: [0.49863951 0.25      ]
# Iteration 1050/2000 -- Loss Output: 0.075587091512414 -- Moving Avg Loss: 0.07712688231936282
# 	Parameters used: [0.05161303 0.25      ]
# Iteration 1200/2000 -- Loss Output: 0.08221628211782007 -- Moving Avg Loss: 0.06840799534388319
# 	Parameters used: [0.92170969 0.25      ]
# Iteration 1350/2000 -- Loss Output: 0.0824556359988878 -- Moving Avg Loss: 0.07351098540619044
# 	Parameters used: [0.47291357 0.25      ]
# Iteration 1500/2000 -- Loss Output: 0.06277334951442565 -- Moving Avg Loss: 0.07574150804064238
# 	Parameters used: [0.49362989 0.25      ]
# Iteration 1650/2000 -- Loss Output: 0.0836516414540453 -- Moving Avg Loss: 0.07781697271525335
# 	Parameters used: [0.43703449 0.25      ]
# Iteration 1800/2000 -- Loss Output: 0.0955722020550779 -- Moving Avg Loss: 0.07126980334223876
# 	Parameters used: [0.93736773 0.25      ]
# Iteration 1950/2000 -- Loss Output: 0.06335042589214329 -- Moving Avg Loss: 0.07176180706969951
# 	Parameters used: [0.87591866 0.25      ]
# Iteration 150/2000 -- Loss Output: 0.166712242163573 -- Moving Avg Loss: 0.4273354751392698
# 	Parameters used: [0.19966439 0.25      ]
# Iteration 300/2000 -- Loss Output: 0.31600267017549993 -- Moving Avg Loss: 0.27274059373615445
# 	Parameters used: [0.38733925 0.25      ]
# Iteration 450/2000 -- Loss Output: 0.14012960193222682 -- Moving Avg Loss: 0.543028082011373
# 	Parameters used: [0.42625715 0.25      ]
# Iteration 600/2000 -- Loss Output: 20.548417336316685 -- Moving Avg Loss: 16.788800880352916
# 	Parameters used: [0.85335481 0.25      ]
# Iteration 750/2000 -- Loss Output: 0.12994288769165493 -- Moving Avg Loss: 0.4197889703416932
# 	Parameters used: [0.20327944 0.25      ]
# Iteration 900/2000 -- Loss Output: 0.15387359562777184 -- Moving Avg Loss: 0.2523053293686126
# 	Parameters used: [0.25626082 0.25      ]
# Iteration 1050/2000 -- Loss Output: 0.116928148091054 -- Moving Avg Loss: 0.20465263449403856
# 	Parameters used: [0.30102881 0.25      ]
# Iteration 1200/2000 -- Loss Output: 0.49285482282176196 -- Moving Avg Loss: 0.43857092966015815
# 	Parameters used: [0.35795239 0.25      ]
# Iteration 1350/2000 -- Loss Output: 0.12909857276720713 -- Moving Avg Loss: 0.6053276767108041
# 	Parameters used: [0.4161797 0.25     ]
# Iteration 1500/2000 -- Loss Output: 0.5805122252251166 -- Moving Avg Loss: 1.3939719544873097
# 	Parameters used: [0.51980009 0.25      ]
# Iteration 1650/2000 -- Loss Output: 2.1461997499311707 -- Moving Avg Loss: 0.33732718691410907
# 	Parameters used: [0.19080633 0.25      ]
# Iteration 1800/2000 -- Loss Output: 0.13999902787562155 -- Moving Avg Loss: 0.38878939012887925
# 	Parameters used: [0.2860974 0.25     ]
# Iteration 1950/2000 -- Loss Output: 0.12145113132363068 -- Moving Avg Loss: 0.3276399695660026
# 	Parameters used: [0.36437523 0.25      ]
# Iteration 150/2000 -- Loss Output: 5.369291670451144 -- Moving Avg Loss: 10.677673227950022
# 	Parameters used: [0.38393966 0.25      ]
# Iteration 300/2000 -- Loss Output: 9.149433378288633 -- Moving Avg Loss: 12.433744439865425
# 	Parameters used: [0.55059919 0.25      ]
# Iteration 450/2000 -- Loss Output: 9.462883800808118 -- Moving Avg Loss: 11.540668158272048
# 	Parameters used: [0.14320194 0.25      ]
# Iteration 600/2000 -- Loss Output: 17.767186980480023 -- Moving Avg Loss: 11.30856148247242
# 	Parameters used: [0.05693183 0.25      ]
# Iteration 750/2000 -- Loss Output: 13.723415327869796 -- Moving Avg Loss: 14.255227653094039
# 	Parameters used: [0.65191244 0.25      ]
# Iteration 900/2000 -- Loss Output: 16.427249814753225 -- Moving Avg Loss: 11.794236120545389
# 	Parameters used: [0.99417078 0.25      ]
# Iteration 1050/2000 -- Loss Output: 10.226172274912049 -- Moving Avg Loss: 8.958620610917247
# 	Parameters used: [0.18649229 0.25      ]
# Iteration 1200/2000 -- Loss Output: 13.410750858735186 -- Moving Avg Loss: 9.865022631070081
# 	Parameters used: [0.10808245 0.25      ]
# Iteration 1350/2000 -- Loss Output: 16.43857047074936 -- Moving Avg Loss: 14.595000368419237
# 	Parameters used: [0.66785485 0.25      ]
# Iteration 1500/2000 -- Loss Output: 6.878953170229484 -- Moving Avg Loss: 10.346153892527132
# 	Parameters used: [0.30208576 0.25      ]
# Iteration 1650/2000 -- Loss Output: 10.46279715754041 -- Moving Avg Loss: 15.793963469451977
# 	Parameters used: [0.75973197 0.25      ]
# Iteration 1800/2000 -- Loss Output: 16.88971474569228 -- Moving Avg Loss: 16.18817398957706
# 	Parameters used: [0.76253318 0.25      ]
# Iteration 1950/2000 -- Loss Output: 7.396159422900203 -- Moving Avg Loss: 14.997457156775411
# 	Parameters used: [0.65991219 0.25      ]
# Iteration 150/2000 -- Loss Output: 6.096555645606235 -- Moving Avg Loss: 3.669404395012427
# 	Parameters used: [0.84706009 0.25      ]
# Iteration 300/2000 -- Loss Output: 6.908507863543432 -- Moving Avg Loss: 3.001073523262787
# 	Parameters used: [0.86897608 0.25      ]
# Iteration 450/2000 -- Loss Output: 1.6685181106730698 -- Moving Avg Loss: 3.317802926997944
# 	Parameters used: [0.61100199 0.25      ]
# Iteration 600/2000 -- Loss Output: 1.3616036351636638 -- Moving Avg Loss: 0.6585883177368472
# 	Parameters used: [0.33379545 0.25      ]
# Iteration 750/2000 -- Loss Output: 2.803652323132593 -- Moving Avg Loss: 1.2280067765801195
# 	Parameters used: [0.22320088 0.25      ]
# Iteration 900/2000 -- Loss Output: 5.614407519703468 -- Moving Avg Loss: 3.1185430826805294
# 	Parameters used: [0.03039548 0.25      ]
# Iteration 1050/2000 -- Loss Output: 0.9936773502204417 -- Moving Avg Loss: 0.7578106916193731
# 	Parameters used: [0.30557082 0.25      ]
# Iteration 1200/2000 -- Loss Output: 2.139206362887001 -- Moving Avg Loss: 2.5407708009283123
# 	Parameters used: [0.46312067 0.25      ]
# Iteration 1350/2000 -- Loss Output: 1.1397611332068178 -- Moving Avg Loss: 3.8737405776412204
# 	Parameters used: [0.63458992 0.25      ]
# Iteration 1500/2000 -- Loss Output: 3.1797026418866605 -- Moving Avg Loss: 1.8522178322023053
# 	Parameters used: [0.1465743 0.25     ]
# Iteration 1650/2000 -- Loss Output: 0.5683830485458486 -- Moving Avg Loss: 1.1276992828501349
# 	Parameters used: [0.30919582 0.25      ]
# Iteration 1800/2000 -- Loss Output: 2.7050880139846454 -- Moving Avg Loss: 3.6787945380495266
# 	Parameters used: [0.59450109 0.25      ]
# Iteration 1950/2000 -- Loss Output: 0.9769266169252129 -- Moving Avg Loss: 0.8161678572203931
# 	Parameters used: [0.28556092 0.25      ]
# Iteration 150/2000 -- Loss Output: 0.061862132834353774 -- Moving Avg Loss: 0.06890000068742504
# 	Parameters used: [0.16644364 0.25      ]
# Iteration 300/2000 -- Loss Output: 0.09923105254922196 -- Moving Avg Loss: 0.07354525801591326
# 	Parameters used: [0.59250761 0.25      ]
# Iteration 450/2000 -- Loss Output: 0.0605417619125785 -- Moving Avg Loss: 0.07574004687603625
# 	Parameters used: [0.96752527 0.25      ]
# Iteration 600/2000 -- Loss Output: 0.06710158062328418 -- Moving Avg Loss: 0.07873350782007824
# 	Parameters used: [0.21303112 0.25      ]
# Iteration 750/2000 -- Loss Output: 0.07273810159101742 -- Moving Avg Loss: 0.07332707080263921
# 	Parameters used: [0.56375553 0.25      ]
# Iteration 900/2000 -- Loss Output: 0.0813606473659735 -- Moving Avg Loss: 0.07415027357368237
# 	Parameters used: [0.67426202 0.25      ]
# Iteration 1050/2000 -- Loss Output: 0.07909317602748281 -- Moving Avg Loss: 0.07758493999300116
# 	Parameters used: [0.55360176 0.25      ]
# Iteration 1200/2000 -- Loss Output: 0.06978974016501664 -- Moving Avg Loss: 0.07644941561038446
# 	Parameters used: [0.56770864 0.25      ]
# Iteration 1350/2000 -- Loss Output: 0.09246784253436567 -- Moving Avg Loss: 0.0753817457574045
# 	Parameters used: [0.67642157 0.25      ]
# Iteration 1500/2000 -- Loss Output: 0.05398878831035114 -- Moving Avg Loss: 0.07566013130957805
# 	Parameters used: [0.31024997 0.25      ]
# Iteration 1650/2000 -- Loss Output: 0.07589163594767682 -- Moving Avg Loss: 0.07547988005701757
# 	Parameters used: [0.85503236 0.25      ]
# Iteration 1800/2000 -- Loss Output: 0.07993491945940133 -- Moving Avg Loss: 0.07901478833144943
# 	Parameters used: [0.18466383 0.25      ]
# Iteration 1950/2000 -- Loss Output: 0.06152247107875169 -- Moving Avg Loss: 0.0711374821311784
# 	Parameters used: [0.04703869 0.25      ]
# Iteration 150/2000 -- Loss Output: 11.254982889870762 -- Moving Avg Loss: 10.795343265436161
# 	Parameters used: [0.55381198 0.25      ]
# Iteration 300/2000 -- Loss Output: 6.849926611966497 -- Moving Avg Loss: 5.884299360328296
# 	Parameters used: [0.10722358 0.25      ]
# Iteration 450/2000 -- Loss Output: 1.6050932607133155 -- Moving Avg Loss: 8.727573996091646
# 	Parameters used: [0.22352858 0.25      ]
# Iteration 600/2000 -- Loss Output: 3.890308465768236 -- Moving Avg Loss: 7.914859463655701
# 	Parameters used: [0.37041078 0.25      ]
# Iteration 750/2000 -- Loss Output: 7.0363334979996495 -- Moving Avg Loss: 8.829642389329772
# 	Parameters used: [0.33271342 0.25      ]
# Iteration 900/2000 -- Loss Output: 3.5264705887033783 -- Moving Avg Loss: 8.79444706305155
# 	Parameters used: [0.1672576 0.25     ]
# Iteration 1050/2000 -- Loss Output: 15.70077890032101 -- Moving Avg Loss: 13.237461096225507
# 	Parameters used: [0.57457644 0.25      ]
# Iteration 1200/2000 -- Loss Output: 4.345121759741815 -- Moving Avg Loss: 6.153530927378103
# 	Parameters used: [0.26877744 0.25      ]
# Iteration 1350/2000 -- Loss Output: 3.8807057252427133 -- Moving Avg Loss: 6.533455508759369
# 	Parameters used: [0.02207453 0.25      ]
# Iteration 1500/2000 -- Loss Output: 9.495702555652425 -- Moving Avg Loss: 12.415915638159241
# 	Parameters used: [0.81477509 0.25      ]
# Iteration 1650/2000 -- Loss Output: 3.595392675170473 -- Moving Avg Loss: 7.988842960094338
# 	Parameters used: [0.30898345 0.25      ]
# Iteration 1800/2000 -- Loss Output: 3.4429512125636696 -- Moving Avg Loss: 4.699080640819201
# 	Parameters used: [0.055718 0.25    ]
# Iteration 1950/2000 -- Loss Output: 6.228597187513498 -- Moving Avg Loss: 9.394180530039533
# 	Parameters used: [0.40326078 0.25      ]
# Iteration 150/2000 -- Loss Output: 0.1729861925104681 -- Moving Avg Loss: 0.22124593024734804
# 	Parameters used: [0.00356725 0.25      ]
# Iteration 300/2000 -- Loss Output: 10.672073879024449 -- Moving Avg Loss: 2.6595968827634238
# 	Parameters used: [0.88396294 0.25      ]
# Iteration 450/2000 -- Loss Output: 0.09088728268992648 -- Moving Avg Loss: 0.3261978564077216
# 	Parameters used: [0.12739496 0.25      ]
# Iteration 600/2000 -- Loss Output: 0.1795701010159169 -- Moving Avg Loss: 0.2978731620979498
# 	Parameters used: [0.97310271 0.25      ]
# Iteration 750/2000 -- Loss Output: 0.08921875188989838 -- Moving Avg Loss: 0.28970965972297674
# 	Parameters used: [0.08912645 0.25      ]
# Iteration 900/2000 -- Loss Output: 0.20219464146009697 -- Moving Avg Loss: 0.3178842195689498
# 	Parameters used: [0.97586215 0.25      ]
# Iteration 1050/2000 -- Loss Output: 0.09000970213631779 -- Moving Avg Loss: 0.35761159793048186
# 	Parameters used: [0.11220829 0.25      ]
# Iteration 1200/2000 -- Loss Output: 3.5216297094119566 -- Moving Avg Loss: 8.689185707280377
# 	Parameters used: [0.59539338 0.25      ]
# Iteration 1350/2000 -- Loss Output: 0.30461537268688743 -- Moving Avg Loss: 0.31142096876461944
# 	Parameters used: [0.04806189 0.25      ]
# Iteration 1500/2000 -- Loss Output: 0.09523587194626629 -- Moving Avg Loss: 0.6836926750196644
# 	Parameters used: [0.08971405 0.25      ]
# Iteration 1650/2000 -- Loss Output: 11.194062232256732 -- Moving Avg Loss: 4.058124616181733
# 	Parameters used: [0.82688581 0.25      ]
# Iteration 1800/2000 -- Loss Output: 1.2325305454562712 -- Moving Avg Loss: 0.3584752329669847
# 	Parameters used: [0.9757292 0.25     ]
# Iteration 1950/2000 -- Loss Output: 15.816691221118628 -- Moving Avg Loss: 4.527611385957642
# 	Parameters used: [0.76148221 0.25      ]

# %% [markdown]
# ## Testng with Longitude translation

# %%
for key in cycloids:
    process_cycloid_by_name(key, 
                            iterations=3000,
                            folder='./output/nsr/',
                            paramCount=3,
                            verbose=False)
# Out:
# [16:49:14] Processing Cycloid: alex
# Iteration 150/3000 -- Loss Output: 3.993348575793139 -- Moving Avg Loss: 6.066777333419317
# 	Parameters used: [0.46012209 0.81010718 0.07752626]
# Iteration 300/3000 -- Loss Output: 3.4830213137547266 -- Moving Avg Loss: 8.58269274451601
# 	Parameters used: [0.49358162 0.27003794 0.10659239]
# Iteration 450/3000 -- Loss Output: 4.438351592889975 -- Moving Avg Loss: 7.21941105413801
# 	Parameters used: [0.4875027  0.55898334 0.17224785]
# Iteration 600/3000 -- Loss Output: 6.5211076353545 -- Moving Avg Loss: 7.1587789803364394
# 	Parameters used: [0.46812296 0.12196166 0.11444358]
# Iteration 750/3000 -- Loss Output: 0.2709421453561012 -- Moving Avg Loss: 0.24088192288309382
# 	Parameters used: [0.0180393  0.07847188 0.66818887]
# Iteration 900/3000 -- Loss Output: 1.4457301532433176 -- Moving Avg Loss: 4.56963180786252
# 	Parameters used: [0.04175198 0.12000308 0.69987714]
# Iteration 1050/3000 -- Loss Output: 0.6666224419993874 -- Moving Avg Loss: 5.516989568703891
# 	Parameters used: [0.6455826  0.10994671 0.365872  ]
# Iteration 1200/3000 -- Loss Output: 6.509963681467167 -- Moving Avg Loss: 0.8615922746535652
# 	Parameters used: [0.42535975 0.63269025 0.14695688]
# Iteration 1350/3000 -- Loss Output: 0.21768083707794897 -- Moving Avg Loss: 0.2253588705488544
# 	Parameters used: [0.88129005 0.08610495 0.69003078]
# Iteration 1500/3000 -- Loss Output: 0.23716129284516801 -- Moving Avg Loss: 0.24010419563464805
# 	Parameters used: [0.83878551 0.0435463  0.64766743]
# Iteration 1650/3000 -- Loss Output: 2.306100686796564 -- Moving Avg Loss: 3.0020554345626937
# 	Parameters used: [0.56219127 0.13922991 0.37808249]
# Iteration 1800/3000 -- Loss Output: 2.153132898191693 -- Moving Avg Loss: 1.289714496705794
# 	Parameters used: [0.3405096  0.18793327 0.15691545]
# Iteration 1950/3000 -- Loss Output: 0.7191224663769423 -- Moving Avg Loss: 0.3135480139277112
# 	Parameters used: [0.84832244 0.13942972 0.66589899]
# Iteration 2100/3000 -- Loss Output: 0.13201698360695938 -- Moving Avg Loss: 0.567872095848037
# 	Parameters used: [0.79559192 0.06340249 0.70433231]
# Iteration 2250/3000 -- Loss Output: 0.16292453395450188 -- Moving Avg Loss: 0.14247560902910933
# 	Parameters used: [0.74601719 0.01379012 0.65479754]
# Iteration 2400/3000 -- Loss Output: 0.14808347774366315 -- Moving Avg Loss: 0.9011237992636169
# 	Parameters used: [0.30927882 0.24026907 0.21840891]
# Iteration 2550/3000 -- Loss Output: 0.20049244935968807 -- Moving Avg Loss: 0.1837009535696891
# 	Parameters used: [0.26657335 0.19753122 0.17573764]
# Iteration 2700/3000 -- Loss Output: 5.4262895951073284 -- Moving Avg Loss: 4.757583824891026
# 	Parameters used: [0.11215076 0.04299158 0.02143865]
# Iteration 2850/3000 -- Loss Output: 1.091272098724631 -- Moving Avg Loss: 0.380620437061026
# 	Parameters used: [0.22388898 0.16160043 0.13958164]
# Iteration 3000/3000 -- Loss Output: 0.16068265675970697 -- Moving Avg Loss: 0.19211989374589133
# 	Parameters used: [0.79623505 0.32252731 0.71507472]
# [16:53:39] Analyzing optimization parameters for alex
# [16:53:54] Processing Cycloid: carly
# Iteration 150/3000 -- Loss Output: 0.13626217056860537 -- Moving Avg Loss: 2.5786529007866754
# 	Parameters used: [0.19204818 0.26323336 0.00751507]
# Iteration 300/3000 -- Loss Output: 0.08084076146498016 -- Moving Avg Loss: 4.774956503516706
# 	Parameters used: [0.85936217 0.02686186 0.64655692]
# Iteration 450/3000 -- Loss Output: 2.6788958383859502 -- Moving Avg Loss: 1.232680435188001
# 	Parameters used: [0.61018291 0.07905401 0.37845115]
# Iteration 600/3000 -- Loss Output: 0.06810756849677713 -- Moving Avg Loss: 0.07341629188096307
# 	Parameters used: [0.16687399 0.65248455 0.93376941]
# Iteration 750/3000 -- Loss Output: 0.0685763666967148 -- Moving Avg Loss: 1.6533710658558496
# 	Parameters used: [0.28851747 0.38992733 0.0153607 ]
# Iteration 900/3000 -- Loss Output: 0.04611255474259326 -- Moving Avg Loss: 0.055917760597151756
# 	Parameters used: [0.71965149 0.80784125 0.44062608]
# Iteration 1050/3000 -- Loss Output: 0.05029925619141291 -- Moving Avg Loss: 0.06322579290083696
# 	Parameters used: [0.35402806 0.44117386 0.07391115]
# Iteration 1200/3000 -- Loss Output: 0.06463804810865073 -- Moving Avg Loss: 2.426279524689955
# 	Parameters used: [0.94624498 0.03197396 0.66467439]
# Iteration 1350/3000 -- Loss Output: 0.06546671149435854 -- Moving Avg Loss: 0.06089940021745863
# 	Parameters used: [0.36057213 0.39567663 0.07496382]
# Iteration 1500/3000 -- Loss Output: 7.652453790135506 -- Moving Avg Loss: 1.0958505161184127
# 	Parameters used: [0.08473235 0.11908681 0.79924609]
# Iteration 1650/3000 -- Loss Output: 1.5278601445634663 -- Moving Avg Loss: 0.8740746955082416
# 	Parameters used: [0.63200439 0.36958982 0.32708311]
# Iteration 1800/3000 -- Loss Output: 0.05067984498140984 -- Moving Avg Loss: 0.055729169985700634
# 	Parameters used: [0.35476283 0.48249566 0.0453487 ]
# Iteration 1950/3000 -- Loss Output: 0.07903230917957701 -- Moving Avg Loss: 0.17402476450851576
# 	Parameters used: [0.76598479 0.3232734  0.455808  ]
# Iteration 2100/3000 -- Loss Output: 0.06448461678131283 -- Moving Avg Loss: 0.05820904790948174
# 	Parameters used: [0.90853529 0.5137555  0.59671772]
# Iteration 2250/3000 -- Loss Output: 0.062866195447531 -- Moving Avg Loss: 0.34124563331050195
# 	Parameters used: [0.78973039 0.3947027  0.4776774 ]
# Iteration 2400/3000 -- Loss Output: 0.05812854661217612 -- Moving Avg Loss: 0.17501554460397484
# 	Parameters used: [0.22883628 0.53348469 0.91569781]
# Iteration 2550/3000 -- Loss Output: 3.4418763456141233 -- Moving Avg Loss: 0.49763337669466495
# 	Parameters used: [0.79668664 0.1004599  0.48272647]
# Iteration 2700/3000 -- Loss Output: 0.056604239999810776 -- Moving Avg Loss: 0.05530020781787043
# 	Parameters used: [0.21232756 0.58887886 0.89780541]
# Iteration 2850/3000 -- Loss Output: 0.06875931213171997 -- Moving Avg Loss: 0.38164543654874644
# 	Parameters used: [0.33613458 0.29157224 0.02000948]
# Iteration 3000/3000 -- Loss Output: 0.06830958395723911 -- Moving Avg Loss: 1.72980560587881
# 	Parameters used: [0.29999522 0.68783047 0.00964285]
# [16:58:36] Analyzing optimization parameters for carly
# [16:59:01] Processing Cycloid: cilicia
# Iteration 150/3000 -- Loss Output: 3.1025520516701963 -- Moving Avg Loss: 0.2566640955161377
# 	Parameters used: [0.18631138 0.74857342 0.94169941]
# Iteration 300/3000 -- Loss Output: 0.066340954222744 -- Moving Avg Loss: 0.06052568198044294
# 	Parameters used: [0.52012772 0.25913741 0.35263872]
# Iteration 450/3000 -- Loss Output: 0.10187192317187499 -- Moving Avg Loss: 0.1448330203892303
# 	Parameters used: [0.12367895 0.85926287 0.99330317]
# Iteration 600/3000 -- Loss Output: 0.07549491794620874 -- Moving Avg Loss: 0.11525046764820253
# 	Parameters used: [0.19868466 0.61408902 0.10307462]
# Iteration 750/3000 -- Loss Output: 0.06532712621854334 -- Moving Avg Loss: 0.06200032468958706
# 	Parameters used: [0.41918335 0.88321578 0.33288214]
# Iteration 900/3000 -- Loss Output: 0.12158569759307636 -- Moving Avg Loss: 0.11419158853337585
# 	Parameters used: [0.75700722 0.70686707 0.68494804]
# Iteration 1050/3000 -- Loss Output: 0.08840015050391872 -- Moving Avg Loss: 0.09608787211408394
# 	Parameters used: [0.03758393 0.79319985 0.97831563]
# Iteration 1200/3000 -- Loss Output: 0.0370799322554827 -- Moving Avg Loss: 0.048720918396954936
# 	Parameters used: [0.38645178 0.35435546 0.34177085]
# Iteration 1350/3000 -- Loss Output: 0.08038066454570977 -- Moving Avg Loss: 0.10072552233224887
# 	Parameters used: [0.21878221 0.56434557 0.20211016]
# Iteration 1500/3000 -- Loss Output: 0.04824147522037297 -- Moving Avg Loss: 0.0823501225283193
# 	Parameters used: [0.74186865 0.64433662 0.74250839]
# Iteration 1650/3000 -- Loss Output: 0.09336943780584547 -- Moving Avg Loss: 0.08734076807891357
# 	Parameters used: [0.97866021 0.9233316  0.98768213]
# Iteration 1800/3000 -- Loss Output: 0.04947833441940979 -- Moving Avg Loss: 0.05678068616582609
# 	Parameters used: [0.34746972 0.62670778 0.37139135]
# Iteration 1950/3000 -- Loss Output: 0.12622198883223937 -- Moving Avg Loss: 0.11955848492544988
# 	Parameters used: [0.62921753 0.95856686 0.66308546]
# Iteration 2100/3000 -- Loss Output: 0.05947668355060291 -- Moving Avg Loss: 0.06089681746593676
# 	Parameters used: [0.85162685 0.74318798 0.89334246]
# Iteration 2250/3000 -- Loss Output: 0.05555572594178302 -- Moving Avg Loss: 0.05291533168327423
# 	Parameters used: [0.31165929 0.86455247 0.37102246]
# Iteration 2400/3000 -- Loss Output: 0.0815506150910732 -- Moving Avg Loss: 0.0982055084588866
# 	Parameters used: [0.61948219 0.85719443 0.68961007]
# Iteration 2550/3000 -- Loss Output: 0.04820289661348381 -- Moving Avg Loss: 0.07478400451524181
# 	Parameters used: [0.91747374 0.26645356 0.99801708]
# Iteration 2700/3000 -- Loss Output: 0.06695080770030856 -- Moving Avg Loss: 0.050588856798986795
# 	Parameters used: [0.21698802 0.61920208 0.30790845]
# Iteration 2850/3000 -- Loss Output: 0.07977974393738972 -- Moving Avg Loss: 0.07207050682659266
# 	Parameters used: [0.84581557 0.40357405 0.95843904]
# Iteration 3000/3000 -- Loss Output: 0.06006022164363309 -- Moving Avg Loss: 0.09523368098138844
# 	Parameters used: [0.36528514 0.13145812 0.49571685]
# [17:03:55] Analyzing optimization parameters for cilicia
# [17:04:25] Processing Cycloid: delphi
# Iteration 150/3000 -- Loss Output: 0.12031750464991167 -- Moving Avg Loss: 0.07803285617350468
# 	Parameters used: [0.90719499 0.82492511 0.5322643 ]
# Iteration 300/3000 -- Loss Output: 0.049893976330876076 -- Moving Avg Loss: 0.07464668255003817
# 	Parameters used: [0.30571377 0.60994262 0.67568101]
# Iteration 450/3000 -- Loss Output: 0.056321109596977774 -- Moving Avg Loss: 0.06853046714107994
# 	Parameters used: [0.02256145 0.81279698 0.47784206]
# Iteration 600/3000 -- Loss Output: 0.08008143865085243 -- Moving Avg Loss: 0.06468000688088736
# 	Parameters used: [0.92431071 0.36145071 0.94661583]
# Iteration 750/3000 -- Loss Output: 0.08680177493774298 -- Moving Avg Loss: 0.06519632730953723
# 	Parameters used: [0.2407141  0.09262057 0.89692444]
# Iteration 900/3000 -- Loss Output: 0.054170378113005124 -- Moving Avg Loss: 0.07021234334138525
# 	Parameters used: [0.210742   0.73722471 0.68951125]
# Iteration 1050/3000 -- Loss Output: 0.06899276907137454 -- Moving Avg Loss: 0.07277371752829713
# 	Parameters used: [0.79124934 0.36965729 0.13132019]
# Iteration 1200/3000 -- Loss Output: 0.07562710868964902 -- Moving Avg Loss: 0.06408675395364162
# 	Parameters used: [0.61110535 0.83687899 0.86288368]
# Iteration 1350/3000 -- Loss Output: 0.08163775743470665 -- Moving Avg Loss: 0.062484280927182924
# 	Parameters used: [0.7335965  0.85488388 0.91717251]
# Iteration 1500/3000 -- Loss Output: 0.045214488577761086 -- Moving Avg Loss: 0.06297362740049894
# 	Parameters used: [0.64070531 0.81921583 0.78656098]
# Iteration 1650/3000 -- Loss Output: 0.05877805049793136 -- Moving Avg Loss: 0.06571338371874806
# 	Parameters used: [0.82932814 0.2244926  0.81666998]
# Iteration 1800/3000 -- Loss Output: 0.09718571492301652 -- Moving Avg Loss: 0.06162824992393365
# 	Parameters used: [0.9950925  0.19520163 0.90648875]
# Iteration 1950/3000 -- Loss Output: 0.052946767491779054 -- Moving Avg Loss: 0.06403700060515155
# 	Parameters used: [0.44912067 0.35756587 0.25596432]
# Iteration 2100/3000 -- Loss Output: 0.09624814933373355 -- Moving Avg Loss: 0.09212839213866847
# 	Parameters used: [0.30544846 0.94598527 0.14819712]
# Iteration 2250/3000 -- Loss Output: 0.04521242445600913 -- Moving Avg Loss: 0.0549953846148565
# 	Parameters used: [0.56162608 0.10899224 0.35432035]
# Iteration 2400/3000 -- Loss Output: 0.06133323157417441 -- Moving Avg Loss: 0.06890693665653279
# 	Parameters used: [0.95480494 0.56294962 0.70215553]
# Iteration 2550/3000 -- Loss Output: 0.06916765132751646 -- Moving Avg Loss: 0.07394581119681477
# 	Parameters used: [0.89938173 0.46524445 0.61609533]
# Iteration 2700/3000 -- Loss Output: 0.06416489302656599 -- Moving Avg Loss: 0.06004895711581778
# 	Parameters used: [0.19772657 0.72607632 0.86550721]
# Iteration 2850/3000 -- Loss Output: 0.07209330936848198 -- Moving Avg Loss: 0.09005371814176698
# 	Parameters used: [0.56830011 0.67316113 0.18513871]
# Iteration 3000/3000 -- Loss Output: 0.10964474711187704 -- Moving Avg Loss: 0.06733154684072125
# 	Parameters used: [0.92413764 0.65849942 0.48905902]
# [17:09:06] Analyzing optimization parameters for delphi
# [17:09:30] Processing Cycloid: dirk
# Iteration 150/3000 -- Loss Output: 23.300991359423733 -- Moving Avg Loss: 10.59529920240434
# 	Parameters used: [0.83936696 0.0660118  0.28404399]
# Iteration 300/3000 -- Loss Output: 5.430850568408622 -- Moving Avg Loss: 15.061280542802155
# 	Parameters used: [0.58482162 0.57878731 0.03144823]
# Iteration 450/3000 -- Loss Output: 17.413582357827476 -- Moving Avg Loss: 14.000245935659757
# 	Parameters used: [0.66409181 0.31481041 0.11260638]
# Iteration 600/3000 -- Loss Output: 0.9371163349028698 -- Moving Avg Loss: 4.370159213051962
# 	Parameters used: [0.03291473 0.50030554 0.488228  ]
# Iteration 750/3000 -- Loss Output: 13.818507266870386 -- Moving Avg Loss: 11.395650735981754
# 	Parameters used: [0.64658595 0.16880435 0.10173978]
# Iteration 900/3000 -- Loss Output: 19.07759915191211 -- Moving Avg Loss: 2.8829334854258257
# 	Parameters used: [0.44902575 0.51100282 0.90550143]
# Iteration 1050/3000 -- Loss Output: 0.2507617407492014 -- Moving Avg Loss: 9.090460272142616
# 	Parameters used: [0.97838944 0.07916989 0.58202823]
# Iteration 1200/3000 -- Loss Output: 15.043984637110174 -- Moving Avg Loss: 6.140564620188131
# 	Parameters used: [0.23155032 0.14635558 0.82885747]
# Iteration 1350/3000 -- Loss Output: 0.06489359809025584 -- Moving Avg Loss: 0.07761995817578651
# 	Parameters used: [0.95071635 0.82338688 0.54697287]
# Iteration 1500/3000 -- Loss Output: 3.029337274400588 -- Moving Avg Loss: 0.4729776878857266
# 	Parameters used: [0.8512322  0.72684755 0.44709371]
# Iteration 1650/3000 -- Loss Output: 0.08667172909191856 -- Moving Avg Loss: 0.10543711423661843
# 	Parameters used: [0.47978794 0.3663697  0.07417867]
# Iteration 1800/3000 -- Loss Output: 2.157352917588559 -- Moving Avg Loss: 0.45078359558803066
# 	Parameters used: [0.43301244 0.32097505 0.02721798]
# Iteration 1950/3000 -- Loss Output: 0.15362602271114037 -- Moving Avg Loss: 0.579464469102604
# 	Parameters used: [0.32738984 0.21847002 0.92122586]
# Iteration 2100/3000 -- Loss Output: 0.11259958002324312 -- Moving Avg Loss: 0.5182175105266065
# 	Parameters used: [0.87392523 0.33493468 0.46554187]
# Iteration 2250/3000 -- Loss Output: 0.16504635119458846 -- Moving Avg Loss: 7.48558418454868
# 	Parameters used: [0.07154186 0.21015042 0.66124235]
# Iteration 2400/3000 -- Loss Output: 0.08448423557597282 -- Moving Avg Loss: 0.3861864373344115
# 	Parameters used: [0.40833837 0.50939677 0.99647398]
# Iteration 2550/3000 -- Loss Output: 0.5593464753787937 -- Moving Avg Loss: 0.9507832907393634
# 	Parameters used: [0.90430892 0.01429691 0.49121838]
# Iteration 2700/3000 -- Loss Output: 0.093273090041598 -- Moving Avg Loss: 0.6834252010312314
# 	Parameters used: [0.38306257 0.38196735 0.96875464]
# Iteration 2850/3000 -- Loss Output: 0.24479736073336433 -- Moving Avg Loss: 7.603652249198002
# 	Parameters used: [0.99779501 0.122853   0.58075164]
# Iteration 3000/3000 -- Loss Output: 0.0677325056337415 -- Moving Avg Loss: 10.5411732267018
# 	Parameters used: [0.04350678 0.86391855 0.62013167]
# [17:14:23] Analyzing optimization parameters for dirk
# [17:14:52] Processing Cycloid: mira
# Iteration 150/3000 -- Loss Output: 2.3952669921091663 -- Moving Avg Loss: 10.138811123214499
# 	Parameters used: [0.04546628 0.33783328 0.14491173]
# Iteration 300/3000 -- Loss Output: 24.042781163910128 -- Moving Avg Loss: 9.677760307800337
# 	Parameters used: [0.91078658 0.83547523 0.98719151]
# Iteration 450/3000 -- Loss Output: 0.16067680065686965 -- Moving Avg Loss: 0.1585249279167341
# 	Parameters used: [0.27221722 0.77810899 0.30461676]
# Iteration 600/3000 -- Loss Output: 0.2035321555245529 -- Moving Avg Loss: 0.18573937309279004
# 	Parameters used: [0.78569047 0.58886861 0.81903177]
# Iteration 750/3000 -- Loss Output: 0.15037734244631462 -- Moving Avg Loss: 0.15289129232316553
# 	Parameters used: [0.27454063 0.84412818 0.29753003]
# Iteration 900/3000 -- Loss Output: 0.19639021967814585 -- Moving Avg Loss: 0.7685717368945714
# 	Parameters used: [0.76207662 0.99399383 0.78435251]
# Iteration 1050/3000 -- Loss Output: 0.08415326021900098 -- Moving Avg Loss: 0.5687793996243223
# 	Parameters used: [0.24620608 0.47862583 0.25894192]
# Iteration 1200/3000 -- Loss Output: 0.14156737425130883 -- Moving Avg Loss: 0.1360468339246284
# 	Parameters used: [0.28890705 0.52118553 0.3015839 ]
# Iteration 1350/3000 -- Loss Output: 0.8744178305929693 -- Moving Avg Loss: 0.24175937194538705
# 	Parameters used: [0.80984051 0.85398733 0.8217857 ]
# Iteration 1500/3000 -- Loss Output: 0.19906618755158176 -- Moving Avg Loss: 3.465549643115892
# 	Parameters used: [0.27432359 0.54758168 0.31492312]
# Iteration 1650/3000 -- Loss Output: 1.1337374139952534 -- Moving Avg Loss: 3.0658601209109393
# 	Parameters used: [0.21587437 0.74167315 0.25354136]
# Iteration 1800/3000 -- Loss Output: 0.13158098082294276 -- Moving Avg Loss: 0.11822679176159634
# 	Parameters used: [0.272611   0.24843366 0.31013256]
# Iteration 1950/3000 -- Loss Output: 0.14632625419795992 -- Moving Avg Loss: 0.9266323897309172
# 	Parameters used: [0.30565551 0.30396983 0.34166029]
# Iteration 2100/3000 -- Loss Output: 0.1009557847836834 -- Moving Avg Loss: 0.15748990780409156
# 	Parameters used: [0.68894069 0.00668277 0.72464352]
# Iteration 2250/3000 -- Loss Output: 0.2103385513833712 -- Moving Avg Loss: 0.40416483545812065
# 	Parameters used: [0.7485109  0.76539995 0.78416681]
# Iteration 2400/3000 -- Loss Output: 14.45222994408754 -- Moving Avg Loss: 6.481843955485288
# 	Parameters used: [0.88704645 0.65791321 0.92259339]
# Iteration 2550/3000 -- Loss Output: 0.13675766381060578 -- Moving Avg Loss: 0.11823510856224019
# 	Parameters used: [0.25162496 0.36653405 0.29060436]
# Iteration 2700/3000 -- Loss Output: 0.13185913852350284 -- Moving Avg Loss: 0.1309855866720099
# 	Parameters used: [0.27578002 0.34777031 0.31474036]
# Iteration 2850/3000 -- Loss Output: 0.851564592383917 -- Moving Avg Loss: 3.882973937473338
# 	Parameters used: [0.66764341 0.04322058 0.70629515]
# Iteration 3000/3000 -- Loss Output: 0.06773579078254356 -- Moving Avg Loss: 0.08381551061444278
# 	Parameters used: [0.71155731 0.0090871  0.75017449]
# [17:19:33] Analyzing optimization parameters for mira
# [17:19:58] Processing Cycloid: odessa
# Iteration 150/3000 -- Loss Output: 3.043809920018817 -- Moving Avg Loss: 0.5483923277263978
# 	Parameters used: [0.1181314  0.00824054 0.49748152]
# Iteration 300/3000 -- Loss Output: 15.888291541495832 -- Moving Avg Loss: 7.441960407049658
# 	Parameters used: [0.77424694 0.70358022 0.1614592 ]
# Iteration 450/3000 -- Loss Output: 8.592051775667558 -- Moving Avg Loss: 3.6479452562357926
# 	Parameters used: [0.88442479 0.77702293 0.30753575]
# Iteration 600/3000 -- Loss Output: 0.12236552850739106 -- Moving Avg Loss: 0.1343022283552334
# 	Parameters used: [0.13240325 0.02790135 0.58972061]
# Iteration 750/3000 -- Loss Output: 0.13558132943560033 -- Moving Avg Loss: 2.902338571126665
# 	Parameters used: [0.77724829 0.03698748 0.24146891]
# Iteration 900/3000 -- Loss Output: 0.10564675798302178 -- Moving Avg Loss: 0.11627343801714668
# 	Parameters used: [0.07922823 0.08145069 0.54889113]
# Iteration 1050/3000 -- Loss Output: 0.23575197862703262 -- Moving Avg Loss: 0.2271750249394578
# 	Parameters used: [0.61555211 0.276622   0.08583084]
# Iteration 1200/3000 -- Loss Output: 0.30337746992064296 -- Moving Avg Loss: 0.31263284751723736
# 	Parameters used: [0.12607376 0.39391716 0.61467965]
# Iteration 1350/3000 -- Loss Output: 0.15424303157857425 -- Moving Avg Loss: 2.2627266062187665
# 	Parameters used: [0.22615633 0.60554627 0.74231511]
# Iteration 1500/3000 -- Loss Output: 0.08972417694846084 -- Moving Avg Loss: 0.10672143240978695
# 	Parameters used: [0.02004809 0.4030974  0.54259752]
# Iteration 1650/3000 -- Loss Output: 0.08963815472783884 -- Moving Avg Loss: 0.10706824272444544
# 	Parameters used: [0.66069936 0.05044926 0.19500472]
# Iteration 1800/3000 -- Loss Output: 0.16017343107683324 -- Moving Avg Loss: 0.1466566848978374
# 	Parameters used: [0.5122734  0.8676324  0.05142995]
# Iteration 1950/3000 -- Loss Output: 0.10745904609184885 -- Moving Avg Loss: 0.5698874631272536
# 	Parameters used: [0.00293385 0.36725706 0.55785384]
# Iteration 2100/3000 -- Loss Output: 0.05766563869967699 -- Moving Avg Loss: 0.07813715269133287
# 	Parameters used: [0.13593551 0.27557057 0.71710328]
# Iteration 2250/3000 -- Loss Output: 0.09165168966526711 -- Moving Avg Loss: 0.11035324498954248
# 	Parameters used: [0.03015206 0.17162838 0.61455469]
# Iteration 2400/3000 -- Loss Output: 2.1961531924100206 -- Moving Avg Loss: 0.43378318140432875
# 	Parameters used: [0.91874156 0.06206851 0.5064636 ]
# Iteration 2550/3000 -- Loss Output: 0.07483341184336106 -- Moving Avg Loss: 0.0730136057554697
# 	Parameters used: [0.44089054 0.32869103 0.04306677]
# Iteration 2700/3000 -- Loss Output: 0.06685001624111907 -- Moving Avg Loss: 0.07621357037381774
# 	Parameters used: [0.90832998 0.32418306 0.5441187 ]
# Iteration 2850/3000 -- Loss Output: 0.08649342581719517 -- Moving Avg Loss: 0.07343334634311903
# 	Parameters used: [0.5004731  0.66333443 0.14844227]
# Iteration 3000/3000 -- Loss Output: 0.059299311175115964 -- Moving Avg Loss: 0.06306169116103623
# 	Parameters used: [0.39207353 0.55678722 0.04329177]
# [17:24:28] Analyzing optimization parameters for odessa
# [17:24:47] Processing Cycloid: sidon
# Iteration 150/3000 -- Loss Output: 0.05886317892078031 -- Moving Avg Loss: 0.07665112316573866
# 	Parameters used: [0.18470407 0.47426296 0.00184525]
# Iteration 300/3000 -- Loss Output: 0.0839276596711967 -- Moving Avg Loss: 0.06899087546399474
# 	Parameters used: [0.08402675 0.10682627 0.64104414]
# Iteration 450/3000 -- Loss Output: 0.06674900350689 -- Moving Avg Loss: 0.06504063930568982
# 	Parameters used: [0.32947595 0.60374262 0.63111599]
# Iteration 600/3000 -- Loss Output: 0.040316037863205915 -- Moving Avg Loss: 0.07113212097060663
# 	Parameters used: [0.57366301 0.31484721 0.75733318]
# Iteration 750/3000 -- Loss Output: 0.05082657913309403 -- Moving Avg Loss: 0.07098575558384455
# 	Parameters used: [0.72505686 0.00744895 0.84929869]
# Iteration 900/3000 -- Loss Output: 0.055829799601878664 -- Moving Avg Loss: 0.07267381935560485
# 	Parameters used: [0.2456068  0.16595966 0.32139468]
# Iteration 1050/3000 -- Loss Output: 0.07264989149840005 -- Moving Avg Loss: 0.07693415448784355
# 	Parameters used: [0.70024686 0.50098698 0.96154138]
# Iteration 1200/3000 -- Loss Output: 0.07275976218506662 -- Moving Avg Loss: 0.06429569046440785
# 	Parameters used: [0.35813755 0.24134903 0.55106373]
# Iteration 1350/3000 -- Loss Output: 0.06879470966526653 -- Moving Avg Loss: 0.0814926504872839
# 	Parameters used: [0.25977082 0.23469567 0.42526854]
# Iteration 1500/3000 -- Loss Output: 0.09885814418550096 -- Moving Avg Loss: 0.06647000444741619
# 	Parameters used: [0.39988686 0.08763289 0.54223227]
# Iteration 1650/3000 -- Loss Output: 0.0682081883251693 -- Moving Avg Loss: 0.07358470627648597
# 	Parameters used: [0.8568235  0.01575784 0.98455898]
# Iteration 1800/3000 -- Loss Output: 0.06230059493709416 -- Moving Avg Loss: 0.07768345618861805
# 	Parameters used: [0.26563068 0.29904948 0.37859457]
# Iteration 1950/3000 -- Loss Output: 0.04480152144263758 -- Moving Avg Loss: 0.057187554804385365
# 	Parameters used: [0.67158001 0.10856791 0.76936285]
# Iteration 2100/3000 -- Loss Output: 0.10579481547960137 -- Moving Avg Loss: 0.07362305294060684
# 	Parameters used: [0.99113538 0.8745855  0.0698477 ]
# Iteration 2250/3000 -- Loss Output: 0.05755265791138336 -- Moving Avg Loss: 0.054992936738119585
# 	Parameters used: [0.19145214 0.08586    0.24789535]
# Iteration 2400/3000 -- Loss Output: 0.05541427330991578 -- Moving Avg Loss: 0.066688710349111
# 	Parameters used: [0.8024639  0.07105698 0.82682709]
# Iteration 2550/3000 -- Loss Output: 0.0983206076054221 -- Moving Avg Loss: 0.06862950942736581
# 	Parameters used: [0.54347451 0.46682711 0.62698136]
# Iteration 2700/3000 -- Loss Output: 0.10379020461167171 -- Moving Avg Loss: 0.07103511166318847
# 	Parameters used: [0.52996575 0.87082605 0.58809028]
# Iteration 2850/3000 -- Loss Output: 0.06711667303974138 -- Moving Avg Loss: 0.06930077003103001
# 	Parameters used: [0.08841054 0.40401211 0.14097818]
# Iteration 3000/3000 -- Loss Output: 0.07686572061276989 -- Moving Avg Loss: 0.09315665725123905
# 	Parameters used: [0.9517859  0.79637642 0.90990124]
# [17:30:18] Analyzing optimization parameters for sidon
# [17:31:03] Processing Cycloid: tyrrel
# Iteration 150/3000 -- Loss Output: 4.199630216097773 -- Moving Avg Loss: 1.3015473918292864
# 	Parameters used: [0.22980377 0.55626584 0.94154896]
# Iteration 300/3000 -- Loss Output: 6.651578161153479 -- Moving Avg Loss: 3.9851887176190166
# 	Parameters used: [0.91259412 0.8944227  0.58756031]
# Iteration 450/3000 -- Loss Output: 0.4349022854744789 -- Moving Avg Loss: 0.14661746804046286
# 	Parameters used: [0.15812631 0.34800299 0.83030734]
# Iteration 600/3000 -- Loss Output: 0.7015531146170895 -- Moving Avg Loss: 0.22618103190028582
# 	Parameters used: [0.71676719 0.8837     0.38275018]
# Iteration 750/3000 -- Loss Output: 0.05993008598854969 -- Moving Avg Loss: 0.09364422814085216
# 	Parameters used: [0.151594   0.98259206 0.81398674]
# Iteration 900/3000 -- Loss Output: 6.430386729736929 -- Moving Avg Loss: 5.752807371626899
# 	Parameters used: [0.95998259 0.79684975 0.6210833 ]
# Iteration 1050/3000 -- Loss Output: 0.0725608534782748 -- Moving Avg Loss: 0.6648931782843871
# 	Parameters used: [0.61867527 0.45293789 0.27748686]
# Iteration 1200/3000 -- Loss Output: 0.05107437470785008 -- Moving Avg Loss: 0.07585346690854497
# 	Parameters used: [0.65285757 0.48679524 0.31166937]
# Iteration 1350/3000 -- Loss Output: 0.0820688462262508 -- Moving Avg Loss: 0.09893320466551997
# 	Parameters used: [0.68604614 0.51966851 0.34485812]
# Iteration 1500/3000 -- Loss Output: 0.08945274119631788 -- Moving Avg Loss: 0.06953822347456931
# 	Parameters used: [0.14040705 0.97723365 0.80669352]
# Iteration 1650/3000 -- Loss Output: 0.06846872267901442 -- Moving Avg Loss: 0.06908995743734252
# 	Parameters used: [0.16294143 0.99956749 0.82923745]
# Iteration 1800/3000 -- Loss Output: 0.07159544969402303 -- Moving Avg Loss: 0.0713652711267399
# 	Parameters used: [0.64898922 0.89209819 0.31248461]
# Iteration 1950/3000 -- Loss Output: 0.05561804019954283 -- Moving Avg Loss: 0.0693506825458186
# 	Parameters used: [0.67741709 0.92026345 0.34091237]
# Iteration 2100/3000 -- Loss Output: 0.04999616556874639 -- Moving Avg Loss: 0.14930650370864781
# 	Parameters used: [0.72039272 0.9628421  0.38388781]
# Iteration 2250/3000 -- Loss Output: 0.813301881396424 -- Moving Avg Loss: 0.31732813908399926
# 	Parameters used: [0.20494294 0.61821529 0.8698526 ]
# Iteration 2400/3000 -- Loss Output: 0.0787682299860554 -- Moving Avg Loss: 0.0725117130933099
# 	Parameters used: [0.64379163 0.57642905 0.30610327]
# Iteration 2550/3000 -- Loss Output: 0.08300876777137448 -- Moving Avg Loss: 0.06729997160334102
# 	Parameters used: [0.67552542 0.60787736 0.33783612]
# Iteration 2700/3000 -- Loss Output: 0.1656302737862888 -- Moving Avg Loss: 3.7919757877193434
# 	Parameters used: [0.13624028 0.24168148 0.79891899]
# Iteration 2850/3000 -- Loss Output: 0.06255036039129232 -- Moving Avg Loss: 0.06599113729786278
# 	Parameters used: [0.67593472 0.77640116 0.33365746]
# Iteration 3000/3000 -- Loss Output: 9.256104337142165 -- Moving Avg Loss: 1.9579585462985352
# 	Parameters used: [0.77576013 0.87534166 0.43347196]
# [17:36:34] Analyzing optimization parameters for tyrrel
# [17:37:18] Processing Cycloid: yaphet
# Iteration 150/3000 -- Loss Output: 0.07361802102381974 -- Moving Avg Loss: 3.1555021441694735
# 	Parameters used: [0.6413433  0.21174757 0.35204003]
# Iteration 300/3000 -- Loss Output: 10.817319001314475 -- Moving Avg Loss: 2.8023758819405886
# 	Parameters used: [0.36815802 0.23742782 0.08345697]
# Iteration 450/3000 -- Loss Output: 0.07238433932013318 -- Moving Avg Loss: 2.6500172624573413
# 	Parameters used: [0.50908214 0.42502996 0.2300888 ]
# Iteration 600/3000 -- Loss Output: 0.10101167000476272 -- Moving Avg Loss: 1.6925429648301213
# 	Parameters used: [0.52477246 0.19876255 0.25800261]
# Iteration 750/3000 -- Loss Output: 0.058565323412707156 -- Moving Avg Loss: 0.061576729835667046
# 	Parameters used: [0.03739365 0.35712584 0.77506185]
# Iteration 900/3000 -- Loss Output: 0.04427191567766169 -- Moving Avg Loss: 3.915601102593921
# 	Parameters used: [0.61561951 0.95154833 0.35441414]
# Iteration 1050/3000 -- Loss Output: 0.10399606069851049 -- Moving Avg Loss: 0.08552839821606356
# 	Parameters used: [0.0415922  0.10151523 0.78169135]
# Iteration 1200/3000 -- Loss Output: 0.047175595471633844 -- Moving Avg Loss: 1.6228173464214988
# 	Parameters used: [0.12161403 0.68796977 0.86390591]
# Iteration 1350/3000 -- Loss Output: 0.10577339547521973 -- Moving Avg Loss: 0.09569024606800713
# 	Parameters used: [0.95798316 0.52404383 0.70026318]
# Iteration 1500/3000 -- Loss Output: 2.697589582642823 -- Moving Avg Loss: 0.546002196038081
# 	Parameters used: [0.91245944 0.62632738 0.65536524]
# Iteration 1650/3000 -- Loss Output: 0.06926387598612961 -- Moving Avg Loss: 0.07025196574198472
# 	Parameters used: [0.01888344 0.6471319  0.76220091]
# Iteration 1800/3000 -- Loss Output: 1.000971094427954 -- Moving Avg Loss: 0.4372375169500108
# 	Parameters used: [0.92991457 0.55791534 0.67292188]
# Iteration 1950/3000 -- Loss Output: 0.09928037011360098 -- Moving Avg Loss: 0.08754223279655111
# 	Parameters used: [0.00105316 0.3245735  0.74669291]
# Iteration 2100/3000 -- Loss Output: 0.0885256949092324 -- Moving Avg Loss: 0.08381183824291288
# 	Parameters used: [0.98495928 0.59792661 0.73080644]
# Iteration 2250/3000 -- Loss Output: 0.09552233756381943 -- Moving Avg Loss: 0.08234601401090423
# 	Parameters used: [3.27936063e-04 2.44911312e-01 7.46552639e-01]
# Iteration 2400/3000 -- Loss Output: 0.11740669878254338 -- Moving Avg Loss: 0.19093592529197786
# 	Parameters used: [0.94761265 0.50575228 0.6931218 ]
# Iteration 2550/3000 -- Loss Output: 0.04349692589417753 -- Moving Avg Loss: 0.04950012744488269
# 	Parameters used: [0.11021473 0.46314938 0.85739368]
# Iteration 2700/3000 -- Loss Output: 0.09473394541092142 -- Moving Avg Loss: 0.10811659564424689
# 	Parameters used: [0.96895143 0.32186605 0.7161188 ]
# Iteration 2850/3000 -- Loss Output: 0.05814157871149993 -- Moving Avg Loss: 0.06545622639944543
# 	Parameters used: [0.03109054 0.29100629 0.77848154]
# Iteration 3000/3000 -- Loss Output: 0.0670956076745915 -- Moving Avg Loss: 0.06397287765715083
# 	Parameters used: [0.08308876 0.21913389 0.83164778]
# [17:41:50] Analyzing optimization parameters for yaphet

# %% [markdown]
# ## Experiments

# %%
opt = pd.DataFrame(output[3], columns=['loss', 'phase', 'obliquity', 'longitude'])

df = opt.loc[opt['loss'] < 1]

# Find loss threshold
loss_hist = np.histogram(df['loss'], bins=100, density=True)
index = np.argmax(loss_hist[0])
threshold = loss_hist[1][index + 1]

# %%
best_fits = df.loc[df['loss'] <= threshold]
param_hist = np.histogramdd((best_fits['phase'], best_fits['obliquity'], best_fits['longitude']), bins=50, density=True)

# param_hist = param_hist = np.histogram2d(best_fits['phase'], best_fits['obliquity'], bins=50, density=True)

# %%
index = np.unravel_index(np.argmax(param_hist[0]), param_hist[0].shape)
phase = np.average(param_hist[1][0][index[0]:index[0] + 2])
obliquity = np.average(param_hist[1][1][index[1]:index[1] + 2])
longitude = np.average(param_hist[1][2][index[2]:index[2] + 2])

# %%
phase, obliquity, longitude

# %%
param_hist_3d[1][2][index[2]:index[2] + 2]

# %% [markdown]
# loss_hist[0]

# %%
np.argmax(loss_hist[0])

# %% [markdown]
# Compare 2d vs dd histogram values

# %%
# 2D
param_hist = np.histogram2d(best_fits['phase'], best_fits['obliquity'], bins=50, density=True)
index = np.unravel_index(np.argmax(param_hist[0]), param_hist[0].shape)
phase = np.average(param_hist[1][index[0]:index[0] + 2])
obliquity = np.average(param_hist[2][index[1]:index[1] + 2])

print('2D')
display((phase, obliquity))

#3d
param_hist = np.histogramdd((best_fits['phase'], best_fits['obliquity'], best_fits['longitude']), bins=50, density=True)
index = np.unravel_index(np.argmax(param_hist[0]), param_hist[0].shape)
phase = np.average(param_hist[1][0][index[0]:index[0] + 2])
obliquity = np.average(param_hist[1][1][index[1]:index[1] + 2])
longitude = np.average(param_hist[1][2][index[2]:index[2] + 2])

print('3D')
display((phase, obliquity, longitude))

# %% [markdown]
# ### K-Means Clustering

# %%
from sklearn.cluster import KMeans

def find_best_parameters_kmeans(optimize_history):
    # Filter by low loss
    threshold = optimize_history['loss'].quantile(0.10)
    best_fits = optimize_history.loc[optimize_history['loss'] <= threshold]

    # Applying K-Means clustering
    kmeans = KMeans(n_clusters=5).fit(best_fits[['phase', 'obliquity']])

    # Finding the cluster with the highest frequency
    labels, counts = np.unique(kmeans.labels_, return_counts=True)
    most_common_cluster = labels[np.argmax(counts)]

    # Calculating the centroid of the most common cluster
    phase, obliquity = kmeans.cluster_centers_[most_common_cluster]

    return phase, obliquity

# %%
find_best_parameters_kmeans(opt)

# %%
opt['loss'].quantile(0.10)
df = opt[opt['loss'] <= 0.05409826806047949]
print(len(df))

kmeans = KMeans(n_clusters=6, n_init='auto').fit(df[['phase', 'obliquity', 'longitude']])

# %%
np.unique(kmeans.labels_, return_counts=True)
labels, counts = np.unique(kmeans.labels_, return_counts=True)
most_common_cluster = labels[np.argmax(counts)]

# %%
kmeans.cluster_centers_[most_common_cluster]

# %%
kmeans.inertia_

# %%
threshold = opt['loss'].quantile(0.10)
best_fits = opt.loc[opt['loss'] <= threshold]

# %%
len(best_fits)

# %%
23 // 10
