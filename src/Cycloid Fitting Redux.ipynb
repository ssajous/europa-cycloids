# %% [markdown]
# # Cycloid Fitting
#
# ### Simplified to reduce notebook size

# %% [markdown]
# ## Load Cyloid Data Points and Bezier Curves

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import curves.bezier as bezier
import curves.fitCurves as fit
import StressTools as tools
import utils
import fitting
import cycloidData
from scipy import stats
from os import path
from datetime import datetime

interior = utils.import_interior('interior1')

TOLERANCE = 1

cycloids = cycloidData.load_all_cycloids()
highResCycloids = cycloidData.load_all_cycloids(points_per_curve=1000)

min_vals = np.array([0, 0.1, 0])
max_vals = np.array([360, 1, 360])
constraints = [
    dict(wrapValue=True, minValue=1e-8, maxValue=1),
    dict(minValue=1e-8, maxValue=1, unstick=True),
    dict(wrapValue=True, minValue=0, maxValue=1)
]

tight_obliquity_contstraints = [
        dict(wrapValue=True, minValue=1e-8, maxValue=1),
        dict(minValue=0.62, maxValue=0.82, unstick=True),
        dict(wrapValue=True, minValue=0, maxValue=1)
    ]

def getConstraints(obliquity, longitude_max=1):
    return [
        dict(wrapValue=True, minValue=1e-8, maxValue=1),
        dict(minValue=obliquity, maxValue=obliquity, unstick=False),
        dict(wrapValue=True, minValue=0, maxValue=longitude_max)
    ]

def get_longitude_only_constraints(obliquity, phase):
    return [
        dict(minValue=phase, maxValue=phase, unstick=False),
        dict(minValue=obliquity, maxValue=obliquity, unstick=False),
        dict(wrapValue=True, minValue=0, maxValue=1)
    ]

# %% [markdown]
# ### Helper Functions

# %%
def logmessage(msg):
    now = datetime.now()
    timestamp = now.strftime("%H:%M:%S")
    
    print(f'[{timestamp}] {msg}')
    

def translate_params(params, minVals, maxVals):
    if len(params) == 3:
        variables = params * (max_vals - min_vals) + min_vals # denormalize
    else:
        variables = params * (max_vals[0:2:] - min_vals[0:2:]) + min_vals[0:2:]

    return variables

def setChartXLimit(points, plt):
    BUFFER_PERCENT = 0.025

    first = points['lon'].max()
    last = points['lon'].min()

    buffer = (first - last) * BUFFER_PERCENT

    plt.xlim(first + buffer, last - buffer)


def check_fit(params, minVals, maxVals, curve, interior, tolerance=0.25, title='',
              verbose=True, path='./output/stressfield.csv.gz'):

    if len(params) == 3:
        variables = params * (max_vals - min_vals) + min_vals # denormalize
    else:
        variables = params * (max_vals[0:2:] - min_vals[0:2:]) + min_vals[0:2:]

    data, loss = fitting.match_stresses(curve,
                                        variables,
                                        interior,
                                        save_stress_field=True,
                                        path=path)
    if verbose:
        plt.figure()
        plt.title(f'{title} - Orientation Match')
        fit_points = data.loc[data['deltaHeading'] < tolerance].copy()

        if len(variables) >= 3:
            fit_points['lon'] = fit_points['lon'] - variables[2]

        plt.plot(curve['lon'], curve['lat'])
        setChartXLimit(curve, plt)

        plt.scatter(fit_points['lon'], fit_points['lat'], alpha=0.3, color='green')

        plt.figure()
        plt.title(f'{title} - Stress Magnitude')
        plt.scatter(fit_points['pointNumber'], fit_points['stress'])

        print(np.array(variables))

    return data

def plot_time(data):
    timeData = data.copy()
    time = np.array(timeData['time'])
    time[time < 180] = time[time < 180] + 360
    timeData['time'] = time

    plt.figure()
    plt.scatter(timeData['pointNumber'], timeData['time'],s=1)
    plt.title("Time")

def analyze_fit(opt, curve, tolerance, name=''):
    plt.figure()
    plt.title('Optimizer Loss Values')
    plt.plot(opt[0])

    display(opt[1])
    display(opt[2])

    params = opt[1]['parameters']
    bestCase = check_fit(params, min_vals, max_vals, curve, interior, tolerance=tolerance,
                         title=f'{name} Best Fit')

    params = opt[2]['parameters']
    finalCase = check_fit(params, min_vals, max_vals, curve, interior, tolerance=tolerance,
                         title=f'{name} Final Fit')


    # Plot time progression
    plot_time(bestCase)

    return bestCase, finalCase

def analyze_params(params, curve, tolerance, name='', verbose=True, folder='./output/', suffix=''):
    fieldPath = path.join(folder, f'{name}{suffix}StressField.csv.gz')
    results = check_fit(params, min_vals, max_vals, curve, interior, tolerance=tolerance,
                       title=f'{name} Highest Probability Fit', verbose=verbose, path=fieldPath)

    if verbose:
        plot_time(results)

    return results

def direct_fit(curve, tolerance, show_plots=True, params=[0, 0, 0]):
    data, loss = fitting.match_stresses(curve, params, interior)
    fit_points = data.loc[data['deltaHeading'] < tolerance].copy()

    if show_plots:
        plt.figure()
        plt.plot(curve['lon'], curve['lat'])
        setChartXLimit(curve, plt)

        plt.scatter(fit_points['lon'], fit_points['lat'], alpha=0.3, color='green')
        plt.figure()
        plt.scatter(fit_points['pointNumber'], fit_points['stress'])

        plot_time(data)

    return data, loss

def process_cycloid(curve,
                    name,
                    paramCount = 2,
                    analysisCurve=None,
                    folder='./output/',
                    iterations=500,
                    constraints=tight_obliquity_contstraints,
                    verbose=True):

    logmessage(f'Processing Cycloid: {name}')
    plt.close('all')
    numParams = paramCount
    start_params = [np.random.rand() for iter in range(numParams)]
    start_params[1] = 0.67

    optimizer = fitting.Adam(alpha=0.05)

    opt = optimizer.minimize(
        fitting.test_stress_parameters,
        curve,
        start_params,
        interior,
        constraints=constraints,
        max_iterations=iterations,
        verbose=verbose,
        batch_size=16
    )

    params = fitting.find_best_parameters(opt)
    fullCurve = analysisCurve if analysisCurve is not None else curve
    
    logmessage(f'Analyzing optimization parameters for {name}')
    bestFit = analyze_params(np.array(params), fullCurve, 0.25, name, verbose, folder)

    cols = ['loss', 'phase', 'obliquity']
    df = pd.DataFrame(opt[3], columns=cols).copy()

    df['phase'] = df['phase'] * (max_vals[0] - min_vals[0]) + min_vals[0]
    df['obliquity'] = df['obliquity'] * (max_vals[1] - min_vals[1]) + min_vals[1]

    df.to_csv(f'{folder}{name}Fits.csv.gz', index=False, encoding='utf-8', compression='gzip')
    bestFit.to_csv(f'{folder}{name}BestFit.csv.gz', index=False, encoding='utf-8', compression='gzip')
    
def process_cycloid_by_name(name, folder='./output/', iterations=5000, constraints=constraints, verbose=False):
    process_cycloid(cycloids[name].curve,
                    name,
#                     analysisCurve=highResCycloids[name].curve,
                    folder=folder,
                    iterations=iterations,
                    constraints=constraints,
                    verbose=verbose)

def process_cycloid_top_fits(curve,
                    name,
                    paramCount = 2,
                    analysisCurve=None,
                    folder='./output/',
                    iterations=500,
                    constraints=constraints,
                    verbose=True,
                    number_of_fits=5):

    numParams = paramCount
    start_params = [np.random.rand() for iter in range(numParams)]
    start_params[1] = 0.67

    optimizer = fitting.Adam(alpha=0.05)

    opt = optimizer.minimize(
        fitting.test_stress_parameters,
        curve,
        start_params,
        interior,
        constraints=constraints,
        max_iterations=iterations,
        verbose=verbose,
        batch_size=16
    )

    cols = ['loss', 'phase', 'obliquity']
    if paramCount == 3:
        cols.append('longitude')
    fitFrame = pd.DataFrame(opt[3],
                            columns=cols).sort_values('loss')[0:number_of_fits]
    fitFrame['FitNumber'] = range(1, number_of_fits + 1)

    fullCurve = analysisCurve if analysisCurve is not None else curve

    for fit in fitFrame.itertuples():
        params = [fit.phase, fit.obliquity]
        if paramCount == 3:
            params.append(fit.longitude)
        bestFit = analyze_params(np.array(params),
                                 fullCurve,
                                 0.25,
                                 name,
                                 verbose,
                                 folder,
                                 suffix=fit.FitNumber)
        bestFit.to_csv(f'{folder}{name}BestFit{fit.FitNumber}.csv.gz',
                       index=False, encoding='utf-8', compression='gzip')

    df = pd.DataFrame(opt[3], columns=cols).copy()

    df['phase'] = df['phase'] * (max_vals[0] - min_vals[0]) + min_vals[0]
    df['obliquity'] = df['obliquity'] * (max_vals[1] - min_vals[1]) + min_vals[1]
    if paramCount == 3:
        df['longitude'] = df['longitude'] * (max_vals[2] - min_vals[2]) + min_vals[2]

    df.to_csv(f'{folder}{name}Fits.csv.gz', index=False, encoding='utf-8', compression='gzip')

    
def process_cycloid_by_name(name, folder='./output/', iterations=3000, constraints=constraints, verbose=False):
    process_cycloid(cycloids[name].curve,
                    name,
                    analysisCurve=highResCycloids[name].curve,
                    folder=folder,
                    iterations=iterations,
                    constraints=constraints,
                    verbose=verbose)

# %% [markdown]
# ## Generate Cyloid Data in Full Obliquity Range

# %%
for key in cycloids:
    process_cycloid_by_name(key, 
                            iterations=2000,
                            folder='./output/fullObliquityRange/',
                            verbose=False)
# Out:
# [08:49:14] Processing Cycloid: alex
# Iteration 150/2000 -- Loss Output: 8.920044958005164 -- Moving Avg Loss: 10.432709334162006
# 	Parameters used: [0.10877435 0.30438117]
# Iteration 300/2000 -- Loss Output: 1.1227306652741154 -- Moving Avg Loss: 1.282155248409742
# 	Parameters used: [0.53562021 0.87363327]
# Iteration 450/2000 -- Loss Output: 0.7325965639744422 -- Moving Avg Loss: 2.415568040573023
# 	Parameters used: [0.62324668 0.14296286]
# Iteration 600/2000 -- Loss Output: 1.1741233963325186 -- Moving Avg Loss: 1.4061807502154846
# 	Parameters used: [0.69809626 0.18553366]
# Iteration 750/2000 -- Loss Output: 0.8342071991144359 -- Moving Avg Loss: 0.3722574268983112
# 	Parameters used: [0.84131224 0.55522016]
# Iteration 900/2000 -- Loss Output: 0.0486009826545592 -- Moving Avg Loss: 0.09531378243667145
# 	Parameters used: [0.79650552 0.51109519]
# Iteration 1050/2000 -- Loss Output: 0.2998940779298645 -- Moving Avg Loss: 0.4690945467702166
# 	Parameters used: [0.67010518 0.38668292]
# Iteration 1200/2000 -- Loss Output: 0.32630810260460985 -- Moving Avg Loss: 0.16201296149806524
# 	Parameters used: [0.78612921 0.47337538]
# Iteration 1350/2000 -- Loss Output: 1.6189864343152405 -- Moving Avg Loss: 0.6252402041749494
# 	Parameters used: [0.64165286 0.33103825]
# Iteration 1500/2000 -- Loss Output: 0.10242521869670383 -- Moving Avg Loss: 2.0826071181353583
# 	Parameters used: [0.69603875 0.02248361]
# Iteration 1650/2000 -- Loss Output: 7.684671494760879 -- Moving Avg Loss: 6.230493188500524
# 	Parameters used: [0.27417923 0.29297156]
# Iteration 1800/2000 -- Loss Output: 0.33825613151721273 -- Moving Avg Loss: 0.1316038319441821
# 	Parameters used: [0.79967866 0.5032895 ]
# Iteration 1950/2000 -- Loss Output: 0.0518299795734459 -- Moving Avg Loss: 0.23138921352561284
# 	Parameters used: [0.71261081 0.41750928]
# [08:51:59] Analyzing optimization parameters for alex
# [08:52:14] Processing Cycloid: carly
# Iteration 150/2000 -- Loss Output: 9.299281018479915 -- Moving Avg Loss: 2.7861024051593937
# 	Parameters used: [0.81631997 0.72092492]
# Iteration 300/2000 -- Loss Output: 0.05608237762008704 -- Moving Avg Loss: 4.550462728355876
# 	Parameters used: [0.28832666 0.98631208]
# Iteration 450/2000 -- Loss Output: 0.061434508900019315 -- Moving Avg Loss: 0.053114024570908885
# 	Parameters used: [0.39241661 0.83529325]
# Iteration 600/2000 -- Loss Output: 0.08052855013357657 -- Moving Avg Loss: 0.1254130705777788
# 	Parameters used: [0.23444076 0.64123763]
# Iteration 750/2000 -- Loss Output: 0.05102800168669382 -- Moving Avg Loss: 0.06886896576717916
# 	Parameters used: [0.26661877 0.67174449]
# Iteration 900/2000 -- Loss Output: 0.06853926745879178 -- Moving Avg Loss: 0.8288577211488862
# 	Parameters used: [0.42576299 0.52963584]
# Iteration 1050/2000 -- Loss Output: 0.04942325680048266 -- Moving Avg Loss: 0.06045394539390305
# 	Parameters used: [0.3122775  0.66697516]
# Iteration 1200/2000 -- Loss Output: 0.0464337479655312 -- Moving Avg Loss: 0.0681073789515766
# 	Parameters used: [0.34058413 0.69396709]
# Iteration 1350/2000 -- Loss Output: 0.04570286337275066 -- Moving Avg Loss: 0.08269428817194108
# 	Parameters used: [0.37691428 0.72860991]
# Iteration 1500/2000 -- Loss Output: 1.0772888392918252 -- Moving Avg Loss: 4.824727364898366
# 	Parameters used: [0.49577382 0.40577018]
# Iteration 1650/2000 -- Loss Output: 0.3506735392822686 -- Moving Avg Loss: 0.14555052676543892
# 	Parameters used: [0.30428515 0.50446137]
# Iteration 1800/2000 -- Loss Output: 6.722426463931897 -- Moving Avg Loss: 3.332233745301281
# 	Parameters used: [0.62265923 0.80949618]
# Iteration 1950/2000 -- Loss Output: 0.04723271385646026 -- Moving Avg Loss: 0.05008030678569973
# 	Parameters used: [0.31734469 0.84766171]
# [08:55:06] Analyzing optimization parameters for carly
# [08:55:31] Processing Cycloid: cilicia
# Iteration 150/2000 -- Loss Output: 0.06169375683213715 -- Moving Avg Loss: 0.08169392088822533
# 	Parameters used: [0.02728448 0.09255778]
# Iteration 300/2000 -- Loss Output: 0.06672398529941131 -- Moving Avg Loss: 0.07138265733169662
# 	Parameters used: [0.93750644 0.38405235]
# Iteration 450/2000 -- Loss Output: 0.10210756733146277 -- Moving Avg Loss: 0.31086148862590274
# 	Parameters used: [0.79767483 0.30374872]
# Iteration 600/2000 -- Loss Output: 0.06744707822732365 -- Moving Avg Loss: 0.0769726314785949
# 	Parameters used: [0.93021361 0.21262847]
# Iteration 750/2000 -- Loss Output: 0.09197933679691166 -- Moving Avg Loss: 0.0705322581473955
# 	Parameters used: [0.30681638 0.02032757]
# Iteration 900/2000 -- Loss Output: 0.08212418455287133 -- Moving Avg Loss: 0.07717245380492904
# 	Parameters used: [0.67903202 0.24547627]
# Iteration 1050/2000 -- Loss Output: 0.07410572399107666 -- Moving Avg Loss: 0.07495554616437783
# 	Parameters used: [0.80023356 0.12000974]
# Iteration 1200/2000 -- Loss Output: 0.12208201782597973 -- Moving Avg Loss: 0.09622547325319351
# 	Parameters used: [0.42584167 0.56765407]
# Iteration 1350/2000 -- Loss Output: 0.08681312441960477 -- Moving Avg Loss: 0.08318123364323135
# 	Parameters used: [0.59069337 0.50448244]
# Iteration 1500/2000 -- Loss Output: 0.0729165477243077 -- Moving Avg Loss: 0.0742634228720701
# 	Parameters used: [0.86036173 0.43761375]
# Iteration 1650/2000 -- Loss Output: 0.10236435456122805 -- Moving Avg Loss: 0.10153110693766791
# 	Parameters used: [0.03054889 0.69870481]
# Iteration 1800/2000 -- Loss Output: 0.05380967970461324 -- Moving Avg Loss: 0.3222904161442975
# 	Parameters used: [0.09945547 0.16835144]
# Iteration 1950/2000 -- Loss Output: 0.07739102673035893 -- Moving Avg Loss: 0.08834801417706313
# 	Parameters used: [0.28345422 0.1411597 ]
# [08:58:36] Analyzing optimization parameters for cilicia
# [08:59:06] Processing Cycloid: delphi
# Iteration 150/2000 -- Loss Output: 0.058803719744271184 -- Moving Avg Loss: 0.07672318682332359
# 	Parameters used: [0.77368855 0.07383509]
# Iteration 300/2000 -- Loss Output: 0.062253851518000385 -- Moving Avg Loss: 0.07574003194159627
# 	Parameters used: [0.29405513 0.45240117]
# Iteration 450/2000 -- Loss Output: 0.0642264239850277 -- Moving Avg Loss: 0.07254041556449879
# 	Parameters used: [0.7200589 0.5093461]
# Iteration 600/2000 -- Loss Output: 0.08355147977576392 -- Moving Avg Loss: 0.07201292399155497
# 	Parameters used: [0.73618184 0.58061628]
# Iteration 750/2000 -- Loss Output: 0.06353908628441232 -- Moving Avg Loss: 0.08176982258830164
# 	Parameters used: [0.96466201 0.36081187]
# Iteration 900/2000 -- Loss Output: 0.08508822030872333 -- Moving Avg Loss: 0.07790161504851999
# 	Parameters used: [0.02715283 0.13017922]
# Iteration 1050/2000 -- Loss Output: 0.0808786971872662 -- Moving Avg Loss: 0.0697378514227718
# 	Parameters used: [0.19888993 0.06421933]
# Iteration 1200/2000 -- Loss Output: 0.0920991023558295 -- Moving Avg Loss: 0.07267052594711597
# 	Parameters used: [0.5849094  0.15643408]
# Iteration 1350/2000 -- Loss Output: 0.07689800630754505 -- Moving Avg Loss: 0.07195493446801626
# 	Parameters used: [0.58945207 0.10643884]
# Iteration 1500/2000 -- Loss Output: 0.08135593464012417 -- Moving Avg Loss: 0.07090131635530397
# 	Parameters used: [0.788724   0.10178838]
# Iteration 1650/2000 -- Loss Output: 0.06859910662856103 -- Moving Avg Loss: 0.07411898531888128
# 	Parameters used: [0.59629601 0.47729564]
# Iteration 1800/2000 -- Loss Output: 0.08349289905783822 -- Moving Avg Loss: 0.07237706624017001
# 	Parameters used: [0.71793109 0.1976466 ]
# Iteration 1950/2000 -- Loss Output: 0.07456728411125564 -- Moving Avg Loss: 0.0750302148719898
# 	Parameters used: [0.85878749 0.56043882]
# [09:02:02] Analyzing optimization parameters for delphi
# [09:02:26] Processing Cycloid: dirk
# Iteration 150/2000 -- Loss Output: 2.294145296771803 -- Moving Avg Loss: 0.9876349229005063
# 	Parameters used: [0.08668238 0.11657415]
# Iteration 300/2000 -- Loss Output: 1.1133281049235852 -- Moving Avg Loss: 0.5683939301493713
# 	Parameters used: [0.1888572 0.9009605]
# Iteration 450/2000 -- Loss Output: 0.13884406715528386 -- Moving Avg Loss: 0.735326891319547
# 	Parameters used: [0.33588487 0.17095931]
# Iteration 600/2000 -- Loss Output: 31.095063889861283 -- Moving Avg Loss: 14.326569167308127
# 	Parameters used: [0.86498226 0.07406963]
# Iteration 750/2000 -- Loss Output: 0.3517966456591429 -- Moving Avg Loss: 0.4819951821773049
# 	Parameters used: [0.16835449 0.11072163]
# Iteration 900/2000 -- Loss Output: 1.610999672750289 -- Moving Avg Loss: 7.86579225937473
# 	Parameters used: [0.40491935 0.37731   ]
# Iteration 1050/2000 -- Loss Output: 0.37703363590979705 -- Moving Avg Loss: 0.33483915763676625
# 	Parameters used: [0.28305637 0.25496478]
# Iteration 1200/2000 -- Loss Output: 0.25274608382256625 -- Moving Avg Loss: 1.0097547511199223
# 	Parameters used: [0.16091639 0.13234181]
# Iteration 1350/2000 -- Loss Output: 0.1693738526210661 -- Moving Avg Loss: 4.3293327317338495
# 	Parameters used: [0.43240728 0.14932704]
# Iteration 1500/2000 -- Loss Output: 0.2910267614675254 -- Moving Avg Loss: 0.6566775193451564
# 	Parameters used: [0.29599665 0.01258162]
# Iteration 1650/2000 -- Loss Output: 0.1542624436271045 -- Moving Avg Loss: 0.43933636303802326
# 	Parameters used: [0.22697136 0.26625593]
# Iteration 1800/2000 -- Loss Output: 0.3363424957123116 -- Moving Avg Loss: 0.5485624364417625
# 	Parameters used: [0.13027023 0.16931682]
# Iteration 1950/2000 -- Loss Output: 0.0983724696822202 -- Moving Avg Loss: 0.3557551869863604
# 	Parameters used: [0.30505044 0.22862484]
# [09:05:31] Analyzing optimization parameters for dirk
# [09:06:00] Processing Cycloid: mira
# Iteration 150/2000 -- Loss Output: 15.265774549971608 -- Moving Avg Loss: 8.737374744631184
# 	Parameters used: [0.80711515 0.27800412]
# Iteration 300/2000 -- Loss Output: 2.5143473115228123 -- Moving Avg Loss: 8.186341540275563
# 	Parameters used: [0.39249983 0.64102896]
# Iteration 450/2000 -- Loss Output: 9.407247392685246 -- Moving Avg Loss: 12.54020390191696
# 	Parameters used: [0.13061724 0.59271289]
# Iteration 600/2000 -- Loss Output: 6.60748256555612 -- Moving Avg Loss: 4.68741991507138
# 	Parameters used: [0.37678435 0.66020982]
# Iteration 750/2000 -- Loss Output: 1.9508120218292346 -- Moving Avg Loss: 5.286218600973668
# 	Parameters used: [0.44383661 0.84254684]
# Iteration 900/2000 -- Loss Output: 7.296819125611488 -- Moving Avg Loss: 11.340761543763618
# 	Parameters used: [0.68040235 0.36693948]
# Iteration 1050/2000 -- Loss Output: 13.978125952388213 -- Moving Avg Loss: 14.486893374389085
# 	Parameters used: [0.03559016 0.90504143]
# Iteration 1200/2000 -- Loss Output: 1.5795240171307179 -- Moving Avg Loss: 3.73859199564831
# 	Parameters used: [0.38121278 0.83507217]
# Iteration 1350/2000 -- Loss Output: 1.9733981138115375 -- Moving Avg Loss: 4.336472885436312
# 	Parameters used: [0.24547655 0.73583469]
# Iteration 1500/2000 -- Loss Output: 7.113300432386754 -- Moving Avg Loss: 8.95805372295487
# 	Parameters used: [0.74245646 0.51067205]
# Iteration 1650/2000 -- Loss Output: 1.4909953799593925 -- Moving Avg Loss: 2.8654023103716537
# 	Parameters used: [0.2888164  0.90150121]
# Iteration 1800/2000 -- Loss Output: 8.963524510321873 -- Moving Avg Loss: 13.353006127827369
# 	Parameters used: [0.15103366 0.82066027]
# Iteration 1950/2000 -- Loss Output: 3.268620851508183 -- Moving Avg Loss: 7.67707816868137
# 	Parameters used: [0.62000898 0.50835901]
# [09:08:52] Analyzing optimization parameters for mira
# [09:09:17] Processing Cycloid: odessa
# Iteration 150/2000 -- Loss Output: 0.04325712502643399 -- Moving Avg Loss: 8.151058996445816
# 	Parameters used: [0.23248448 0.75352764]
# Iteration 300/2000 -- Loss Output: 0.056637356685859314 -- Moving Avg Loss: 0.04336029705107796
# 	Parameters used: [0.33622362 0.85565359]
# Iteration 450/2000 -- Loss Output: 0.05343214301190252 -- Moving Avg Loss: 0.05211193776157848
# 	Parameters used: [0.37971454 0.89784263]
# Iteration 600/2000 -- Loss Output: 0.15347915429074552 -- Moving Avg Loss: 0.09226083068486685
# 	Parameters used: [0.47196284 0.98733107]
# Iteration 750/2000 -- Loss Output: 0.023729336758859895 -- Moving Avg Loss: 0.1844230680042283
# 	Parameters used: [0.40131775 0.45630647]
# Iteration 900/2000 -- Loss Output: 0.09752356787106238 -- Moving Avg Loss: 3.2801660939356077
# 	Parameters used: [0.52154203 0.79788436]
# Iteration 1050/2000 -- Loss Output: 0.04006303133957222 -- Moving Avg Loss: 0.0460537227757934
# 	Parameters used: [0.37508429 0.56413503]
# Iteration 1200/2000 -- Loss Output: 0.08167394076382987 -- Moving Avg Loss: 0.1273616141399524
# 	Parameters used: [0.47056912 0.65765723]
# Iteration 1350/2000 -- Loss Output: 0.07337917358279908 -- Moving Avg Loss: 7.252790834699075
# 	Parameters used: [0.21495609 0.78231684]
# Iteration 1500/2000 -- Loss Output: 0.045156499011592376 -- Moving Avg Loss: 0.04603117772762566
# 	Parameters used: [0.34597447 0.90079553]
# Iteration 1650/2000 -- Loss Output: 0.07113958720364998 -- Moving Avg Loss: 0.06554781022418217
# 	Parameters used: [0.41693336 0.96605575]
# Iteration 1800/2000 -- Loss Output: 1.550106306853299 -- Moving Avg Loss: 0.4930099103119395
# 	Parameters used: [0.52026484 0.55881493]
# Iteration 1950/2000 -- Loss Output: 0.06802069942777507 -- Moving Avg Loss: 0.05206756491114046
# 	Parameters used: [0.38726622 0.93460303]
# [09:12:00] Analyzing optimization parameters for odessa
# [09:12:20] Processing Cycloid: sidon
# Iteration 150/2000 -- Loss Output: 0.06648932113538673 -- Moving Avg Loss: 0.07839659516938088
# 	Parameters used: [0.64335696 0.44991426]
# Iteration 300/2000 -- Loss Output: 0.08398664227758627 -- Moving Avg Loss: 0.08354389618229682
# 	Parameters used: [0.1945027  0.30516291]
# Iteration 450/2000 -- Loss Output: 0.07649787756420495 -- Moving Avg Loss: 0.06949837485912728
# 	Parameters used: [0.39185168 0.00197256]
# Iteration 600/2000 -- Loss Output: 0.08608742923993469 -- Moving Avg Loss: 0.07818991616608927
# 	Parameters used: [0.72641601 0.00078775]
# Iteration 750/2000 -- Loss Output: 0.05748368707710232 -- Moving Avg Loss: 0.07552289468202147
# 	Parameters used: [0.27806691 0.20997664]
# Iteration 900/2000 -- Loss Output: 0.08574800203848781 -- Moving Avg Loss: 0.069929334740354
# 	Parameters used: [0.91785413 0.23752313]
# Iteration 1050/2000 -- Loss Output: 0.08701290352915758 -- Moving Avg Loss: 0.07805394680100922
# 	Parameters used: [0.33094477 0.02630196]
# Iteration 1200/2000 -- Loss Output: 0.09595429750860675 -- Moving Avg Loss: 0.07818798702581391
# 	Parameters used: [0.78682326 0.75511867]
# Iteration 1350/2000 -- Loss Output: 0.07524109780866034 -- Moving Avg Loss: 0.06933065425961109
# 	Parameters used: [0.09075597 0.06526063]
# Iteration 1500/2000 -- Loss Output: 0.10028456322909805 -- Moving Avg Loss: 0.09892159795241343
# 	Parameters used: [0.27125983 0.47857298]
# Iteration 1650/2000 -- Loss Output: 0.07971722478054094 -- Moving Avg Loss: 0.0774313361465761
# 	Parameters used: [0.03915041 0.34800569]
# Iteration 1800/2000 -- Loss Output: 0.09183259522272527 -- Moving Avg Loss: 0.07373777772552641
# 	Parameters used: [0.21696822 0.0640016 ]
# Iteration 1950/2000 -- Loss Output: 0.05589155329555343 -- Moving Avg Loss: 0.07276422154627082
# 	Parameters used: [0.05473928 0.13966009]
# [09:15:42] Analyzing optimization parameters for sidon
# [09:16:26] Processing Cycloid: tyrrel
# Iteration 150/2000 -- Loss Output: 8.770498509746146 -- Moving Avg Loss: 6.204268111769684
# 	Parameters used: [0.95547275 0.42436904]
# Iteration 300/2000 -- Loss Output: 12.00274462096745 -- Moving Avg Loss: 9.917186375540851
# 	Parameters used: [0.62608235 0.00941304]
# Iteration 450/2000 -- Loss Output: 2.7510030212816607 -- Moving Avg Loss: 6.6737219329421045
# 	Parameters used: [0.1129863  0.49330216]
# Iteration 600/2000 -- Loss Output: 10.421622253774501 -- Moving Avg Loss: 10.47423241900321
# 	Parameters used: [0.62414769 0.09229085]
# Iteration 750/2000 -- Loss Output: 2.747554987531436 -- Moving Avg Loss: 8.235765868615307
# 	Parameters used: [0.98863229 0.28606392]
# Iteration 900/2000 -- Loss Output: 2.037607138466667 -- Moving Avg Loss: 7.318757960766342
# 	Parameters used: [0.34498756 0.27226624]
# Iteration 1050/2000 -- Loss Output: 15.46665926212185 -- Moving Avg Loss: 14.872865011132568
# 	Parameters used: [0.53166419 0.25117285]
# Iteration 1200/2000 -- Loss Output: 1.2291087339937363 -- Moving Avg Loss: 3.8834984753795703
# 	Parameters used: [0.25076896 0.86397162]
# Iteration 1350/2000 -- Loss Output: 6.34446384324045 -- Moving Avg Loss: 6.592794432448678
# 	Parameters used: [3.72366785e-04 6.08529922e-01]
# Iteration 1500/2000 -- Loss Output: 7.332632856900459 -- Moving Avg Loss: 7.814476452277458
# 	Parameters used: [0.35630716 0.55209091]
# Iteration 1650/2000 -- Loss Output: 7.496155468998777 -- Moving Avg Loss: 5.4908252008715905
# 	Parameters used: [0.09210695 0.28269973]
# Iteration 1800/2000 -- Loss Output: 8.82331709184508 -- Moving Avg Loss: 12.268108401315075
# 	Parameters used: [0.53035627 0.58707211]
# Iteration 1950/2000 -- Loss Output: 4.785554419371061 -- Moving Avg Loss: 4.935325576206832
# 	Parameters used: [0.16997807 0.21972913]
# [09:19:48] Analyzing optimization parameters for tyrrel
# [09:20:34] Processing Cycloid: yaphet
# Iteration 150/2000 -- Loss Output: 0.044379533878719964 -- Moving Avg Loss: 0.09163249520472178
# 	Parameters used: [0.20821841 0.90816028]
# Iteration 300/2000 -- Loss Output: 15.776532824664272 -- Moving Avg Loss: 8.067269490631288
# 	Parameters used: [0.81025929 0.79909505]
# Iteration 450/2000 -- Loss Output: 0.5763945249559606 -- Moving Avg Loss: 0.5703660429635601
# 	Parameters used: [0.22447253 0.35422687]
# Iteration 600/2000 -- Loss Output: 0.04426378473195316 -- Moving Avg Loss: 0.07576457236855338
# 	Parameters used: [0.19557143 0.87068226]
# Iteration 750/2000 -- Loss Output: 18.07510901207162 -- Moving Avg Loss: 9.736063470584812
# 	Parameters used: [0.80064874 0.69943574]
# Iteration 900/2000 -- Loss Output: 0.0637651960441996 -- Moving Avg Loss: 0.07843975109228647
# 	Parameters used: [0.14187737 0.55011379]
# Iteration 1050/2000 -- Loss Output: 23.791592437935524 -- Moving Avg Loss: 11.637731419077229
# 	Parameters used: [0.82167646 0.43378089]
# Iteration 1200/2000 -- Loss Output: 0.06253657723023438 -- Moving Avg Loss: 0.06930327690284424
# 	Parameters used: [0.18253917 0.61079158]
# Iteration 1350/2000 -- Loss Output: 0.05628950945070796 -- Moving Avg Loss: 7.786157915768102
# 	Parameters used: [0.18086789 0.84090719]
# Iteration 1500/2000 -- Loss Output: 0.054030700275416566 -- Moving Avg Loss: 0.11578208801255677
# 	Parameters used: [0.12620798 0.53622858]
# Iteration 1650/2000 -- Loss Output: 0.06258294126887354 -- Moving Avg Loss: 0.21086106151608952
# 	Parameters used: [0.19786192 0.60775911]
# Iteration 1800/2000 -- Loss Output: 0.05576435867352554 -- Moving Avg Loss: 0.060895462332083324
# 	Parameters used: [0.17250517 0.87312559]
# Iteration 1950/2000 -- Loss Output: 0.10361285923188472 -- Moving Avg Loss: 2.4176412887464527
# 	Parameters used: [0.47827544 0.37854605]
# [09:23:19] Analyzing optimization parameters for yaphet

# %% [markdown]
# ## Non-Optimized Fits
#
# * 0.25 Deg Obliquity
# * Phases 0, 60, 120, 180, 240 and 300 degrees

# %%
losses = []
folder = './output/lockedFits/'

OBLIQUITY = 0.25
phases = [0, 60, 120, 180, 240, 300]

for current in cycloids:
    for phase in phases:
        print(f'Processing phase {phase}')
        data, loss = direct_fit(cycloids[current].curve, 
                                0.25, 
                                show_plots=False, 
                                params=[phase, OBLIQUITY, 0])

        losses.append(dict(cycloid=current, loss=loss, phase=phase))
        print(current,'\t-', loss)

        filename = f'{folder}{current}-phase{phase}.csv.gz'
        data.to_csv(filename, index=False, compression='gzip')

lossFrame = pd.DataFrame(losses)
filename = f'{folder}Losses.csv'
lossFrame.to_csv(filename, index=False)
# Out:
# Processing phase 0
# alex 	- 1.101083245680132
# Processing phase 60
# alex 	- 1.4971956846431838
# Processing phase 120
# alex 	- 0.6598343140300722
# Processing phase 180
# alex 	- 0.7702316207406991
# Processing phase 240
# alex 	- 0.43309652602466875
# Processing phase 300
# alex 	- 0.5071788920359364
# Processing phase 0
# carly 	- 0.35328613497182065
# Processing phase 60
# carly 	- 0.21267623114570441
# Processing phase 120
# carly 	- 0.24922552695109376
# Processing phase 180
# carly 	- 0.538335195440918
# Processing phase 240
# carly 	- 0.8777948253803868
# Processing phase 300
# carly 	- 1.8209416009303054
# Processing phase 0
# cilicia 	- 0.012293092595647051
# Processing phase 60
# cilicia 	- 0.01239612808496264
# Processing phase 120
# cilicia 	- 0.012877744702335128
# Processing phase 180
# cilicia 	- 0.013864483392336313
# Processing phase 240
# cilicia 	- 0.011287991762470551
# Processing phase 300
# cilicia 	- 0.011243036088465809
# Processing phase 0
# delphi 	- 0.013205383710725268
# Processing phase 60
# delphi 	- 0.013160345707482517
# Processing phase 120
# delphi 	- 0.013290890297907173
# Processing phase 180
# delphi 	- 0.013202676538413973
# Processing phase 240
# delphi 	- 0.013055121880552807
# Processing phase 300
# delphi 	- 0.012797128595729282
# Processing phase 0
# dirk 	- 3.367056706039251
# Processing phase 60
# dirk 	- 0.13759690896666923
# Processing phase 120
# dirk 	- 0.13875360288581387
# Processing phase 180
# dirk 	- 0.29411201474848647
# Processing phase 240
# dirk 	- 3.7767413826847687
# Processing phase 300
# dirk 	- 3.555025822716339
# Processing phase 0
# mira 	- 2.6679100870698123
# Processing phase 60
# mira 	- 1.9692835740267005
# Processing phase 120
# mira 	- 1.67811873404682
# Processing phase 180
# mira 	- 1.9586866427318785
# Processing phase 240
# mira 	- 2.4311884007706746
# Processing phase 300
# mira 	- 2.783880687854297
# Processing phase 0
# odessa 	- 1.0922006276311136
# Processing phase 60
# odessa 	- 0.6148629598184023
# Processing phase 120
# odessa 	- 0.2752575560511966
# Processing phase 180
# odessa 	- 0.3628690153326097
# Processing phase 240
# odessa 	- 0.7069418095555955
# Processing phase 300
# odessa 	- 1.0604877439998193
# Processing phase 0
# sidon 	- 0.009706054836317824
# Processing phase 60
# sidon 	- 0.009639118896826893
# Processing phase 120
# sidon 	- 0.01103232963957045
# Processing phase 180
# sidon 	- 0.010145938961389824
# Processing phase 240
# sidon 	- 0.009964654452619149
# Processing phase 300
# sidon 	- 0.010255636306789126
# Processing phase 0
# tyrrel 	- 0.5455693964540093
# Processing phase 60
# tyrrel 	- 0.793646033010145
# Processing phase 120
# tyrrel 	- 1.105389083382538
# Processing phase 180
# tyrrel 	- 1.0614500016325699
# Processing phase 240
# tyrrel 	- 1.6913946028194555
# Processing phase 300
# tyrrel 	- 1.6105589566565115
# Processing phase 0
# yaphet 	- 0.0986318751726185
# Processing phase 60
# yaphet 	- 0.14652338122268518
# Processing phase 120
# yaphet 	- 0.3116822921627202
# Processing phase 180
# yaphet 	- 0.365706642595349
# Processing phase 240
# yaphet 	- 1.8113313971266873
# Processing phase 300
# yaphet 	- 1.3333428185154181

# %% [markdown]
# ## Direct Fits (no phase or obliquity) for all cycloids

# %%
losses = []
folder = './output/directFits/'

for current in cycloids:
    data, loss = direct_fit(cycloids[current].curve, 0.25, show_plots=False)

    losses.append(dict(cycloid=current, loss=loss))
    print(current,'\t-', loss)

    filename = f'{folder}{current}.csv.gz'
    data.to_csv(filename, index=False, compression='gzip')

lossFrame = pd.DataFrame(losses)
filename = f'{folder}directLosses.csv'
lossFrame.to_csv(filename, index=False)
# Out:
# alex 	- 0.90675499538864
# carly 	- 0.4679169956204177
# cilicia 	- 0.011850136742198897
# delphi 	- 0.01290892547457404
# dirk 	- 2.1386070161654858
# mira 	- 2.261342358536797
# odessa 	- 0.6678619449895173
# sidon 	- 0.010174794559418736
# tyrrel 	- 0.8524575485454637
# yaphet 	- 0.21000699087411415

# %% [markdown]
# ## Fits with Tight Obliquity

# %%
for cycloid in cycloids:
    process_cycloid_top_fits(cycloids[cycloid].curve,
                             cycloid,
                             folder='./output/tightObliquity/',
                             iterations=2000,
                             constraints=tight_obliquity_contstraints,
                             number_of_fits=5,
                             paramCount=2,
                             verbose=False
                            )
# Out:
# Iteration 150/2000 -- Loss Output: 0.06210398648378454 -- Moving Avg Loss: 0.0563501429239001
# 	Parameters used: [0.74296968 0.74300612]
# Iteration 300/2000 -- Loss Output: 0.055815900385971715 -- Moving Avg Loss: 0.07943345115011605
# 	Parameters used: [0.69584328 0.76574406]
# Iteration 450/2000 -- Loss Output: 0.09070572030638192 -- Moving Avg Loss: 5.075391706113116
# 	Parameters used: [0.63988126 0.65579232]
# Iteration 600/2000 -- Loss Output: 0.05964518576883631 -- Moving Avg Loss: 0.08081977253779796
# 	Parameters used: [0.69372664 0.75877465]
# Iteration 750/2000 -- Loss Output: 0.06700438921192332 -- Moving Avg Loss: 0.11248966027489621
# 	Parameters used: [0.67797218 0.68870854]
# Iteration 900/2000 -- Loss Output: 10.408914424168042 -- Moving Avg Loss: 3.853511851566286
# 	Parameters used: [0.25162284 0.66346267]
# Iteration 1050/2000 -- Loss Output: 0.042283721541265105 -- Moving Avg Loss: 0.05482456510537623
# 	Parameters used: [0.72102838 0.81522621]
# Iteration 1200/2000 -- Loss Output: 0.07203607238836088 -- Moving Avg Loss: 0.09926687811180245
# 	Parameters used: [0.69374108 0.76914743]
# Iteration 1350/2000 -- Loss Output: 0.06694810859604484 -- Moving Avg Loss: 3.6443713787349874
# 	Parameters used: [0.82435605 0.78766385]
# Iteration 1500/2000 -- Loss Output: 0.05261848225435934 -- Moving Avg Loss: 0.05575677473086845
# 	Parameters used: [0.75702386 0.74517952]
# Iteration 1650/2000 -- Loss Output: 0.0494707535936369 -- Moving Avg Loss: 0.057126780554979203
# 	Parameters used: [0.71469815 0.77447763]
# Iteration 1800/2000 -- Loss Output: 1.4992549531596628 -- Moving Avg Loss: 0.2329661409791746
# 	Parameters used: [0.65502569 0.81578371]
# Iteration 1950/2000 -- Loss Output: 0.06296823391177137 -- Moving Avg Loss: 0.1246261936170337
# 	Parameters used: [0.68888736 0.80003262]
# Iteration 150/2000 -- Loss Output: 6.691325666080534 -- Moving Avg Loss: 3.694906274319529
# 	Parameters used: [0.83302712 0.77322496]
# Iteration 300/2000 -- Loss Output: 0.07356675782201601 -- Moving Avg Loss: 0.07214835367188902
# 	Parameters used: [0.22386051 0.72625266]
# Iteration 450/2000 -- Loss Output: 0.22246154370083113 -- Moving Avg Loss: 0.15105421435433372
# 	Parameters used: [0.38645102 0.78875175]
# Iteration 600/2000 -- Loss Output: 0.050706267800525895 -- Moving Avg Loss: 0.0518875358224902
# 	Parameters used: [0.34822154 0.74256708]
# Iteration 750/2000 -- Loss Output: 0.06780786440759412 -- Moving Avg Loss: 0.2249971906668099
# 	Parameters used: [0.39278799 0.78658579]
# Iteration 900/2000 -- Loss Output: 0.05279112920860751 -- Moving Avg Loss: 0.06558105791019729
# 	Parameters used: [0.25835058 0.72324183]
# Iteration 1050/2000 -- Loss Output: 0.05283439423984832 -- Moving Avg Loss: 0.051239965765888004
# 	Parameters used: [0.29823781 0.75827434]
# Iteration 1200/2000 -- Loss Output: 0.042671291992196506 -- Moving Avg Loss: 0.051680058858573685
# 	Parameters used: [0.33442451 0.79166025]
# Iteration 1350/2000 -- Loss Output: 0.050415649712480616 -- Moving Avg Loss: 0.16344413904914576
# 	Parameters used: [0.37990263 0.66051642]
# Iteration 1500/2000 -- Loss Output: 0.0342047280651742 -- Moving Avg Loss: 0.09435008781862826
# 	Parameters used: [0.3655498  0.70050639]
# Iteration 1650/2000 -- Loss Output: 0.034329968524133864 -- Moving Avg Loss: 0.05020054875617722
# 	Parameters used: [0.36502434 0.78822313]
# Iteration 1800/2000 -- Loss Output: 0.04846042931703248 -- Moving Avg Loss: 0.058473536315931
# 	Parameters used: [0.2666305  0.81650955]
# Iteration 1950/2000 -- Loss Output: 0.053284746266713603 -- Moving Avg Loss: 0.05084635208579795
# 	Parameters used: [0.30993994 0.79828151]
# Iteration 150/2000 -- Loss Output: 0.07498066519574124 -- Moving Avg Loss: 0.10421933702368236
# 	Parameters used: [0.39009213 0.68410489]
# Iteration 300/2000 -- Loss Output: 0.07223399930420295 -- Moving Avg Loss: 0.07464501155682926
# 	Parameters used: [0.85917839 0.72370701]
# Iteration 450/2000 -- Loss Output: 0.059847289747423565 -- Moving Avg Loss: 0.08521644799925458
# 	Parameters used: [0.646831  0.7284956]
# Iteration 600/2000 -- Loss Output: 0.06268555013075218 -- Moving Avg Loss: 0.07731105463212487
# 	Parameters used: [0.93130425 0.62611705]
# Iteration 750/2000 -- Loss Output: 0.11092496367957551 -- Moving Avg Loss: 0.08564753738709344
# 	Parameters used: [0.55636389 0.75228341]
# Iteration 900/2000 -- Loss Output: 0.08254578804442446 -- Moving Avg Loss: 0.07933832436837635
# 	Parameters used: [0.66672798 0.67778681]
# Iteration 1050/2000 -- Loss Output: 0.050204101747823936 -- Moving Avg Loss: 0.10599088020506349
# 	Parameters used: [0.40957498 0.66108975]
# Iteration 1200/2000 -- Loss Output: 0.12926230762897511 -- Moving Avg Loss: 0.08439710746827628
# 	Parameters used: [0.57571491 0.69373058]
# Iteration 1350/2000 -- Loss Output: 0.06726986699520959 -- Moving Avg Loss: 0.07917994414468063
# 	Parameters used: [0.67334824 0.6395297 ]
# Iteration 1500/2000 -- Loss Output: 0.05173163521578404 -- Moving Avg Loss: 0.07183280884455182
# 	Parameters used: [0.81969448 0.72071415]
# Iteration 1650/2000 -- Loss Output: 0.13601203886989907 -- Moving Avg Loss: 0.29891889260398075
# 	Parameters used: [0.33447664 0.75166731]
# Iteration 1800/2000 -- Loss Output: 0.0983277649835245 -- Moving Avg Loss: 0.09040153388095193
# 	Parameters used: [0.5418988  0.70952686]
# Iteration 1950/2000 -- Loss Output: 0.08190423002053374 -- Moving Avg Loss: 0.08160793048390422
# 	Parameters used: [0.60703385 0.67105042]
# Iteration 150/2000 -- Loss Output: 0.0822084637133147 -- Moving Avg Loss: 0.07492870406409403
# 	Parameters used: [0.89179392 0.64865251]
# Iteration 300/2000 -- Loss Output: 0.08040993293865856 -- Moving Avg Loss: 0.09033072006140193
# 	Parameters used: [0.5387207  0.81035199]
# Iteration 450/2000 -- Loss Output: 0.0750302383465256 -- Moving Avg Loss: 0.0870265810585746
# 	Parameters used: [0.25032926 0.79316637]
# Iteration 600/2000 -- Loss Output: 0.09519685276529642 -- Moving Avg Loss: 0.07622636503896368
# 	Parameters used: [0.93333478 0.78579147]
# Iteration 750/2000 -- Loss Output: 0.08140583578021725 -- Moving Avg Loss: 0.0910024368915247
# 	Parameters used: [0.37487264 0.81614387]
# Iteration 900/2000 -- Loss Output: 0.049913495785343376 -- Moving Avg Loss: 0.06881934338412747
# 	Parameters used: [0.75336895 0.80515656]
# Iteration 1050/2000 -- Loss Output: 0.09163215996929902 -- Moving Avg Loss: 0.07894720188565738
# 	Parameters used: [0.05622284 0.7628377 ]
# Iteration 1200/2000 -- Loss Output: 0.11591527763833297 -- Moving Avg Loss: 0.10651285126978842
# 	Parameters used: [0.32215924 0.79750104]
# Iteration 1350/2000 -- Loss Output: 0.0839558062612375 -- Moving Avg Loss: 0.07446221904854966
# 	Parameters used: [0.94183318 0.81727649]
# Iteration 1500/2000 -- Loss Output: 0.10846807450391444 -- Moving Avg Loss: 0.09551086635547502
# 	Parameters used: [0.36554896 0.78740955]
# Iteration 1650/2000 -- Loss Output: 0.07101236447992709 -- Moving Avg Loss: 0.07255809328135107
# 	Parameters used: [0.75169297 0.73892332]
# Iteration 1800/2000 -- Loss Output: 0.10093150936967403 -- Moving Avg Loss: 0.09809924410160342
# 	Parameters used: [0.22982006 0.79671808]
# Iteration 1950/2000 -- Loss Output: 0.06929577779646667 -- Moving Avg Loss: 0.07481019837058765
# 	Parameters used: [0.50630881 0.66494522]
# Iteration 150/2000 -- Loss Output: 0.08751609821903342 -- Moving Avg Loss: 0.15537615313651862
# 	Parameters used: [0.21295525 0.81450486]
# Iteration 300/2000 -- Loss Output: 0.06498264336076721 -- Moving Avg Loss: 0.07374783894836165
# 	Parameters used: [0.25046443 0.75574681]
# Iteration 450/2000 -- Loss Output: 0.058736063892623855 -- Moving Avg Loss: 0.05771548244741356
# 	Parameters used: [0.27597829 0.77869943]
# Iteration 600/2000 -- Loss Output: 0.06312043116687842 -- Moving Avg Loss: 0.05733147106170811
# 	Parameters used: [0.30346996 0.80343138]
# Iteration 750/2000 -- Loss Output: 0.060941307962526926 -- Moving Avg Loss: 0.05929501846710721
# 	Parameters used: [0.33014275 0.67627782]
# Iteration 900/2000 -- Loss Output: 0.0824320561738415 -- Moving Avg Loss: 0.1750919127359248
# 	Parameters used: [0.47156314 0.80368348]
# Iteration 1050/2000 -- Loss Output: 0.04864582902075927 -- Moving Avg Loss: 0.052656551124995316
# 	Parameters used: [0.33551525 0.80252564]
# Iteration 1200/2000 -- Loss Output: 0.06835129046123235 -- Moving Avg Loss: 0.11602497736755168
# 	Parameters used: [0.36587086 0.67949521]
# Iteration 1350/2000 -- Loss Output: 0.07930370386479296 -- Moving Avg Loss: 0.16531131016137432
# 	Parameters used: [0.41368033 0.72260111]
# Iteration 1500/2000 -- Loss Output: 0.2563233678017381 -- Moving Avg Loss: 6.3231588123316955
# 	Parameters used: [0.1737351  0.76596724]
# Iteration 1650/2000 -- Loss Output: 0.08278226732509296 -- Moving Avg Loss: 0.10411282925828043
# 	Parameters used: [0.24320843 0.8161935 ]
# Iteration 1800/2000 -- Loss Output: 0.057275997051911165 -- Moving Avg Loss: 0.059381487224058345
# 	Parameters used: [0.28839895 0.71648506]
# Iteration 1950/2000 -- Loss Output: 0.05072664293616243 -- Moving Avg Loss: 0.05682097555939799
# 	Parameters used: [0.33771932 0.76108735]
# Iteration 150/2000 -- Loss Output: 3.6600366251280274 -- Moving Avg Loss: 8.776705162678665
# 	Parameters used: [0.54815469 0.72722364]
# Iteration 300/2000 -- Loss Output: 0.05695039051173985 -- Moving Avg Loss: 5.368471103752842
# 	Parameters used: [0.27242904 0.76461405]
# Iteration 450/2000 -- Loss Output: 12.064981896965884 -- Moving Avg Loss: 9.052319107218844
# 	Parameters used: [0.62952051 0.72175081]
# Iteration 600/2000 -- Loss Output: 9.410172650770853 -- Moving Avg Loss: 4.485874731216651
# 	Parameters used: [0.13724211 0.77755786]
# Iteration 750/2000 -- Loss Output: 5.114134554800748 -- Moving Avg Loss: 4.492122809446421
# 	Parameters used: [0.16118784 0.6721995 ]
# Iteration 900/2000 -- Loss Output: 10.47378136957532 -- Moving Avg Loss: 5.8549328642520075
# 	Parameters used: [0.13776542 0.66708021]
# Iteration 1050/2000 -- Loss Output: 0.0802092825564656 -- Moving Avg Loss: 14.700246474687846
# 	Parameters used: [0.20765092 0.62248955]
# Iteration 1200/2000 -- Loss Output: 1.6047186932717563 -- Moving Avg Loss: 3.866156876167232
# 	Parameters used: [0.37097277 0.7115487 ]
# Iteration 1350/2000 -- Loss Output: 23.193223143708366 -- Moving Avg Loss: 8.97731494534769
# 	Parameters used: [0.02397987 0.73658491]
# Iteration 1500/2000 -- Loss Output: 11.101437279506454 -- Moving Avg Loss: 11.22813065857012
# 	Parameters used: [0.63139292 0.75167326]
# Iteration 1650/2000 -- Loss Output: 6.768948081684517 -- Moving Avg Loss: 6.053425590950081
# 	Parameters used: [0.37891666 0.66766452]
# Iteration 1800/2000 -- Loss Output: 1.1120599726216043 -- Moving Avg Loss: 3.9412717408364286
# 	Parameters used: [0.25099573 0.70285814]
# Iteration 1950/2000 -- Loss Output: 21.623594918889516 -- Moving Avg Loss: 11.423593538672588
# 	Parameters used: [0.03900513 0.70209748]
# Iteration 150/2000 -- Loss Output: 10.011694508810294 -- Moving Avg Loss: 4.997826403485567
# 	Parameters used: [0.83531072 0.75437732]
# Iteration 300/2000 -- Loss Output: 0.059974032064386805 -- Moving Avg Loss: 6.022681094100884
# 	Parameters used: [0.43959572 0.69503419]
# Iteration 450/2000 -- Loss Output: 8.570693139681504 -- Moving Avg Loss: 4.435124644325786
# 	Parameters used: [0.98476624 0.673909  ]
# Iteration 600/2000 -- Loss Output: 0.04031831756708271 -- Moving Avg Loss: 0.040796114333415255
# 	Parameters used: [0.28661004 0.68782065]
# Iteration 750/2000 -- Loss Output: 0.046052238938285445 -- Moving Avg Loss: 0.04601085104422739
# 	Parameters used: [0.24951894 0.67173371]
# Iteration 900/2000 -- Loss Output: 0.044388041072119654 -- Moving Avg Loss: 0.26297868724868523
# 	Parameters used: [0.25884125 0.64833706]
# Iteration 1050/2000 -- Loss Output: 0.12756828342485757 -- Moving Avg Loss: 5.294257304437572
# 	Parameters used: [0.21261837 0.658664  ]
# Iteration 1200/2000 -- Loss Output: 11.718920653379893 -- Moving Avg Loss: 6.089486327713618
# 	Parameters used: [0.823405   0.70073497]
# Iteration 1350/2000 -- Loss Output: 0.03720773543604953 -- Moving Avg Loss: 4.14784378649646
# 	Parameters used: [0.30339812 0.7261675 ]
# Iteration 1500/2000 -- Loss Output: 0.07552105530797122 -- Moving Avg Loss: 0.08549796568819476
# 	Parameters used: [0.18672914 0.80736453]
# Iteration 1650/2000 -- Loss Output: 1.364312357809171 -- Moving Avg Loss: 0.3776081122772967
# 	Parameters used: [0.18723282 0.6968246 ]
# Iteration 1800/2000 -- Loss Output: 0.04303498704475139 -- Moving Avg Loss: 0.04299635063031321
# 	Parameters used: [0.26555487 0.81465109]
# Iteration 1950/2000 -- Loss Output: 0.06350137909226405 -- Moving Avg Loss: 0.10651583502139264
# 	Parameters used: [0.21529887 0.65049889]
# Iteration 150/2000 -- Loss Output: 0.08299865553483322 -- Moving Avg Loss: 0.08682970792349122
# 	Parameters used: [0.81679463 0.62606532]
# Iteration 300/2000 -- Loss Output: 0.08654161904056386 -- Moving Avg Loss: 0.07946645627321133
# 	Parameters used: [0.53470102 0.70843071]
# Iteration 450/2000 -- Loss Output: 0.06792731396134145 -- Moving Avg Loss: 0.08079014935379397
# 	Parameters used: [0.66658168 0.71183821]
# Iteration 600/2000 -- Loss Output: 0.09477007083188811 -- Moving Avg Loss: 0.07991199746191668
# 	Parameters used: [0.7505098  0.72076939]
# Iteration 750/2000 -- Loss Output: 0.08156555024411655 -- Moving Avg Loss: 0.08522792308002597
# 	Parameters used: [0.90043466 0.71385114]
# Iteration 900/2000 -- Loss Output: 0.10705464208224902 -- Moving Avg Loss: 0.08006486246943523
# 	Parameters used: [0.49133274 0.63423327]
# Iteration 1050/2000 -- Loss Output: 0.0591656043724261 -- Moving Avg Loss: 0.08116525013112223
# 	Parameters used: [0.90238037 0.67069871]
# Iteration 1200/2000 -- Loss Output: 0.08991204568791784 -- Moving Avg Loss: 0.08383578719799913
# 	Parameters used: [0.58620087 0.70759539]
# Iteration 1350/2000 -- Loss Output: 0.11648809636940526 -- Moving Avg Loss: 0.08210971875868728
# 	Parameters used: [0.61570128 0.69554966]
# Iteration 1500/2000 -- Loss Output: 0.09320288504090973 -- Moving Avg Loss: 0.0776424078107824
# 	Parameters used: [0.68321621 0.65691836]
# Iteration 1650/2000 -- Loss Output: 0.09291102182804048 -- Moving Avg Loss: 0.08280610756626619
# 	Parameters used: [0.46608176 0.65230184]
# Iteration 1800/2000 -- Loss Output: 0.07046517935367129 -- Moving Avg Loss: 0.08701688436841053
# 	Parameters used: [0.86726648 0.69318497]
# Iteration 1950/2000 -- Loss Output: 0.08954844479271211 -- Moving Avg Loss: 0.0920238958214645
# 	Parameters used: [0.95863083 0.67810546]
# Iteration 150/2000 -- Loss Output: 7.703529148469945 -- Moving Avg Loss: 7.322423412201584
# 	Parameters used: [0.06278482 0.70602077]
# Iteration 300/2000 -- Loss Output: 6.42395686390284 -- Moving Avg Loss: 3.659130264717301
# 	Parameters used: [0.01557459 0.71313253]
# Iteration 450/2000 -- Loss Output: 9.64240764598839 -- Moving Avg Loss: 8.185295791374202
# 	Parameters used: [0.84803107 0.66608133]
# Iteration 600/2000 -- Loss Output: 7.149120376954919 -- Moving Avg Loss: 11.347855490590241
# 	Parameters used: [0.36728773 0.69334636]
# Iteration 750/2000 -- Loss Output: 5.256255311403126 -- Moving Avg Loss: 6.390005761819427
# 	Parameters used: [0.16025301 0.72289077]
# Iteration 900/2000 -- Loss Output: 8.971781094959876 -- Moving Avg Loss: 5.207622160498124
# 	Parameters used: [0.95678037 0.62704537]
# Iteration 1050/2000 -- Loss Output: 10.36350332026975 -- Moving Avg Loss: 12.714456969704566
# 	Parameters used: [0.43555263 0.70387186]
# Iteration 1200/2000 -- Loss Output: 2.5262864557780156 -- Moving Avg Loss: 4.179258369709612
# 	Parameters used: [0.12410325 0.67132329]
# Iteration 1350/2000 -- Loss Output: 7.305124828026824 -- Moving Avg Loss: 6.2107902548681775
# 	Parameters used: [0.93676062 0.73279655]
# Iteration 1500/2000 -- Loss Output: 14.684343913955649 -- Moving Avg Loss: 12.02356071516132
# 	Parameters used: [0.39307408 0.75441325]
# Iteration 1650/2000 -- Loss Output: 10.246206299161797 -- Moving Avg Loss: 5.683302250675174
# 	Parameters used: [0.90802036 0.74092579]
# Iteration 1800/2000 -- Loss Output: 7.645246444054707 -- Moving Avg Loss: 8.356383637503722
# 	Parameters used: [0.77807866 0.76432122]
# Iteration 1950/2000 -- Loss Output: 2.7066250935237126 -- Moving Avg Loss: 2.752726354448373
# 	Parameters used: [0.06663472 0.69585867]
# Iteration 150/2000 -- Loss Output: 0.09309521548667297 -- Moving Avg Loss: 0.8577305528757242
# 	Parameters used: [0.07062249 0.71185423]
# Iteration 300/2000 -- Loss Output: 0.10675004299748773 -- Moving Avg Loss: 0.10949109470433159
# 	Parameters used: [0.05109952 0.68171335]
# Iteration 450/2000 -- Loss Output: 0.15714950313945172 -- Moving Avg Loss: 0.1353483994602507
# 	Parameters used: [0.0250356  0.75534188]
# Iteration 600/2000 -- Loss Output: 0.04872433239020803 -- Moving Avg Loss: 0.0704370066704155
# 	Parameters used: [0.1425453 0.6241121]
# Iteration 750/2000 -- Loss Output: 0.06893834102698036 -- Moving Avg Loss: 0.08787815702346136
# 	Parameters used: [0.07910865 0.7382068 ]
# Iteration 900/2000 -- Loss Output: 0.1675695965269399 -- Moving Avg Loss: 0.17725230665557554
# 	Parameters used: [0.99974071 0.6597255 ]
# Iteration 1050/2000 -- Loss Output: 0.09131397016467811 -- Moving Avg Loss: 0.07546857625051924
# 	Parameters used: [0.13314014 0.65394688]
# Iteration 1200/2000 -- Loss Output: 0.16632869734510217 -- Moving Avg Loss: 0.12677037627113039
# 	Parameters used: [0.01388661 0.6951098 ]
# Iteration 1350/2000 -- Loss Output: 2.1321784412376665 -- Moving Avg Loss: 9.03427869699854
# 	Parameters used: [0.40568018 0.67947642]
# Iteration 1500/2000 -- Loss Output: 0.06045830568515165 -- Moving Avg Loss: 0.06515004623678709
# 	Parameters used: [0.14879336 0.67755947]
# Iteration 1650/2000 -- Loss Output: 0.11863238296317469 -- Moving Avg Loss: 0.08699901659568551
# 	Parameters used: [0.06265907 0.62634921]
# Iteration 1800/2000 -- Loss Output: 10.80579877139605 -- Moving Avg Loss: 8.70237736718866
# 	Parameters used: [0.68845392 0.63279249]
# Iteration 1950/2000 -- Loss Output: 0.4937569926045273 -- Moving Avg Loss: 0.4332195520305189
# 	Parameters used: [0.23755156 0.64159353]

# %% [markdown]
# ## Fits with Specific Obliquity

# %%
OBLIQUITY = 0.25
constraints = getConstraints(OBLIQUITY, longitude_max=0)

for cycloid in cycloids:
    process_cycloid_top_fits(cycloids[cycloid].curve,
                             cycloid,
                             folder='./output/lockedObliquity025/',
                             iterations=2000,
                             constraints=constraints,
                             number_of_fits=5,
                             paramCount=2,
                             verbose=False
                            )
    
# process_cycloid_top_fits(cycloids['alex'].curve,
#                          cycloid,
#                          folder='./output/lockedObliquity025/',
#                          iterations=2000,
#                          constraints=constraints,
#                          number_of_fits=5,
#                          paramCount=2,
#                          verbose=False
#                         )
# Out:
# Iteration 150/2000 -- Loss Output: 2.16024819583002 -- Moving Avg Loss: 1.863116178481181
# 	Parameters used: [0.64146317 0.25      ]
# Iteration 300/2000 -- Loss Output: 3.1661546059353585 -- Moving Avg Loss: 3.136314110969231
# 	Parameters used: [0.48571932 0.25      ]
# Iteration 450/2000 -- Loss Output: 0.2787510925695823 -- Moving Avg Loss: 1.148028478119953
# 	Parameters used: [0.6975672 0.25     ]
# Iteration 600/2000 -- Loss Output: 0.20185797208509196 -- Moving Avg Loss: 1.1353190246828213
# 	Parameters used: [0.74479543 0.25      ]
# Iteration 750/2000 -- Loss Output: 2.793670412617595 -- Moving Avg Loss: 1.4562211783827896
# 	Parameters used: [0.5776587 0.25     ]
# Iteration 900/2000 -- Loss Output: 3.597043075399308 -- Moving Avg Loss: 2.5299871560869676
# 	Parameters used: [0.4706108 0.25     ]
# Iteration 1050/2000 -- Loss Output: 0.4135257418138971 -- Moving Avg Loss: 1.052964572909955
# 	Parameters used: [0.68564265 0.25      ]
# Iteration 1200/2000 -- Loss Output: 11.612648662229123 -- Moving Avg Loss: 8.578410107689274
# 	Parameters used: [0.25729923 0.25      ]
# Iteration 1350/2000 -- Loss Output: 2.2415434652829127 -- Moving Avg Loss: 5.640280831490076
# 	Parameters used: [0.9315762 0.25     ]
# Iteration 1500/2000 -- Loss Output: 1.4627358582564813 -- Moving Avg Loss: 1.6680433977894793
# 	Parameters used: [0.58542128 0.25      ]
# Iteration 1650/2000 -- Loss Output: 0.042517558173951 -- Moving Avg Loss: 1.0396353390932789
# 	Parameters used: [0.66967868 0.25      ]
# Iteration 1800/2000 -- Loss Output: 1.213992428762787 -- Moving Avg Loss: 0.9528425835986283
# 	Parameters used: [0.77100763 0.25      ]
# Iteration 1950/2000 -- Loss Output: 3.95760282950087 -- Moving Avg Loss: 6.960788417422093
# 	Parameters used: [0.98181558 0.25      ]
# Iteration 150/2000 -- Loss Output: 1.1824051023023638 -- Moving Avg Loss: 1.20656033300274
# 	Parameters used: [0.37603242 0.25      ]
# Iteration 300/2000 -- Loss Output: 3.1868711323522154 -- Moving Avg Loss: 4.170232072436958
# 	Parameters used: [0.39874744 0.25      ]
# Iteration 450/2000 -- Loss Output: 1.5267041166093425 -- Moving Avg Loss: 0.5198913230153221
# 	Parameters used: [0.29505156 0.25      ]
# Iteration 600/2000 -- Loss Output: 0.12580667044525645 -- Moving Avg Loss: 0.5524893674659181
# 	Parameters used: [0.25110446 0.25      ]
# Iteration 750/2000 -- Loss Output: 14.58641741967069 -- Moving Avg Loss: 2.6394888069593367
# 	Parameters used: [0.94803283 0.25      ]
# Iteration 900/2000 -- Loss Output: 0.06481226921216497 -- Moving Avg Loss: 1.1653516230269245
# 	Parameters used: [0.39410672 0.25      ]
# Iteration 1050/2000 -- Loss Output: 0.4290341150613355 -- Moving Avg Loss: 0.6549957477597489
# 	Parameters used: [0.23346911 0.25      ]
# Iteration 1200/2000 -- Loss Output: 2.5529586805151467 -- Moving Avg Loss: 0.6042177214359638
# 	Parameters used: [0.15891893 0.25      ]
# Iteration 1350/2000 -- Loss Output: 14.903829170638732 -- Moving Avg Loss: 5.21393424323508
# 	Parameters used: [0.86680762 0.25      ]
# Iteration 1500/2000 -- Loss Output: 0.05960030117188423 -- Moving Avg Loss: 0.598086709404618
# 	Parameters used: [0.35116061 0.25      ]
# Iteration 1650/2000 -- Loss Output: 1.3546704713730249 -- Moving Avg Loss: 0.3569158895091282
# 	Parameters used: [0.23633695 0.25      ]
# Iteration 1800/2000 -- Loss Output: 4.372107638428744 -- Moving Avg Loss: 5.140524890148613
# 	Parameters used: [0.45350399 0.25      ]
# Iteration 1950/2000 -- Loss Output: 0.19732264630168764 -- Moving Avg Loss: 0.4530647252473501
# 	Parameters used: [0.17943085 0.25      ]
# Iteration 150/2000 -- Loss Output: 0.07418326583480084 -- Moving Avg Loss: 0.07434660123834076
# 	Parameters used: [0.20146097 0.25      ]
# Iteration 300/2000 -- Loss Output: 0.0755770661340947 -- Moving Avg Loss: 0.07936042750004696
# 	Parameters used: [0.68087245 0.25      ]
# Iteration 450/2000 -- Loss Output: 0.10225724992217412 -- Moving Avg Loss: 0.07842834577919837
# 	Parameters used: [0.19360066 0.25      ]
# Iteration 600/2000 -- Loss Output: 0.07565229501510672 -- Moving Avg Loss: 0.07628168479395271
# 	Parameters used: [0.12550596 0.25      ]
# Iteration 750/2000 -- Loss Output: 0.0766129380698736 -- Moving Avg Loss: 0.07426747772240404
# 	Parameters used: [0.12187877 0.25      ]
# Iteration 900/2000 -- Loss Output: 0.09046111150223071 -- Moving Avg Loss: 0.08321706864876142
# 	Parameters used: [0.3452642 0.25     ]
# Iteration 1050/2000 -- Loss Output: 0.0652763788536844 -- Moving Avg Loss: 0.07646634562420845
# 	Parameters used: [0.08368071 0.25      ]
# Iteration 1200/2000 -- Loss Output: 0.14798896838998327 -- Moving Avg Loss: 0.08442452465944489
# 	Parameters used: [0.32734038 0.25      ]
# Iteration 1350/2000 -- Loss Output: 0.09839842507167411 -- Moving Avg Loss: 0.08437429471248013
# 	Parameters used: [0.16134372 0.25      ]
# Iteration 1500/2000 -- Loss Output: 0.0691218863791859 -- Moving Avg Loss: 0.06814523700104867
# 	Parameters used: [0.84015871 0.25      ]
# Iteration 1650/2000 -- Loss Output: 0.06306561205672527 -- Moving Avg Loss: 0.0713663728558696
# 	Parameters used: [0.76145771 0.25      ]
# Iteration 1800/2000 -- Loss Output: 0.09108282965864913 -- Moving Avg Loss: 0.08235775938832626
# 	Parameters used: [0.33025442 0.25      ]
# Iteration 1950/2000 -- Loss Output: 0.0926376029858181 -- Moving Avg Loss: 0.07726000168575435
# 	Parameters used: [0.02724085 0.25      ]
# Iteration 150/2000 -- Loss Output: 0.08871706998023747 -- Moving Avg Loss: 0.07570014678445318
# 	Parameters used: [0.08153556 0.25      ]
# Iteration 300/2000 -- Loss Output: 0.06082393987663263 -- Moving Avg Loss: 0.07534657161607035
# 	Parameters used: [0.46306499 0.25      ]
# Iteration 450/2000 -- Loss Output: 0.07989275568186521 -- Moving Avg Loss: 0.079953792136521
# 	Parameters used: [0.47637618 0.25      ]
# Iteration 600/2000 -- Loss Output: 0.056005077660019754 -- Moving Avg Loss: 0.071678149228644
# 	Parameters used: [0.67539993 0.25      ]
# Iteration 750/2000 -- Loss Output: 0.08074956632417687 -- Moving Avg Loss: 0.07295621316063881
# 	Parameters used: [0.08099485 0.25      ]
# Iteration 900/2000 -- Loss Output: 0.06019351117055061 -- Moving Avg Loss: 0.07101843126300093
# 	Parameters used: [0.44432528 0.25      ]
# Iteration 1050/2000 -- Loss Output: 0.07227261144737736 -- Moving Avg Loss: 0.07277276769166806
# 	Parameters used: [0.66432882 0.25      ]
# Iteration 1200/2000 -- Loss Output: 0.05786829658664311 -- Moving Avg Loss: 0.0720265075410764
# 	Parameters used: [0.40768652 0.25      ]
# Iteration 1350/2000 -- Loss Output: 0.06929522697903359 -- Moving Avg Loss: 0.07561959842753778
# 	Parameters used: [0.61751858 0.25      ]
# Iteration 1500/2000 -- Loss Output: 0.060771843672901164 -- Moving Avg Loss: 0.07996684233192863
# 	Parameters used: [0.08341936 0.25      ]
# Iteration 1650/2000 -- Loss Output: 0.06372544667276651 -- Moving Avg Loss: 0.06764085149967278
# 	Parameters used: [0.63524391 0.25      ]
# Iteration 1800/2000 -- Loss Output: 0.08804084452712874 -- Moving Avg Loss: 0.07484523759734601
# 	Parameters used: [0.83273311 0.25      ]
# Iteration 1950/2000 -- Loss Output: 0.07133927623012801 -- Moving Avg Loss: 0.0754507264757859
# 	Parameters used: [0.64467025 0.25      ]
# Iteration 150/2000 -- Loss Output: 25.298955247988435 -- Moving Avg Loss: 11.027831413012935
# 	Parameters used: [0.86060554 0.25      ]
# Iteration 300/2000 -- Loss Output: 6.424862760377699 -- Moving Avg Loss: 1.4099941601478008
# 	Parameters used: [0.0540289 0.25     ]
# Iteration 450/2000 -- Loss Output: 0.31329568288870563 -- Moving Avg Loss: 0.656445524413655
# 	Parameters used: [0.12931636 0.25      ]
# Iteration 600/2000 -- Loss Output: 0.807662897866784 -- Moving Avg Loss: 0.3187275764886504
# 	Parameters used: [0.20793866 0.25      ]
# Iteration 750/2000 -- Loss Output: 1.127905036222378 -- Moving Avg Loss: 0.4685429039600874
# 	Parameters used: [0.28989039 0.25      ]
# Iteration 900/2000 -- Loss Output: 3.1587006438817675 -- Moving Avg Loss: 5.0064671446200295
# 	Parameters used: [0.10587813 0.25      ]
# Iteration 1050/2000 -- Loss Output: 3.1872725499335424 -- Moving Avg Loss: 1.6424449499712255
# 	Parameters used: [0.46470513 0.25      ]
# Iteration 1200/2000 -- Loss Output: 0.15559892605664727 -- Moving Avg Loss: 0.3962419546896973
# 	Parameters used: [0.34917719 0.25      ]
# Iteration 1350/2000 -- Loss Output: 0.10814882960214503 -- Moving Avg Loss: 0.43860769805910776
# 	Parameters used: [0.27600693 0.25      ]
# Iteration 1500/2000 -- Loss Output: 0.20440293120394615 -- Moving Avg Loss: 0.45715822449257293
# 	Parameters used: [0.21200701 0.25      ]
# Iteration 1650/2000 -- Loss Output: 1.6582129097015803 -- Moving Avg Loss: 0.9811184067674407
# 	Parameters used: [0.07461352 0.25      ]
# Iteration 1800/2000 -- Loss Output: 25.07741754647398 -- Moving Avg Loss: 19.827201008415603
# 	Parameters used: [0.85450456 0.25      ]
# Iteration 1950/2000 -- Loss Output: 0.4820499427935357 -- Moving Avg Loss: 0.7530183676224556
# 	Parameters used: [0.1182775 0.25     ]
# Iteration 150/2000 -- Loss Output: 19.24945965572736 -- Moving Avg Loss: 12.483684567958084
# 	Parameters used: [0.89973681 0.25      ]
# Iteration 300/2000 -- Loss Output: 20.010959853173702 -- Moving Avg Loss: 16.629952410043604
# 	Parameters used: [0.75042569 0.25      ]
# Iteration 450/2000 -- Loss Output: 16.200038184129866 -- Moving Avg Loss: 14.951603091818374
# 	Parameters used: [0.9383108 0.25     ]
# Iteration 600/2000 -- Loss Output: 10.281260168424708 -- Moving Avg Loss: 12.665501053318582
# 	Parameters used: [0.59115028 0.25      ]
# Iteration 750/2000 -- Loss Output: 17.833489660581616 -- Moving Avg Loss: 17.232983831184736
# 	Parameters used: [0.7855357 0.25     ]
# Iteration 900/2000 -- Loss Output: 9.786225744960403 -- Moving Avg Loss: 12.865328060238932
# 	Parameters used: [0.5015006 0.25     ]
# Iteration 1050/2000 -- Loss Output: 9.204141186663328 -- Moving Avg Loss: 8.556792434728385
# 	Parameters used: [0.20599981 0.25      ]
# Iteration 1200/2000 -- Loss Output: 19.747102322556238 -- Moving Avg Loss: 11.848235163933893
# 	Parameters used: [0.40822418 0.25      ]
# Iteration 1350/2000 -- Loss Output: 15.466266680232062 -- Moving Avg Loss: 11.918005702448866
# 	Parameters used: [0.46885576 0.25      ]
# Iteration 1500/2000 -- Loss Output: 14.851863032119713 -- Moving Avg Loss: 11.71195148421915
# 	Parameters used: [0.52032054 0.25      ]
# Iteration 1650/2000 -- Loss Output: 17.057011570240718 -- Moving Avg Loss: 10.617939331478476
# 	Parameters used: [0.08273469 0.25      ]
# Iteration 1800/2000 -- Loss Output: 15.520216546488419 -- Moving Avg Loss: 14.292830629840509
# 	Parameters used: [0.7148547 0.25     ]
# Iteration 1950/2000 -- Loss Output: 7.490223925562929 -- Moving Avg Loss: 8.549928944581175
# 	Parameters used: [0.20231084 0.25      ]
# Iteration 150/2000 -- Loss Output: 0.8751996655897206 -- Moving Avg Loss: 3.490155927690331
# 	Parameters used: [0.25454824 0.25      ]
# Iteration 300/2000 -- Loss Output: 4.237681852947841 -- Moving Avg Loss: 1.73961491729856
# 	Parameters used: [0.65208437 0.25      ]
# Iteration 450/2000 -- Loss Output: 1.3892875752230978 -- Moving Avg Loss: 0.9594001392476713
# 	Parameters used: [0.47834055 0.25      ]
# Iteration 600/2000 -- Loss Output: 3.6669989281234283 -- Moving Avg Loss: 4.918713936199132
# 	Parameters used: [0.15984573 0.25      ]
# Iteration 750/2000 -- Loss Output: 0.06303845455907746 -- Moving Avg Loss: 0.5054655371755313
# 	Parameters used: [0.38876874 0.25      ]
# Iteration 900/2000 -- Loss Output: 5.452885460705775 -- Moving Avg Loss: 2.584551578527643
# 	Parameters used: [0.78726133 0.25      ]
# Iteration 1050/2000 -- Loss Output: 3.936296815985648 -- Moving Avg Loss: 3.5671809801082013
# 	Parameters used: [0.13158273 0.25      ]
# Iteration 1200/2000 -- Loss Output: 1.0391251369841192 -- Moving Avg Loss: 0.9340946426456357
# 	Parameters used: [0.46417862 0.25      ]
# Iteration 1350/2000 -- Loss Output: 4.582744701513063 -- Moving Avg Loss: 4.3009703641409285
# 	Parameters used: [0.96856812 0.25      ]
# Iteration 1500/2000 -- Loss Output: 1.7083822057279447 -- Moving Avg Loss: 1.0939539768873545
# 	Parameters used: [0.5681164 0.25     ]
# Iteration 1650/2000 -- Loss Output: 1.996475709790224 -- Moving Avg Loss: 2.2450386204410226
# 	Parameters used: [0.33827762 0.25      ]
# Iteration 1800/2000 -- Loss Output: 0.5722786350014287 -- Moving Avg Loss: 0.8242719045543184
# 	Parameters used: [0.43793675 0.25      ]
# Iteration 1950/2000 -- Loss Output: 2.2746243429640356 -- Moving Avg Loss: 5.136416910860589
# 	Parameters used: [0.15999759 0.25      ]
# Iteration 150/2000 -- Loss Output: 0.08184818483265764 -- Moving Avg Loss: 0.07405635996437915
# 	Parameters used: [0.0440335 0.25     ]
# Iteration 300/2000 -- Loss Output: 0.06850001094261636 -- Moving Avg Loss: 0.07360897697984062
# 	Parameters used: [0.88325125 0.25      ]
# Iteration 450/2000 -- Loss Output: 0.0774122797162148 -- Moving Avg Loss: 0.08019330906485617
# 	Parameters used: [0.23163504 0.25      ]
# Iteration 600/2000 -- Loss Output: 0.06095647652851642 -- Moving Avg Loss: 0.07728875146254614
# 	Parameters used: [0.42154069 0.25      ]
# Iteration 750/2000 -- Loss Output: 0.07979483804987679 -- Moving Avg Loss: 0.0757735713880459
# 	Parameters used: [0.58744197 0.25      ]
# Iteration 900/2000 -- Loss Output: 0.060843411219457855 -- Moving Avg Loss: 0.08008564512575318
# 	Parameters used: [0.6958916 0.25     ]
# Iteration 1050/2000 -- Loss Output: 0.06603379646671814 -- Moving Avg Loss: 0.06961233071257954
# 	Parameters used: [0.90887333 0.25      ]
# Iteration 1200/2000 -- Loss Output: 0.08035940175324703 -- Moving Avg Loss: 0.07297051277114884
# 	Parameters used: [0.01152562 0.25      ]
# Iteration 1350/2000 -- Loss Output: 0.07744810990647048 -- Moving Avg Loss: 0.07348459029610135
# 	Parameters used: [0.5924224 0.25     ]
# Iteration 1500/2000 -- Loss Output: 0.06810355719107371 -- Moving Avg Loss: 0.07544608147169017
# 	Parameters used: [0.44901238 0.25      ]
# Iteration 1650/2000 -- Loss Output: 0.07820780657364353 -- Moving Avg Loss: 0.07629206926919391
# 	Parameters used: [0.50654689 0.25      ]
# Iteration 1800/2000 -- Loss Output: 0.06481707031044048 -- Moving Avg Loss: 0.07735624676994529
# 	Parameters used: [0.09603932 0.25      ]
# Iteration 1950/2000 -- Loss Output: 0.06199127830526916 -- Moving Avg Loss: 0.07933437876126774
# 	Parameters used: [0.6590112 0.25     ]
# Iteration 150/2000 -- Loss Output: 8.855038370230059 -- Moving Avg Loss: 10.42710881827832
# 	Parameters used: [0.80479188 0.25      ]
# Iteration 300/2000 -- Loss Output: 5.5932511487522465 -- Moving Avg Loss: 5.596702440631409
# 	Parameters used: [0.1232968 0.25     ]
# Iteration 450/2000 -- Loss Output: 17.576730821123128 -- Moving Avg Loss: 11.590027821812026
# 	Parameters used: [0.71641366 0.25      ]
# Iteration 600/2000 -- Loss Output: 8.374287173354391 -- Moving Avg Loss: 8.564592523711147
# 	Parameters used: [0.44886499 0.25      ]
# Iteration 750/2000 -- Loss Output: 6.583891017238669 -- Moving Avg Loss: 5.752675355769996
# 	Parameters used: [0.04866443 0.25      ]
# Iteration 900/2000 -- Loss Output: 6.339993453332083 -- Moving Avg Loss: 8.566477538145916
# 	Parameters used: [0.49264152 0.25      ]
# Iteration 1050/2000 -- Loss Output: 9.726589613861629 -- Moving Avg Loss: 5.03394329452017
# 	Parameters used: [0.22923181 0.25      ]
# Iteration 1200/2000 -- Loss Output: 4.501077929312071 -- Moving Avg Loss: 8.071051384742471
# 	Parameters used: [0.96885972 0.25      ]
# Iteration 1350/2000 -- Loss Output: 11.424217911142057 -- Moving Avg Loss: 8.834309182322466
# 	Parameters used: [0.61118614 0.25      ]
# Iteration 1500/2000 -- Loss Output: 11.782330720334466 -- Moving Avg Loss: 7.096545964271839
# 	Parameters used: [0.37599261 0.25      ]
# Iteration 1650/2000 -- Loss Output: 3.481059760878609 -- Moving Avg Loss: 6.437431046509626
# 	Parameters used: [0.27104822 0.25      ]
# Iteration 1800/2000 -- Loss Output: 6.702880224935267 -- Moving Avg Loss: 4.237835999037153
# 	Parameters used: [0.14759403 0.25      ]
# Iteration 1950/2000 -- Loss Output: 8.757400820833332 -- Moving Avg Loss: 11.984963686892748
# 	Parameters used: [0.95847273 0.25      ]
# Iteration 150/2000 -- Loss Output: 3.3469197959308086 -- Moving Avg Loss: 1.8184890875194322
# 	Parameters used: [0.59710029 0.25      ]
# Iteration 300/2000 -- Loss Output: 2.289752458356416 -- Moving Avg Loss: 1.9808066138862819
# 	Parameters used: [0.56320139 0.25      ]
# Iteration 450/2000 -- Loss Output: 3.8674653770236502 -- Moving Avg Loss: 2.316762120661261
# 	Parameters used: [0.59802879 0.25      ]
# Iteration 600/2000 -- Loss Output: 0.10925389522091734 -- Moving Avg Loss: 0.2727127012156759
# 	Parameters used: [0.02193449 0.25      ]
# Iteration 750/2000 -- Loss Output: 0.05763372794122717 -- Moving Avg Loss: 0.3956318253325924
# 	Parameters used: [0.12392669 0.25      ]
# Iteration 900/2000 -- Loss Output: 2.001541006135688 -- Moving Avg Loss: 0.7355089672804606
# 	Parameters used: [0.23779456 0.25      ]
# Iteration 1050/2000 -- Loss Output: 5.959192763865125 -- Moving Avg Loss: 7.164480635747907
# 	Parameters used: [0.90718804 0.25      ]
# Iteration 1200/2000 -- Loss Output: 1.4381555363390073 -- Moving Avg Loss: 0.23493955583338283
# 	Parameters used: [0.10503753 0.25      ]
# Iteration 1350/2000 -- Loss Output: 16.40247282283045 -- Moving Avg Loss: 2.83594267899537
# 	Parameters used: [0.64607931 0.25      ]
# Iteration 1500/2000 -- Loss Output: 0.14549936397007382 -- Moving Avg Loss: 0.32153773952577774
# 	Parameters used: [0.99110505 0.25      ]
# Iteration 1650/2000 -- Loss Output: 0.12643367698664287 -- Moving Avg Loss: 0.28581602173436077
# 	Parameters used: [0.02534638 0.25      ]
# Iteration 1800/2000 -- Loss Output: 0.11646621806162438 -- Moving Avg Loss: 0.31163796467753524
# 	Parameters used: [0.05560711 0.25      ]
# Iteration 1950/2000 -- Loss Output: 0.11307666050867572 -- Moving Avg Loss: 0.31627495058454397
# 	Parameters used: [0.08209701 0.25      ]
